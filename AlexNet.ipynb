# %%
import os
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import copy

class MineralDataset(Dataset):
    def __init__(self, img_dir, labels_csv, transform=None):
        self.dataframe = pd.read_csv(labels_csv)
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        file_name = row['Segmented Filename']
        label = row['Class']
        img_path = os.path.join(self.img_dir, file_name)
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label

transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transform_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

IMAGE_DIR = '/Mineral/CPX seg'
TRAIN_SPLIT_FILE = '/Mineral/train_split.csv'
VAL_SPLIT_FILE = '/Mineral/val_split.csv'

dataset_train = MineralDataset(
    img_dir=IMAGE_DIR,
    labels_csv=TRAIN_SPLIT_FILE,
    transform=transform_train
)

dataset_val = MineralDataset(
    img_dir=IMAGE_DIR,
    labels_csv=VAL_SPLIT_FILE,
    transform=transform_val
)

train_loader = DataLoader(dataset_train, batch_size=32, shuffle=True)
val_loader = DataLoader(dataset_val, batch_size=32, shuffle=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

alexnet = models.alexnet(pretrained=True)
for param in alexnet.parameters():
    param.requires_grad = False

num_ftrs = alexnet.classifier[6].in_features
alexnet.classifier[6] = nn.Linear(num_ftrs, 3)
alexnet = alexnet.to(device)

alexnet.classifier = nn.Sequential(
    *list(alexnet.classifier.children())[:-1],
    nn.Dropout(0.25),  # Dropout layer
    nn.Linear(num_ftrs, 3)  # Final linear layer
)
alexnet = alexnet.to(device)

labels = [label for _, label in dataset_train]
class_weights = compute_class_weight('balanced', classes=np.unique(labels), y=labels)
class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)

criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(alexnet.classifier.parameters(), lr=0.0001)

def train_and_evaluate_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=200, device='cuda'):
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    history = {
        'train_loss': [],
        'train_acc': [],
        'val_loss': [],
        'val_acc': []
    }

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        train_corrects = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            train_corrects += torch.sum(preds == labels.data).item()

        train_loss = train_loss / len(train_loader.dataset)
        train_acc = train_corrects / len(train_loader.dataset)
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)

        model.eval()
        val_loss = 0.0
        val_corrects = 0

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * inputs.size(0)
                _, preds = torch.max(outputs, 1)
                val_corrects += torch.sum(preds == labels.data).item()

        val_loss = val_loss / len(val_loader.dataset)
        val_acc = val_corrects / len(val_loader.dataset)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)

        print(f'Epoch {epoch+1}/{num_epochs}: Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')

        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = copy.deepcopy(model.state_dict())

    model.load_state_dict(best_model_wts)
    return model, history

trained_model, training_history = train_and_evaluate_model(alexnet, train_loader, val_loader, criterion, optimizer, num_epochs=200, device=device)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/200: Train Loss: 1.1237, Train Acc: 0.4333, Val Loss: 1.0143, Val Acc: 0.5856
# Epoch 2/200: Train Loss: 1.0337, Train Acc: 0.5565, Val Loss: 0.9751, Val Acc: 0.5925
# Epoch 3/200: Train Loss: 0.9750, Train Acc: 0.5953, Val Loss: 0.9724, Val Acc: 0.5274
# Epoch 4/200: Train Loss: 0.9873, Train Acc: 0.5601, Val Loss: 0.9526, Val Acc: 0.5959
# Epoch 5/200: Train Loss: 0.9430, Train Acc: 0.5726, Val Loss: 0.9426, Val Acc: 0.6233
# Epoch 6/200: Train Loss: 0.9344, Train Acc: 0.5880, Val Loss: 0.9345, Val Acc: 0.6370
# Epoch 7/200: Train Loss: 0.9233, Train Acc: 0.5946, Val Loss: 0.9284, Val Acc: 0.6404
# Epoch 8/200: Train Loss: 0.9179, Train Acc: 0.6100, Val Loss: 0.9224, Val Acc: 0.5753
# Epoch 9/200: Train Loss: 0.8893, Train Acc: 0.6100, Val Loss: 0.9206, Val Acc: 0.6062
# Epoch 10/200: Train Loss: 0.8690, Train Acc: 0.6437, Val Loss: 0.9123, Val Acc: 0.6267
# Epoch 11/200: Train Loss: 0.8592, Train Acc: 0.6349, Val Loss: 0.9223, Val Acc: 0.5822
# Epoch 12/200: Train Loss: 0.8820, Train Acc: 0.6232, Val Loss: 0.9162, Val Acc: 0.6438
# Epoch 13/200: Train Loss: 0.8729, Train Acc: 0.6474, Val Loss: 0.9056, Val Acc: 0.6404
# Epoch 14/200: Train Loss: 0.8653, Train Acc: 0.6393, Val Loss: 0.9227, Val Acc: 0.6678
# Epoch 15/200: Train Loss: 0.8566, Train Acc: 0.6540, Val Loss: 0.9110, Val Acc: 0.6438
# Epoch 16/200: Train Loss: 0.8600, Train Acc: 0.6290, Val Loss: 0.9267, Val Acc: 0.6404
# Epoch 17/200: Train Loss: 0.8326, Train Acc: 0.6679, Val Loss: 0.9032, Val Acc: 0.6164
# Epoch 18/200: Train Loss: 0.8326, Train Acc: 0.6437, Val Loss: 0.9210, Val Acc: 0.6130
# Epoch 19/200: Train Loss: 0.8202, Train Acc: 0.6576, Val Loss: 0.9253, Val Acc: 0.6473
# Epoch 20/200: Train Loss: 0.8237, Train Acc: 0.6334, Val Loss: 0.9326, Val Acc: 0.6781
# Epoch 21/200: Train Loss: 0.8351, Train Acc: 0.6730, Val Loss: 0.9106, Val Acc: 0.6336
# Epoch 22/200: Train Loss: 0.8225, Train Acc: 0.6562, Val Loss: 0.9161, Val Acc: 0.6678
# Epoch 23/200: Train Loss: 0.8363, Train Acc: 0.6400, Val Loss: 0.9009, Val Acc: 0.6370
# Epoch 24/200: Train Loss: 0.8542, Train Acc: 0.6532, Val Loss: 0.8924, Val Acc: 0.6130
# Epoch 25/200: Train Loss: 0.8205, Train Acc: 0.6415, Val Loss: 0.9128, Val Acc: 0.6507
# Epoch 26/200: Train Loss: 0.8363, Train Acc: 0.6576, Val Loss: 0.8972, Val Acc: 0.6575
# Epoch 27/200: Train Loss: 0.8124, Train Acc: 0.6796, Val Loss: 0.8988, Val Acc: 0.6678
# Epoch 28/200: Train Loss: 0.8167, Train Acc: 0.6613, Val Loss: 0.8985, Val Acc: 0.6747
# Epoch 29/200: Train Loss: 0.7970, Train Acc: 0.6532, Val Loss: 0.8866, Val Acc: 0.6541
# Epoch 30/200: Train Loss: 0.8370, Train Acc: 0.6364, Val Loss: 0.9069, Val Acc: 0.6712
# Epoch 31/200: Train Loss: 0.8224, Train Acc: 0.6686, Val Loss: 0.9043, Val Acc: 0.6884
# Epoch 32/200: Train Loss: 0.8219, Train Acc: 0.6635, Val Loss: 0.9002, Val Acc: 0.6815
# Epoch 33/200: Train Loss: 0.8186, Train Acc: 0.6496, Val Loss: 0.9092, Val Acc: 0.6918
# Epoch 34/200: Train Loss: 0.8158, Train Acc: 0.6613, Val Loss: 0.9027, Val Acc: 0.6781
# Epoch 35/200: Train Loss: 0.7945, Train Acc: 0.6877, Val Loss: 0.9145, Val Acc: 0.7260
# Epoch 36/200: Train Loss: 0.8055, Train Acc: 0.6547, Val Loss: 0.8825, Val Acc: 0.6233
# Epoch 37/200: Train Loss: 0.7960, Train Acc: 0.6532, Val Loss: 0.8995, Val Acc: 0.7021
# Epoch 38/200: Train Loss: 0.7786, Train Acc: 0.6870, Val Loss: 0.8870, Val Acc: 0.6473
# Epoch 39/200: Train Loss: 0.8282, Train Acc: 0.6510, Val Loss: 0.8832, Val Acc: 0.6610
# Epoch 40/200: Train Loss: 0.8028, Train Acc: 0.6598, Val Loss: 0.8999, Val Acc: 0.7055
# Epoch 41/200: Train Loss: 0.7990, Train Acc: 0.6730, Val Loss: 0.8743, Val Acc: 0.6301
# Epoch 42/200: Train Loss: 0.7778, Train Acc: 0.6767, Val Loss: 0.8942, Val Acc: 0.6918
# Epoch 43/200: Train Loss: 0.7872, Train Acc: 0.6789, Val Loss: 0.9009, Val Acc: 0.6849
# Epoch 44/200: Train Loss: 0.7697, Train Acc: 0.6928, Val Loss: 0.8884, Val Acc: 0.6712
# Epoch 45/200: Train Loss: 0.8496, Train Acc: 0.6657, Val Loss: 0.8832, Val Acc: 0.6473
# Epoch 46/200: Train Loss: 0.7697, Train Acc: 0.6848, Val Loss: 0.8859, Val Acc: 0.6610
# Epoch 47/200: Train Loss: 0.7721, Train Acc: 0.6760, Val Loss: 0.8963, Val Acc: 0.7021
# Epoch 48/200: Train Loss: 0.7846, Train Acc: 0.7045, Val Loss: 0.8819, Val Acc: 0.6473
# Epoch 49/200: Train Loss: 0.7692, Train Acc: 0.6738, Val Loss: 0.9027, Val Acc: 0.6918
# Epoch 50/200: Train Loss: 0.8021, Train Acc: 0.6701, Val Loss: 0.8808, Val Acc: 0.6541
# Epoch 51/200: Train Loss: 0.7891, Train Acc: 0.6862, Val Loss: 0.8876, Val Acc: 0.6301
# Epoch 52/200: Train Loss: 0.7652, Train Acc: 0.6672, Val Loss: 0.9014, Val Acc: 0.7021
# Epoch 53/200: Train Loss: 0.7859, Train Acc: 0.6628, Val Loss: 0.8952, Val Acc: 0.7089
# Epoch 54/200: Train Loss: 0.7805, Train Acc: 0.6760, Val Loss: 0.8854, Val Acc: 0.6986
# Epoch 55/200: Train Loss: 0.7884, Train Acc: 0.6760, Val Loss: 0.8979, Val Acc: 0.6849
# Epoch 56/200: Train Loss: 0.7690, Train Acc: 0.6686, Val Loss: 0.8928, Val Acc: 0.6404
# Epoch 57/200: Train Loss: 0.7712, Train Acc: 0.6782, Val Loss: 0.8797, Val Acc: 0.6404
# Epoch 58/200: Train Loss: 0.7778, Train Acc: 0.6694, Val Loss: 0.8868, Val Acc: 0.6712
# Epoch 59/200: Train Loss: 0.7683, Train Acc: 0.6877, Val Loss: 0.8718, Val Acc: 0.6541
# Epoch 60/200: Train Loss: 0.7899, Train Acc: 0.6679, Val Loss: 0.8897, Val Acc: 0.6747
# Epoch 61/200: Train Loss: 0.7659, Train Acc: 0.6833, Val Loss: 0.8807, Val Acc: 0.6644
# Epoch 62/200: Train Loss: 0.7710, Train Acc: 0.6664, Val Loss: 0.9178, Val Acc: 0.7089
# Epoch 63/200: Train Loss: 0.7515, Train Acc: 0.7001, Val Loss: 0.8807, Val Acc: 0.6507
# Epoch 64/200: Train Loss: 0.8044, Train Acc: 0.6584, Val Loss: 0.8868, Val Acc: 0.6781
# Epoch 65/200: Train Loss: 0.7420, Train Acc: 0.6840, Val Loss: 0.9153, Val Acc: 0.7089
# Epoch 66/200: Train Loss: 0.7586, Train Acc: 0.6943, Val Loss: 0.8840, Val Acc: 0.6370
# Epoch 67/200: Train Loss: 0.7836, Train Acc: 0.6532, Val Loss: 0.8948, Val Acc: 0.6849
# Epoch 68/200: Train Loss: 0.7610, Train Acc: 0.6774, Val Loss: 0.9047, Val Acc: 0.6815
# Epoch 69/200: Train Loss: 0.7386, Train Acc: 0.7009, Val Loss: 0.8891, Val Acc: 0.6781
# Epoch 70/200: Train Loss: 0.7639, Train Acc: 0.6906, Val Loss: 0.8810, Val Acc: 0.6370
# Epoch 71/200: Train Loss: 0.7421, Train Acc: 0.7009, Val Loss: 0.9213, Val Acc: 0.7226
# Epoch 72/200: Train Loss: 0.7720, Train Acc: 0.6870, Val Loss: 0.9079, Val Acc: 0.6849
# Epoch 73/200: Train Loss: 0.7690, Train Acc: 0.6906, Val Loss: 0.9029, Val Acc: 0.6986
# Epoch 74/200: Train Loss: 0.7573, Train Acc: 0.6767, Val Loss: 0.8821, Val Acc: 0.6610
# Epoch 75/200: Train Loss: 0.7347, Train Acc: 0.7060, Val Loss: 0.8916, Val Acc: 0.6815
# Epoch 76/200: Train Loss: 0.7541, Train Acc: 0.6840, Val Loss: 0.8862, Val Acc: 0.6747
# Epoch 77/200: Train Loss: 0.7750, Train Acc: 0.6752, Val Loss: 0.8896, Val Acc: 0.6336
# Epoch 78/200: Train Loss: 0.7493, Train Acc: 0.6840, Val Loss: 0.9076, Val Acc: 0.7123
# Epoch 79/200: Train Loss: 0.7396, Train Acc: 0.7097, Val Loss: 0.8995, Val Acc: 0.7021
# Epoch 80/200: Train Loss: 0.7634, Train Acc: 0.6935, Val Loss: 0.8923, Val Acc: 0.6541
# Epoch 81/200: Train Loss: 0.7609, Train Acc: 0.6760, Val Loss: 0.9014, Val Acc: 0.6884
# Epoch 82/200: Train Loss: 0.7752, Train Acc: 0.6979, Val Loss: 0.8919, Val Acc: 0.7055
# Epoch 83/200: Train Loss: 0.7322, Train Acc: 0.6979, Val Loss: 0.9513, Val Acc: 0.7226
# Epoch 84/200: Train Loss: 0.7773, Train Acc: 0.6752, Val Loss: 0.9025, Val Acc: 0.6952
# Epoch 85/200: Train Loss: 0.7653, Train Acc: 0.6525, Val Loss: 0.9076, Val Acc: 0.7123
# Epoch 86/200: Train Loss: 0.7646, Train Acc: 0.7031, Val Loss: 0.8919, Val Acc: 0.6610
# Epoch 87/200: Train Loss: 0.7387, Train Acc: 0.7038, Val Loss: 0.8841, Val Acc: 0.6815
# Epoch 88/200: Train Loss: 0.7576, Train Acc: 0.6840, Val Loss: 0.8903, Val Acc: 0.6438
# Epoch 89/200: Train Loss: 0.7504, Train Acc: 0.6906, Val Loss: 0.8958, Val Acc: 0.6370
# Epoch 90/200: Train Loss: 0.7539, Train Acc: 0.6745, Val Loss: 0.9021, Val Acc: 0.6815
# Epoch 91/200: Train Loss: 0.7523, Train Acc: 0.6760, Val Loss: 0.9229, Val Acc: 0.7226
# Epoch 92/200: Train Loss: 0.7661, Train Acc: 0.6891, Val Loss: 0.9046, Val Acc: 0.6918
# Epoch 93/200: Train Loss: 0.7384, Train Acc: 0.6987, Val Loss: 0.8905, Val Acc: 0.6301
# Epoch 94/200: Train Loss: 0.7515, Train Acc: 0.7009, Val Loss: 0.9194, Val Acc: 0.7021
# Epoch 95/200: Train Loss: 0.7470, Train Acc: 0.6745, Val Loss: 0.9281, Val Acc: 0.7089
# Epoch 96/200: Train Loss: 0.7702, Train Acc: 0.6877, Val Loss: 0.9084, Val Acc: 0.6849
# Epoch 97/200: Train Loss: 0.7427, Train Acc: 0.6811, Val Loss: 0.9220, Val Acc: 0.6884
# Epoch 98/200: Train Loss: 0.7438, Train Acc: 0.7060, Val Loss: 0.9209, Val Acc: 0.6815
# Epoch 99/200: Train Loss: 0.7365, Train Acc: 0.7038, Val Loss: 0.9208, Val Acc: 0.6815
# Epoch 100/200: Train Loss: 0.7552, Train Acc: 0.6818, Val Loss: 0.9152, Val Acc: 0.6849
# Epoch 101/200: Train Loss: 0.7338, Train Acc: 0.6979, Val Loss: 0.9032, Val Acc: 0.6815
# Epoch 102/200: Train Loss: 0.7731, Train Acc: 0.6716, Val Loss: 0.9098, Val Acc: 0.7158
# Epoch 103/200: Train Loss: 0.7355, Train Acc: 0.6979, Val Loss: 0.9382, Val Acc: 0.6849
# Epoch 104/200: Train Loss: 0.7260, Train Acc: 0.7038, Val Loss: 0.9106, Val Acc: 0.6747
# Epoch 105/200: Train Loss: 0.7702, Train Acc: 0.6613, Val Loss: 0.9388, Val Acc: 0.7021
# Epoch 106/200: Train Loss: 0.7642, Train Acc: 0.6796, Val Loss: 0.9467, Val Acc: 0.7432
# Epoch 107/200: Train Loss: 0.7460, Train Acc: 0.7016, Val Loss: 0.9111, Val Acc: 0.6918
# Epoch 108/200: Train Loss: 0.7702, Train Acc: 0.6891, Val Loss: 0.8839, Val Acc: 0.6575
# Epoch 109/200: Train Loss: 0.7442, Train Acc: 0.6935, Val Loss: 0.8984, Val Acc: 0.6712
# Epoch 110/200: Train Loss: 0.7382, Train Acc: 0.6899, Val Loss: 0.9334, Val Acc: 0.6952
# Epoch 111/200: Train Loss: 0.7345, Train Acc: 0.6899, Val Loss: 0.9039, Val Acc: 0.6404
# Epoch 112/200: Train Loss: 0.7668, Train Acc: 0.6716, Val Loss: 0.9013, Val Acc: 0.6610
# Epoch 113/200: Train Loss: 0.7262, Train Acc: 0.7082, Val Loss: 0.9144, Val Acc: 0.6884
# Epoch 114/200: Train Loss: 0.7589, Train Acc: 0.6833, Val Loss: 0.9056, Val Acc: 0.6986
# Epoch 115/200: Train Loss: 0.7291, Train Acc: 0.7082, Val Loss: 0.8906, Val Acc: 0.6884
# Epoch 116/200: Train Loss: 0.7390, Train Acc: 0.6965, Val Loss: 0.9264, Val Acc: 0.6575
# Epoch 117/200: Train Loss: 0.7226, Train Acc: 0.7001, Val Loss: 0.9086, Val Acc: 0.6507
# Epoch 118/200: Train Loss: 0.7022, Train Acc: 0.6957, Val Loss: 0.9267, Val Acc: 0.6815
# Epoch 119/200: Train Loss: 0.7332, Train Acc: 0.6979, Val Loss: 0.9127, Val Acc: 0.6541
# Epoch 120/200: Train Loss: 0.7425, Train Acc: 0.6928, Val Loss: 0.9221, Val Acc: 0.6952
# Epoch 121/200: Train Loss: 0.7604, Train Acc: 0.6921, Val Loss: 0.9087, Val Acc: 0.6507
# Epoch 122/200: Train Loss: 0.7386, Train Acc: 0.6862, Val Loss: 0.9095, Val Acc: 0.6575
# Epoch 123/200: Train Loss: 0.7237, Train Acc: 0.7045, Val Loss: 0.8844, Val Acc: 0.6027
# Epoch 124/200: Train Loss: 0.7321, Train Acc: 0.6928, Val Loss: 0.9274, Val Acc: 0.6952
# Epoch 125/200: Train Loss: 0.7325, Train Acc: 0.7075, Val Loss: 0.9057, Val Acc: 0.6712
# Epoch 126/200: Train Loss: 0.7446, Train Acc: 0.6957, Val Loss: 0.9263, Val Acc: 0.6815
# Epoch 127/200: Train Loss: 0.7410, Train Acc: 0.7031, Val Loss: 0.9139, Val Acc: 0.6815
# Epoch 128/200: Train Loss: 0.7558, Train Acc: 0.6957, Val Loss: 0.9033, Val Acc: 0.6747
# Epoch 129/200: Train Loss: 0.7476, Train Acc: 0.6870, Val Loss: 0.9160, Val Acc: 0.6849
# Epoch 130/200: Train Loss: 0.7353, Train Acc: 0.7104, Val Loss: 0.9485, Val Acc: 0.7055
# Epoch 131/200: Train Loss: 0.7485, Train Acc: 0.6943, Val Loss: 0.9183, Val Acc: 0.6747
# Epoch 132/200: Train Loss: 0.7488, Train Acc: 0.6906, Val Loss: 0.9026, Val Acc: 0.6575
# Epoch 133/200: Train Loss: 0.7459, Train Acc: 0.6855, Val Loss: 0.9549, Val Acc: 0.7295
# Epoch 134/200: Train Loss: 0.7584, Train Acc: 0.6928, Val Loss: 0.9361, Val Acc: 0.6575
# Epoch 135/200: Train Loss: 0.7397, Train Acc: 0.7089, Val Loss: 0.9274, Val Acc: 0.6918
# Epoch 136/200: Train Loss: 0.7346, Train Acc: 0.6965, Val Loss: 0.9400, Val Acc: 0.6952
# Epoch 137/200: Train Loss: 0.7312, Train Acc: 0.6965, Val Loss: 0.9214, Val Acc: 0.6644
# Epoch 138/200: Train Loss: 0.7570, Train Acc: 0.7045, Val Loss: 0.9094, Val Acc: 0.6062
# Epoch 139/200: Train Loss: 0.7591, Train Acc: 0.6840, Val Loss: 0.9203, Val Acc: 0.6781
# Epoch 140/200: Train Loss: 0.7089, Train Acc: 0.7177, Val Loss: 0.9213, Val Acc: 0.6610
# Epoch 141/200: Train Loss: 0.7375, Train Acc: 0.6862, Val Loss: 0.9280, Val Acc: 0.6952
# Epoch 142/200: Train Loss: 0.7221, Train Acc: 0.6928, Val Loss: 0.9337, Val Acc: 0.6884
# Epoch 143/200: Train Loss: 0.7505, Train Acc: 0.6833, Val Loss: 0.9386, Val Acc: 0.6884
# Epoch 144/200: Train Loss: 0.7584, Train Acc: 0.6848, Val Loss: 0.8975, Val Acc: 0.6712
# Epoch 145/200: Train Loss: 0.7058, Train Acc: 0.7273, Val Loss: 0.9097, Val Acc: 0.6747
# Epoch 146/200: Train Loss: 0.7328, Train Acc: 0.6979, Val Loss: 0.9022, Val Acc: 0.6644
# Epoch 147/200: Train Loss: 0.7372, Train Acc: 0.6870, Val Loss: 0.9275, Val Acc: 0.6884
# Epoch 148/200: Train Loss: 0.7307, Train Acc: 0.6884, Val Loss: 0.9033, Val Acc: 0.6610
# Epoch 149/200: Train Loss: 0.7413, Train Acc: 0.7067, Val Loss: 0.9140, Val Acc: 0.6849
# Epoch 150/200: Train Loss: 0.7369, Train Acc: 0.6950, Val Loss: 0.9083, Val Acc: 0.6678
# Epoch 151/200: Train Loss: 0.7262, Train Acc: 0.6921, Val Loss: 0.8849, Val Acc: 0.6678
# Epoch 152/200: Train Loss: 0.7559, Train Acc: 0.6899, Val Loss: 0.9202, Val Acc: 0.7329
# Epoch 153/200: Train Loss: 0.7204, Train Acc: 0.7031, Val Loss: 0.9116, Val Acc: 0.6712
# Epoch 154/200: Train Loss: 0.7497, Train Acc: 0.6987, Val Loss: 0.9167, Val Acc: 0.6644
# Epoch 155/200: Train Loss: 0.7399, Train Acc: 0.7009, Val Loss: 0.9086, Val Acc: 0.6610
# Epoch 156/200: Train Loss: 0.7333, Train Acc: 0.6972, Val Loss: 0.9044, Val Acc: 0.6747
# Epoch 157/200: Train Loss: 0.7062, Train Acc: 0.7133, Val Loss: 0.9237, Val Acc: 0.6678
# Epoch 158/200: Train Loss: 0.7407, Train Acc: 0.7031, Val Loss: 0.9241, Val Acc: 0.6986
# Epoch 159/200: Train Loss: 0.7388, Train Acc: 0.7119, Val Loss: 0.9475, Val Acc: 0.6884
# Epoch 160/200: Train Loss: 0.7414, Train Acc: 0.6891, Val Loss: 0.9052, Val Acc: 0.6884
# Epoch 161/200: Train Loss: 0.7274, Train Acc: 0.6877, Val Loss: 0.9215, Val Acc: 0.6747
# Epoch 162/200: Train Loss: 0.7603, Train Acc: 0.6950, Val Loss: 0.9160, Val Acc: 0.6575
# Epoch 163/200: Train Loss: 0.6848, Train Acc: 0.7111, Val Loss: 0.9481, Val Acc: 0.7021
# Epoch 164/200: Train Loss: 0.7518, Train Acc: 0.7023, Val Loss: 0.8916, Val Acc: 0.6267
# Epoch 165/200: Train Loss: 0.7634, Train Acc: 0.6694, Val Loss: 0.9017, Val Acc: 0.6336
# Epoch 166/200: Train Loss: 0.7388, Train Acc: 0.6833, Val Loss: 0.9228, Val Acc: 0.7329
# Epoch 167/200: Train Loss: 0.7236, Train Acc: 0.7023, Val Loss: 0.9136, Val Acc: 0.6267
# Epoch 168/200: Train Loss: 0.7033, Train Acc: 0.7001, Val Loss: 0.9447, Val Acc: 0.7055
# Epoch 169/200: Train Loss: 0.7749, Train Acc: 0.6913, Val Loss: 0.9183, Val Acc: 0.6473
# Epoch 170/200: Train Loss: 0.7071, Train Acc: 0.7067, Val Loss: 0.9262, Val Acc: 0.6507
# Epoch 171/200: Train Loss: 0.7091, Train Acc: 0.6979, Val Loss: 0.9464, Val Acc: 0.6986
# Epoch 172/200: Train Loss: 0.7490, Train Acc: 0.6921, Val Loss: 0.9160, Val Acc: 0.7021
# Epoch 173/200: Train Loss: 0.7511, Train Acc: 0.6979, Val Loss: 0.8915, Val Acc: 0.6541
# Epoch 174/200: Train Loss: 0.7315, Train Acc: 0.6891, Val Loss: 0.9260, Val Acc: 0.6610
# Epoch 175/200: Train Loss: 0.7224, Train Acc: 0.6972, Val Loss: 0.9147, Val Acc: 0.6678
# Epoch 176/200: Train Loss: 0.7364, Train Acc: 0.7001, Val Loss: 0.8935, Val Acc: 0.6199
# Epoch 177/200: Train Loss: 0.7202, Train Acc: 0.7016, Val Loss: 0.9055, Val Acc: 0.6575
# Epoch 178/200: Train Loss: 0.7275, Train Acc: 0.6987, Val Loss: 0.9189, Val Acc: 0.6644
# Epoch 179/200: Train Loss: 0.7367, Train Acc: 0.7009, Val Loss: 0.9370, Val Acc: 0.6918
# Epoch 180/200: Train Loss: 0.7287, Train Acc: 0.6979, Val Loss: 0.9196, Val Acc: 0.6712
# Epoch 181/200: Train Loss: 0.7150, Train Acc: 0.6957, Val Loss: 0.9417, Val Acc: 0.6815
# Epoch 182/200: Train Loss: 0.7263, Train Acc: 0.6979, Val Loss: 0.9789, Val Acc: 0.7534
# Epoch 183/200: Train Loss: 0.7142, Train Acc: 0.7214, Val Loss: 0.9075, Val Acc: 0.6575
# Epoch 184/200: Train Loss: 0.7493, Train Acc: 0.7031, Val Loss: 0.9126, Val Acc: 0.6541
# Epoch 185/200: Train Loss: 0.7268, Train Acc: 0.6818, Val Loss: 0.9288, Val Acc: 0.6918
# Epoch 186/200: Train Loss: 0.7590, Train Acc: 0.6855, Val Loss: 0.9138, Val Acc: 0.6747
# Epoch 187/200: Train Loss: 0.7390, Train Acc: 0.6943, Val Loss: 0.9032, Val Acc: 0.6884
# Epoch 188/200: Train Loss: 0.7343, Train Acc: 0.7177, Val Loss: 0.9111, Val Acc: 0.6610
# Epoch 189/200: Train Loss: 0.7159, Train Acc: 0.7045, Val Loss: 0.9140, Val Acc: 0.6884
# Epoch 190/200: Train Loss: 0.7412, Train Acc: 0.6855, Val Loss: 0.9293, Val Acc: 0.6952
# Epoch 191/200: Train Loss: 0.7373, Train Acc: 0.7009, Val Loss: 0.9372, Val Acc: 0.7123
# Epoch 192/200: Train Loss: 0.7354, Train Acc: 0.7067, Val Loss: 0.9593, Val Acc: 0.7021
# Epoch 193/200: Train Loss: 0.7080, Train Acc: 0.7148, Val Loss: 0.9091, Val Acc: 0.6678
# Epoch 194/200: Train Loss: 0.7256, Train Acc: 0.7053, Val Loss: 0.9321, Val Acc: 0.6747
# Epoch 195/200: Train Loss: 0.7185, Train Acc: 0.7016, Val Loss: 0.9380, Val Acc: 0.7226
# Epoch 196/200: Train Loss: 0.7378, Train Acc: 0.7001, Val Loss: 0.9314, Val Acc: 0.6575
# Epoch 197/200: Train Loss: 0.7410, Train Acc: 0.6891, Val Loss: 0.9832, Val Acc: 0.7295
# Epoch 198/200: Train Loss: 0.7386, Train Acc: 0.7001, Val Loss: 0.9181, Val Acc: 0.6712
# Epoch 199/200: Train Loss: 0.7329, Train Acc: 0.7053, Val Loss: 0.9199, Val Acc: 0.7055
# Epoch 200/200: Train Loss: 0.7369, Train Acc: 0.6972, Val Loss: 0.9574, Val Acc: 0.7260

# %%
import matplotlib.pyplot as plt
import torch
def plot_training_history(history):
    epochs = range(1, len(history['train_loss']) + 1)


    train_losses = [x.cpu().numpy() if torch.is_tensor(x) else x for x in history['train_loss']]
    val_losses = [x.cpu().numpy() if torch.is_tensor(x) else x for x in history['val_loss']]
    train_accs = [x.cpu().numpy() if torch.is_tensor(x) else x for x in history['train_acc']]
    val_accs = [x.cpu().numpy() if torch.is_tensor(x) else x for x in history['val_acc']]

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.plot(epochs, val_losses, label='Validation Loss')
    plt.title('AlexNet Training and Validation Loss')
    plt.ylim(0, 1.5)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accs, label='Train Accuracy')
    plt.plot(epochs, val_accs, label='Validation Accuracy')
    plt.title('AlexNet Training and Validation Accuracy')
    plt.ylim(0, 1)
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()
plot_training_history(training_history)

# %% [markdown]
# # TEST

# %%
import os
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import copy
from sklearn.metrics import roc_auc_score, balanced_accuracy_score, recall_score, precision_score

class MineralDataset(Dataset):
    def __init__(self, img_dir, labels_csv, transform=None):
        self.dataframe = pd.read_csv(labels_csv)
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        file_name = row['Segmented Filename']
        label = row['Class']
        img_path = os.path.join(self.img_dir, file_name)
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label


transform_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


IMAGE_DIR = '/Mineral/CPX seg'
TEST_SPLIT_FILE = '/Mineral/test_split.csv'


test_dataset = MineralDataset(
    img_dir=IMAGE_DIR,
    labels_csv=TEST_SPLIT_FILE,
    transform=transform_test
)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


model = torch.load('/Mineral/Alex.path')
model.to(device)
criterion = torch.nn.CrossEntropyLoss()

def evaluate_model(model, data_loader, criterion, device):
    model.eval()  
    all_probs = []
    all_labels = []
    all_losses = []

    with torch.no_grad(): 
        for inputs, labels in data_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            probabilities = torch.softmax(outputs, dim=1)
            all_probs.append(probabilities.cpu().numpy())
            all_labels.append(labels.cpu().numpy())
            all_losses.append(loss.cpu().numpy())

    all_probs = np.concatenate(all_probs)
    all_labels = np.concatenate(all_labels)
    all_losses = np.array(all_losses)
    return all_probs, all_labels, all_losses

def bootstrap_metric(y_true, y_prob, metric_func, n_bootstrap=1000, alpha=0.05, **kwargs):
    rng = np.random.default_rng()
    indices = np.arange(len(y_true))
    bootstrapped_scores = []
    for _ in range(n_bootstrap):
        sample_indices = rng.choice(indices, size=len(indices), replace=True)
        if metric_func == roc_auc_score:
            score = metric_func(y_true[sample_indices], y_prob[sample_indices], **kwargs)
        else:
            y_pred = np.argmax(y_prob[sample_indices], axis=1)
            score = metric_func(y_true[sample_indices], y_pred, **kwargs)
        bootstrapped_scores.append(score)
    sorted_scores = np.sort(bootstrapped_scores)
    ci_lower = sorted_scores[int((alpha/2) * n_bootstrap)]
    ci_upper = sorted_scores[int((1 - alpha/2) * n_bootstrap)]
    return np.mean(bootstrapped_scores), ci_lower, ci_upper

def bootstrap_loss(losses, n_bootstrap=1000, alpha=0.05):
    rng = np.random.default_rng()
    indices = np.arange(len(losses))
    bootstrapped_losses = []
    for _ in range(n_bootstrap):
        sample_indices = rng.choice(indices, size=len(indices), replace=True)
        sample_loss = losses[sample_indices]
        bootstrapped_losses.append(np.mean(sample_loss))
    sorted_losses = np.sort(bootstrapped_losses)
    ci_lower = sorted_losses[int((alpha/2) * n_bootstrap)]
    ci_upper = sorted_losses[int((1 - alpha/2) * n_bootstrap)]
    return np.mean(bootstrapped_losses), ci_lower, ci_upper

test_probs, test_labels, test_losses = evaluate_model(model, test_loader, criterion, device)


class_labels = np.unique(test_labels)
metrics = {}
for class_label in class_labels:
    auc_roc_mean, auc_roc_ci_low, auc_roc_ci_high = bootstrap_metric(test_labels == class_label, test_probs[:, class_label], roc_auc_score)
    balanced_acc_mean, balanced_acc_ci_low, balanced_acc_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: balanced_accuracy_score(y_true == class_label, y_pred == class_label))
    sensitivity_mean, sensitivity_ci_low, sensitivity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: recall_score(y_true == class_label, y_pred == class_label, zero_division=0))
    specificity_mean, specificity_ci_low, specificity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: precision_score(y_true == class_label, y_pred == class_label, zero_division=0))

    metrics[class_label] = {
        "AUC-ROC": (auc_roc_mean, auc_roc_ci_low, auc_roc_ci_high),
        "Balanced Accuracy": (balanced_acc_mean, balanced_acc_ci_low, balanced_acc_ci_high),
        "Sensitivity": (sensitivity_mean, sensitivity_ci_low, sensitivity_ci_high),
        "Specificity": (specificity_mean, specificity_ci_low, specificity_ci_high)
    }


print("Class\t\tAUC-ROC\t\t\tBalanced Accuracy\tSensitivity\t\tSpecificity")
for class_label, metric_values in metrics.items():
    auc_roc = metric_values["AUC-ROC"]
    balanced_acc = metric_values["Balanced Accuracy"]
    sensitivity = metric_values["Sensitivity"]
    specificity = metric_values["Specificity"]
    print(f"{class_label}\t\t{auc_roc[0]:.2f} ({auc_roc[1]:.2f}-{auc_roc[2]:.2f})\t"
          f"{balanced_acc[0]:.2f} ({balanced_acc[1]:.2f}-{balanced_acc[2]:.2f})\t"
          f"{sensitivity[0]:.2f} ({sensitivity[1]:.2f}-{sensitivity[2]:.2f})\t"
          f"{specificity[0]:.2f} ({specificity[1]:.2f}-{specificity[2]:.2f})")

auc_roc_mean, auc_roc_ci_low, auc_roc_ci_high = bootstrap_metric(test_labels, test_probs, roc_auc_score, multi_class='ovr')
balanced_acc_mean, balanced_acc_ci_low, balanced_acc_ci_high = bootstrap_metric(test_labels, test_probs, balanced_accuracy_score)
sensitivity_mean, sensitivity_ci_low, sensitivity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: recall_score(y_true, y_pred, average='macro', zero_division=0))
specificity_mean, specificity_ci_low, specificity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: precision_score(y_true, y_pred, average='macro', zero_division=0))

loss_mean, loss_ci_low, loss_ci_high = bootstrap_loss(test_losses)

print(f"Overall\t\t{auc_roc_mean:.2f} ({auc_roc_ci_low:.2f}-{auc_roc_ci_high:.2f})\t"
      f"{balanced_acc_mean:.2f} ({balanced_acc_ci_low:.2f}-{balanced_acc_ci_high:.2f})\t"
      f"{sensitivity_mean:.2f} ({sensitivity_ci_low:.2f}-{sensitivity_ci_high:.2f})\t"
      f"{specificity_mean:.2f} ({specificity_ci_low:.2f}-{specificity_ci_high:.2f})")
print(f"Loss\t\t{loss_mean:.4f} ({loss_ci_low:.4f}-{loss_ci_high:.4f})")
# Out:
# Class		AUC-ROC			Balanced Accuracy	Sensitivity		Specificity
# 0		0.89 (0.85-0.93)	0.75 (0.70-0.80)	0.57 (0.48-0.68)	0.79 (0.69-0.88)
# 1		0.85 (0.81-0.90)	0.75 (0.70-0.80)	0.87 (0.82-0.92)	0.76 (0.70-0.82)
# 2		0.71 (0.61-0.81)	0.60 (0.52-0.71)	0.30 (0.12-0.48)	0.27 (0.11-0.42)
# Overall		0.82 (0.77-0.86)	0.58 (0.52-0.65)	0.58 (0.51-0.65)	0.61 (0.54-0.68)
# Loss		0.6792 (0.6133-0.7394)

# %%
import torch
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

def get_predictions_and_labels(model, test_loader, device):

    predictions = []
    labels = []
    with torch.no_grad():
        for inputs, actuals in test_loader:
            inputs = inputs.to(device)
            actuals = actuals.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            predictions.extend(preds.cpu().numpy())
            labels.extend(actuals.cpu().numpy())
    return predictions, labels

test_predictions, test_labels = get_predictions_and_labels(model, test_loader, device)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

test_predictions, test_labels = get_predictions_and_labels(model, test_loader, device)

cm = confusion_matrix(test_labels, test_predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title('AlexNet Confusion Matrix')
plt.show()

print(classification_report(test_labels, test_predictions, target_names=['Class 0', 'Class 1', 'Class 2']))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.57      0.67        96
#      Class 1       0.76      0.87      0.81       170
#      Class 2       0.27      0.30      0.28        27
#
#     accuracy                           0.72       293
#    macro avg       0.61      0.58      0.59       293
# weighted avg       0.73      0.72      0.72       293

# %%
def evaluate(model, data_loader, criterion, device):

    total = 0
    total_loss = 0.0
    all_probs = []  
    all_labels = [] 

    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item() * inputs.size(0)
            probs = torch.nn.functional.softmax(outputs, dim=1)
            all_probs.append(probs.cpu())
            all_labels.extend(labels.cpu())
            total += labels.size(0)

    average_loss = total_loss / total
    return average_loss, torch.cat(all_probs).numpy(), np.array(all_labels)


from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt

def plot_multiclass_roc(y_test, y_score, n_classes, figsize=(6, 4)):
    # Binarize the output
    y_test = label_binarize(y_test, classes=[*range(n_classes)])
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

   
    plt.figure(figsize=figsize)
    for i in range(n_classes):
        plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} ROC curve (area = {roc_auc[i]:.2f})')

    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('AlexNet')
    plt.legend(loc="lower right")
    plt.show()

test_loss, probs, true_labels = evaluate(model, test_loader, criterion, device)


n_classes = 3
plot_multiclass_roc(true_labels, probs, n_classes)

# %%
def get_predictions(model, data_loader, device):

    all_probs = []

    with torch.no_grad():
        for inputs, _ in data_loader:
            inputs = inputs.to(device)
            outputs = model(inputs)
            probs = torch.nn.functional.softmax(outputs, dim=1)
            all_probs.extend(probs.cpu().numpy())
    return np.array(all_probs)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_prediction_histograms(probs, num_classes):
    plt.figure(figsize=(6, 4))

    
    cmap = plt.get_cmap('viridis')
    colors = [cmap(i) for i in np.linspace(0, 0.8, num_classes)]

    for i in range(num_classes):
        plt.hist(probs[:, i], bins=30, alpha=0.5, label=f'Class {i}', color=colors[i])
        
    plt.title('AlexNet Prediction Probability Distribution')
    plt.xlabel('Probability')
    plt.ylabel('Frequency')
    plt.legend()
    plt.ylim(0, 100)
    plt.show()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
test_probs = get_predictions(model, test_loader, device)
num_classes = 3
plot_prediction_histograms(test_probs, num_classes)
