# %% [markdown]
# # Training

# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from torch.utils.data import Dataset

class MineralDataset(Dataset):
    def __init__(self, img_dir_fe, img_dir_ca, img_dir_mg, labels_csv, transform=None):
        self.dataframe = pd.read_csv(labels_csv)
        self.img_dir_fe = img_dir_fe
        self.img_dir_ca = img_dir_ca
        self.img_dir_mg = img_dir_mg
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        file_name = row['Segmented Filename']
        label = row['Class']
        img_fe = Image.open(os.path.join(self.img_dir_fe, file_name)).convert('L')
        img_ca = Image.open(os.path.join(self.img_dir_ca, file_name)).convert('L')
        img_mg = Image.open(os.path.join(self.img_dir_mg, file_name)).convert('L')
        img_combined = Image.merge('RGB', (img_fe, img_ca, img_mg))
        if self.transform:
            img_combined = self.transform(img_combined)
        return img_combined, label
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(), 
    transforms.RandomRotation(10),      
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transform_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
dataset_train = MineralDataset(
    img_dir_fe='/Mineral/Enhanced-Al-S',
    img_dir_ca='/Mineral/Ca-S',
    img_dir_mg='/Mineral/Enhanced-Fe-S',
    labels_csv='/Mineral/train_split.csv',  
    transform=transform_train
)

dataset_val = MineralDataset(
    img_dir_fe='/Mineral/Enhanced-Al-S',
    img_dir_ca='/Mineral/Ca-S',
    img_dir_mg='/Mineral/Enhanced-Fe-S',
    labels_csv='/Mineral/val_split.csv',
    transform=transform_test
)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import matplotlib.pyplot as plt
import copy

resnet34 = models.resnet34(pretrained=True)
for param in resnet34.parameters():
    param.requires_grad = False

num_classes = 3  
num_ftrs = resnet34.fc.in_features
resnet34.fc = nn.Linear(num_ftrs, num_classes)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
resnet34 = resnet34.to(device)

labels = [label for _, label in dataset_train]  
class_weights = compute_class_weight('balanced', classes=np.unique(labels), y=labels)
class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(resnet34.fc.parameters(), lr=0.0001)

def train_and_evaluate_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=200, device='cuda'):
    model.to(device)
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

    for epoch in range(num_epochs):
        
        model.train()
        train_loss = 0.0
        train_corrects = 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            train_corrects += torch.sum(preds == labels.data)

        train_loss /= len(train_loader.dataset)
        train_acc = train_corrects.double() / len(train_loader.dataset)
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)

        model.eval()
        val_loss = 0.0
        val_corrects = 0
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            with torch.no_grad():
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                _, preds = torch.max(outputs, 1)
                val_corrects += torch.sum(preds == labels.data)

        val_loss /= len(val_loader.dataset)
        val_acc = val_corrects.double() / len(val_loader.dataset)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)

        print(f'Epoch {epoch+1}/{num_epochs} - Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')

        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = copy.deepcopy(model.state_dict())

    model.load_state_dict(best_model_wts)
    return model, history

train_loader = DataLoader(dataset_train, batch_size=32, shuffle=True)
val_loader = DataLoader(dataset_val, batch_size=32, shuffle=False)
trained_model, training_history = train_and_evaluate_model(resnet34, train_loader, val_loader, criterion, optimizer, num_epochs=200, device=device)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/200 - Train Loss: 1.1397, Train Acc: 0.3805, Val Loss: 1.1017, Val Acc: 0.5068
# Epoch 2/200 - Train Loss: 1.0749, Train Acc: 0.5088, Val Loss: 1.0610, Val Acc: 0.5171
# Epoch 3/200 - Train Loss: 1.0166, Train Acc: 0.5337, Val Loss: 1.0210, Val Acc: 0.5856
# Epoch 4/200 - Train Loss: 0.9828, Train Acc: 0.5733, Val Loss: 0.9907, Val Acc: 0.6199
# Epoch 5/200 - Train Loss: 0.9574, Train Acc: 0.6012, Val Loss: 0.9693, Val Acc: 0.6610
# Epoch 6/200 - Train Loss: 0.9273, Train Acc: 0.6283, Val Loss: 0.9486, Val Acc: 0.6712
# Epoch 7/200 - Train Loss: 0.9249, Train Acc: 0.6459, Val Loss: 0.9349, Val Acc: 0.6952
# Epoch 8/200 - Train Loss: 0.8848, Train Acc: 0.6657, Val Loss: 0.9175, Val Acc: 0.6781
# Epoch 9/200 - Train Loss: 0.8805, Train Acc: 0.6767, Val Loss: 0.9118, Val Acc: 0.7158
# Epoch 10/200 - Train Loss: 0.8649, Train Acc: 0.6738, Val Loss: 0.8988, Val Acc: 0.7123
# Epoch 11/200 - Train Loss: 0.8683, Train Acc: 0.6708, Val Loss: 0.8916, Val Acc: 0.7329
# Epoch 12/200 - Train Loss: 0.8317, Train Acc: 0.6921, Val Loss: 0.8854, Val Acc: 0.7363
# Epoch 13/200 - Train Loss: 0.8287, Train Acc: 0.6943, Val Loss: 0.8740, Val Acc: 0.7192
# Epoch 14/200 - Train Loss: 0.8411, Train Acc: 0.6789, Val Loss: 0.8704, Val Acc: 0.7260
# Epoch 15/200 - Train Loss: 0.8060, Train Acc: 0.7009, Val Loss: 0.8603, Val Acc: 0.7295
# Epoch 16/200 - Train Loss: 0.8051, Train Acc: 0.7053, Val Loss: 0.8666, Val Acc: 0.7363
# Epoch 17/200 - Train Loss: 0.8162, Train Acc: 0.6796, Val Loss: 0.8539, Val Acc: 0.7295
# Epoch 18/200 - Train Loss: 0.8111, Train Acc: 0.7001, Val Loss: 0.8608, Val Acc: 0.7397
# Epoch 19/200 - Train Loss: 0.7967, Train Acc: 0.6943, Val Loss: 0.8503, Val Acc: 0.7295
# Epoch 20/200 - Train Loss: 0.7990, Train Acc: 0.7082, Val Loss: 0.8423, Val Acc: 0.7260
# Epoch 21/200 - Train Loss: 0.7799, Train Acc: 0.7170, Val Loss: 0.8395, Val Acc: 0.7432
# Epoch 22/200 - Train Loss: 0.7747, Train Acc: 0.7155, Val Loss: 0.8452, Val Acc: 0.7260
# Epoch 23/200 - Train Loss: 0.7973, Train Acc: 0.6730, Val Loss: 0.8385, Val Acc: 0.7363
# Epoch 24/200 - Train Loss: 0.7782, Train Acc: 0.6994, Val Loss: 0.8359, Val Acc: 0.7363
# Epoch 25/200 - Train Loss: 0.7657, Train Acc: 0.7251, Val Loss: 0.8327, Val Acc: 0.7329
# Epoch 26/200 - Train Loss: 0.7931, Train Acc: 0.7075, Val Loss: 0.8275, Val Acc: 0.7397
# Epoch 27/200 - Train Loss: 0.7494, Train Acc: 0.7199, Val Loss: 0.8287, Val Acc: 0.7363
# Epoch 28/200 - Train Loss: 0.7615, Train Acc: 0.7089, Val Loss: 0.8321, Val Acc: 0.7500
# Epoch 29/200 - Train Loss: 0.7515, Train Acc: 0.7207, Val Loss: 0.8203, Val Acc: 0.7329
# Epoch 30/200 - Train Loss: 0.7411, Train Acc: 0.7060, Val Loss: 0.8226, Val Acc: 0.7295
# Epoch 31/200 - Train Loss: 0.7468, Train Acc: 0.7280, Val Loss: 0.8221, Val Acc: 0.7363
# Epoch 32/200 - Train Loss: 0.7426, Train Acc: 0.7258, Val Loss: 0.8158, Val Acc: 0.7158
# Epoch 33/200 - Train Loss: 0.7380, Train Acc: 0.7177, Val Loss: 0.8216, Val Acc: 0.7363
# Epoch 34/200 - Train Loss: 0.7532, Train Acc: 0.7221, Val Loss: 0.8193, Val Acc: 0.7363
# Epoch 35/200 - Train Loss: 0.7374, Train Acc: 0.7251, Val Loss: 0.8163, Val Acc: 0.7295
# Epoch 36/200 - Train Loss: 0.7357, Train Acc: 0.7295, Val Loss: 0.8153, Val Acc: 0.7158
# Epoch 37/200 - Train Loss: 0.7377, Train Acc: 0.7133, Val Loss: 0.8151, Val Acc: 0.7329
# Epoch 38/200 - Train Loss: 0.7259, Train Acc: 0.7441, Val Loss: 0.8168, Val Acc: 0.7329
# Epoch 39/200 - Train Loss: 0.7248, Train Acc: 0.7368, Val Loss: 0.8149, Val Acc: 0.7226
# Epoch 40/200 - Train Loss: 0.7254, Train Acc: 0.7229, Val Loss: 0.8089, Val Acc: 0.7226
# Epoch 41/200 - Train Loss: 0.7170, Train Acc: 0.7155, Val Loss: 0.8151, Val Acc: 0.7466
# Epoch 42/200 - Train Loss: 0.7091, Train Acc: 0.7346, Val Loss: 0.8102, Val Acc: 0.7363
# Epoch 43/200 - Train Loss: 0.7167, Train Acc: 0.7258, Val Loss: 0.8134, Val Acc: 0.7397
# Epoch 44/200 - Train Loss: 0.7106, Train Acc: 0.7185, Val Loss: 0.8110, Val Acc: 0.7363
# Epoch 45/200 - Train Loss: 0.7054, Train Acc: 0.7361, Val Loss: 0.8106, Val Acc: 0.7397
# Epoch 46/200 - Train Loss: 0.7018, Train Acc: 0.7375, Val Loss: 0.8017, Val Acc: 0.7226
# Epoch 47/200 - Train Loss: 0.7101, Train Acc: 0.7126, Val Loss: 0.8100, Val Acc: 0.7397
# Epoch 48/200 - Train Loss: 0.7064, Train Acc: 0.7471, Val Loss: 0.8123, Val Acc: 0.7363
# Epoch 49/200 - Train Loss: 0.7028, Train Acc: 0.7507, Val Loss: 0.8070, Val Acc: 0.7363
# Epoch 50/200 - Train Loss: 0.6840, Train Acc: 0.7412, Val Loss: 0.8051, Val Acc: 0.7397
# Epoch 51/200 - Train Loss: 0.6918, Train Acc: 0.7339, Val Loss: 0.8063, Val Acc: 0.7397
# Epoch 52/200 - Train Loss: 0.7038, Train Acc: 0.7397, Val Loss: 0.8109, Val Acc: 0.7397
# Epoch 53/200 - Train Loss: 0.6954, Train Acc: 0.7493, Val Loss: 0.7946, Val Acc: 0.7295
# Epoch 54/200 - Train Loss: 0.6983, Train Acc: 0.7243, Val Loss: 0.8064, Val Acc: 0.7397
# Epoch 55/200 - Train Loss: 0.6772, Train Acc: 0.7258, Val Loss: 0.8077, Val Acc: 0.7397
# Epoch 56/200 - Train Loss: 0.6721, Train Acc: 0.7449, Val Loss: 0.8049, Val Acc: 0.7260
# Epoch 57/200 - Train Loss: 0.6678, Train Acc: 0.7610, Val Loss: 0.8022, Val Acc: 0.7329
# Epoch 58/200 - Train Loss: 0.7011, Train Acc: 0.7353, Val Loss: 0.8038, Val Acc: 0.7466
# Epoch 59/200 - Train Loss: 0.6877, Train Acc: 0.7456, Val Loss: 0.8004, Val Acc: 0.7260
# Epoch 60/200 - Train Loss: 0.6962, Train Acc: 0.7339, Val Loss: 0.8036, Val Acc: 0.7329
# Epoch 61/200 - Train Loss: 0.7073, Train Acc: 0.7419, Val Loss: 0.7981, Val Acc: 0.7329
# Epoch 62/200 - Train Loss: 0.6946, Train Acc: 0.7361, Val Loss: 0.7919, Val Acc: 0.7226
# Epoch 63/200 - Train Loss: 0.6918, Train Acc: 0.7485, Val Loss: 0.7989, Val Acc: 0.7466
# Epoch 64/200 - Train Loss: 0.6863, Train Acc: 0.7434, Val Loss: 0.7922, Val Acc: 0.7397
# Epoch 65/200 - Train Loss: 0.6814, Train Acc: 0.7456, Val Loss: 0.7974, Val Acc: 0.7363
# Epoch 66/200 - Train Loss: 0.6993, Train Acc: 0.7449, Val Loss: 0.8082, Val Acc: 0.7534
# Epoch 67/200 - Train Loss: 0.6803, Train Acc: 0.7639, Val Loss: 0.7869, Val Acc: 0.7363
# Epoch 68/200 - Train Loss: 0.6896, Train Acc: 0.7251, Val Loss: 0.7979, Val Acc: 0.7329
# Epoch 69/200 - Train Loss: 0.6885, Train Acc: 0.7383, Val Loss: 0.7982, Val Acc: 0.7329
# Epoch 70/200 - Train Loss: 0.6826, Train Acc: 0.7353, Val Loss: 0.7953, Val Acc: 0.7295
# Epoch 71/200 - Train Loss: 0.6807, Train Acc: 0.7302, Val Loss: 0.8044, Val Acc: 0.7637
# Epoch 72/200 - Train Loss: 0.6800, Train Acc: 0.7764, Val Loss: 0.7911, Val Acc: 0.7397
# Epoch 73/200 - Train Loss: 0.6660, Train Acc: 0.7346, Val Loss: 0.7978, Val Acc: 0.7397
# Epoch 74/200 - Train Loss: 0.6635, Train Acc: 0.7544, Val Loss: 0.7990, Val Acc: 0.7432
# Epoch 75/200 - Train Loss: 0.6613, Train Acc: 0.7610, Val Loss: 0.8001, Val Acc: 0.7432
# Epoch 76/200 - Train Loss: 0.6818, Train Acc: 0.7500, Val Loss: 0.7977, Val Acc: 0.7432
# Epoch 77/200 - Train Loss: 0.6864, Train Acc: 0.7397, Val Loss: 0.7936, Val Acc: 0.7397
# Epoch 78/200 - Train Loss: 0.6771, Train Acc: 0.7456, Val Loss: 0.7975, Val Acc: 0.7397
# Epoch 79/200 - Train Loss: 0.6724, Train Acc: 0.7529, Val Loss: 0.7940, Val Acc: 0.7500
# Epoch 80/200 - Train Loss: 0.6435, Train Acc: 0.7625, Val Loss: 0.8004, Val Acc: 0.7500
# Epoch 81/200 - Train Loss: 0.6698, Train Acc: 0.7654, Val Loss: 0.7980, Val Acc: 0.7466
# Epoch 82/200 - Train Loss: 0.6649, Train Acc: 0.7434, Val Loss: 0.8082, Val Acc: 0.7568
# Epoch 83/200 - Train Loss: 0.6671, Train Acc: 0.7610, Val Loss: 0.7967, Val Acc: 0.7534
# Epoch 84/200 - Train Loss: 0.6674, Train Acc: 0.7757, Val Loss: 0.7911, Val Acc: 0.7534
# Epoch 85/200 - Train Loss: 0.6655, Train Acc: 0.7375, Val Loss: 0.7963, Val Acc: 0.7295
# Epoch 86/200 - Train Loss: 0.6548, Train Acc: 0.7551, Val Loss: 0.7905, Val Acc: 0.7432
# Epoch 87/200 - Train Loss: 0.6551, Train Acc: 0.7573, Val Loss: 0.7910, Val Acc: 0.7500
# Epoch 88/200 - Train Loss: 0.6570, Train Acc: 0.7595, Val Loss: 0.8024, Val Acc: 0.7466
# Epoch 89/200 - Train Loss: 0.6482, Train Acc: 0.7456, Val Loss: 0.8133, Val Acc: 0.7637
# Epoch 90/200 - Train Loss: 0.6701, Train Acc: 0.7588, Val Loss: 0.7914, Val Acc: 0.7397
# Epoch 91/200 - Train Loss: 0.6528, Train Acc: 0.7537, Val Loss: 0.7928, Val Acc: 0.7397
# Epoch 92/200 - Train Loss: 0.6555, Train Acc: 0.7529, Val Loss: 0.7967, Val Acc: 0.7500
# Epoch 93/200 - Train Loss: 0.6639, Train Acc: 0.7647, Val Loss: 0.7973, Val Acc: 0.7260
# Epoch 94/200 - Train Loss: 0.6648, Train Acc: 0.7463, Val Loss: 0.7976, Val Acc: 0.7432
# Epoch 95/200 - Train Loss: 0.6505, Train Acc: 0.7654, Val Loss: 0.7951, Val Acc: 0.7432
# Epoch 96/200 - Train Loss: 0.6451, Train Acc: 0.7507, Val Loss: 0.8038, Val Acc: 0.7534
# Epoch 97/200 - Train Loss: 0.6481, Train Acc: 0.7647, Val Loss: 0.7998, Val Acc: 0.7534
# Epoch 98/200 - Train Loss: 0.6365, Train Acc: 0.7617, Val Loss: 0.7928, Val Acc: 0.7432
# Epoch 99/200 - Train Loss: 0.6547, Train Acc: 0.7529, Val Loss: 0.7875, Val Acc: 0.7363
# Epoch 100/200 - Train Loss: 0.6486, Train Acc: 0.7581, Val Loss: 0.7952, Val Acc: 0.7534
# Epoch 101/200 - Train Loss: 0.6587, Train Acc: 0.7588, Val Loss: 0.7854, Val Acc: 0.7466
# Epoch 102/200 - Train Loss: 0.6444, Train Acc: 0.7683, Val Loss: 0.7907, Val Acc: 0.7534
# Epoch 103/200 - Train Loss: 0.6511, Train Acc: 0.7441, Val Loss: 0.7896, Val Acc: 0.7568
# Epoch 104/200 - Train Loss: 0.6288, Train Acc: 0.7742, Val Loss: 0.7854, Val Acc: 0.7500
# Epoch 105/200 - Train Loss: 0.6439, Train Acc: 0.7463, Val Loss: 0.7984, Val Acc: 0.7671
# Epoch 106/200 - Train Loss: 0.6662, Train Acc: 0.7544, Val Loss: 0.7880, Val Acc: 0.7363
# Epoch 107/200 - Train Loss: 0.6403, Train Acc: 0.7515, Val Loss: 0.7993, Val Acc: 0.7637
# Epoch 108/200 - Train Loss: 0.6490, Train Acc: 0.7559, Val Loss: 0.7837, Val Acc: 0.7466
# Epoch 109/200 - Train Loss: 0.6229, Train Acc: 0.7698, Val Loss: 0.7911, Val Acc: 0.7466
# Epoch 110/200 - Train Loss: 0.6429, Train Acc: 0.7559, Val Loss: 0.7934, Val Acc: 0.7432
# Epoch 111/200 - Train Loss: 0.6423, Train Acc: 0.7588, Val Loss: 0.7946, Val Acc: 0.7397
# Epoch 112/200 - Train Loss: 0.6524, Train Acc: 0.7625, Val Loss: 0.7884, Val Acc: 0.7534
# Epoch 113/200 - Train Loss: 0.6313, Train Acc: 0.7603, Val Loss: 0.7903, Val Acc: 0.7500
# Epoch 114/200 - Train Loss: 0.6420, Train Acc: 0.7456, Val Loss: 0.7977, Val Acc: 0.7671
# Epoch 115/200 - Train Loss: 0.6354, Train Acc: 0.7713, Val Loss: 0.7872, Val Acc: 0.7637
# Epoch 116/200 - Train Loss: 0.6279, Train Acc: 0.7639, Val Loss: 0.7882, Val Acc: 0.7568
# Epoch 117/200 - Train Loss: 0.6329, Train Acc: 0.7566, Val Loss: 0.7846, Val Acc: 0.7603
# Epoch 118/200 - Train Loss: 0.6302, Train Acc: 0.7434, Val Loss: 0.7941, Val Acc: 0.7671
# Epoch 119/200 - Train Loss: 0.6453, Train Acc: 0.7676, Val Loss: 0.7900, Val Acc: 0.7637
# Epoch 120/200 - Train Loss: 0.6420, Train Acc: 0.7603, Val Loss: 0.7845, Val Acc: 0.7226
# Epoch 121/200 - Train Loss: 0.6176, Train Acc: 0.7786, Val Loss: 0.8011, Val Acc: 0.7671
# Epoch 122/200 - Train Loss: 0.6400, Train Acc: 0.7507, Val Loss: 0.8002, Val Acc: 0.7671
# Epoch 123/200 - Train Loss: 0.6141, Train Acc: 0.7683, Val Loss: 0.7936, Val Acc: 0.7500
# Epoch 124/200 - Train Loss: 0.6346, Train Acc: 0.7544, Val Loss: 0.7988, Val Acc: 0.7568
# Epoch 125/200 - Train Loss: 0.6268, Train Acc: 0.7705, Val Loss: 0.7955, Val Acc: 0.7466
# Epoch 126/200 - Train Loss: 0.6334, Train Acc: 0.7676, Val Loss: 0.7878, Val Acc: 0.7363
# Epoch 127/200 - Train Loss: 0.6286, Train Acc: 0.7639, Val Loss: 0.7916, Val Acc: 0.7603
# Epoch 128/200 - Train Loss: 0.6219, Train Acc: 0.7566, Val Loss: 0.7963, Val Acc: 0.7671
# Epoch 129/200 - Train Loss: 0.6149, Train Acc: 0.7698, Val Loss: 0.7972, Val Acc: 0.7671
# Epoch 130/200 - Train Loss: 0.6390, Train Acc: 0.7617, Val Loss: 0.7864, Val Acc: 0.7466
# Epoch 131/200 - Train Loss: 0.6385, Train Acc: 0.7419, Val Loss: 0.7839, Val Acc: 0.7534
# Epoch 132/200 - Train Loss: 0.6393, Train Acc: 0.7537, Val Loss: 0.7881, Val Acc: 0.7397
# Epoch 133/200 - Train Loss: 0.6196, Train Acc: 0.7793, Val Loss: 0.7788, Val Acc: 0.7500
# Epoch 134/200 - Train Loss: 0.6342, Train Acc: 0.7632, Val Loss: 0.7913, Val Acc: 0.7671
# Epoch 135/200 - Train Loss: 0.6173, Train Acc: 0.7544, Val Loss: 0.7952, Val Acc: 0.7603
# Epoch 136/200 - Train Loss: 0.6325, Train Acc: 0.7625, Val Loss: 0.7887, Val Acc: 0.7568
# Epoch 137/200 - Train Loss: 0.6178, Train Acc: 0.7727, Val Loss: 0.7750, Val Acc: 0.7295
# Epoch 138/200 - Train Loss: 0.6153, Train Acc: 0.7625, Val Loss: 0.7985, Val Acc: 0.7637
# Epoch 139/200 - Train Loss: 0.6222, Train Acc: 0.7859, Val Loss: 0.7961, Val Acc: 0.7637
# Epoch 140/200 - Train Loss: 0.6411, Train Acc: 0.7559, Val Loss: 0.7876, Val Acc: 0.7260
# Epoch 141/200 - Train Loss: 0.6153, Train Acc: 0.7683, Val Loss: 0.7855, Val Acc: 0.7637
# Epoch 142/200 - Train Loss: 0.6110, Train Acc: 0.7669, Val Loss: 0.7844, Val Acc: 0.7603
# Epoch 143/200 - Train Loss: 0.6333, Train Acc: 0.7771, Val Loss: 0.7922, Val Acc: 0.7534
# Epoch 144/200 - Train Loss: 0.6253, Train Acc: 0.7639, Val Loss: 0.7882, Val Acc: 0.7466
# Epoch 145/200 - Train Loss: 0.5960, Train Acc: 0.7881, Val Loss: 0.7939, Val Acc: 0.7432
# Epoch 146/200 - Train Loss: 0.6238, Train Acc: 0.7808, Val Loss: 0.7849, Val Acc: 0.7534
# Epoch 147/200 - Train Loss: 0.6170, Train Acc: 0.7654, Val Loss: 0.7944, Val Acc: 0.7466
# Epoch 148/200 - Train Loss: 0.6191, Train Acc: 0.7845, Val Loss: 0.7882, Val Acc: 0.7603
# Epoch 149/200 - Train Loss: 0.6062, Train Acc: 0.7639, Val Loss: 0.7906, Val Acc: 0.7466
# Epoch 150/200 - Train Loss: 0.6068, Train Acc: 0.7757, Val Loss: 0.7886, Val Acc: 0.7568
# Epoch 151/200 - Train Loss: 0.6198, Train Acc: 0.7720, Val Loss: 0.7871, Val Acc: 0.7260
# Epoch 152/200 - Train Loss: 0.6116, Train Acc: 0.7786, Val Loss: 0.7916, Val Acc: 0.7466
# Epoch 153/200 - Train Loss: 0.6091, Train Acc: 0.7801, Val Loss: 0.7948, Val Acc: 0.7534
# Epoch 154/200 - Train Loss: 0.6286, Train Acc: 0.7654, Val Loss: 0.7871, Val Acc: 0.7637
# Epoch 155/200 - Train Loss: 0.6077, Train Acc: 0.7691, Val Loss: 0.7827, Val Acc: 0.7534
# Epoch 156/200 - Train Loss: 0.6191, Train Acc: 0.7632, Val Loss: 0.7862, Val Acc: 0.7534
# Epoch 157/200 - Train Loss: 0.6247, Train Acc: 0.7551, Val Loss: 0.7990, Val Acc: 0.7603
# Epoch 158/200 - Train Loss: 0.6362, Train Acc: 0.7573, Val Loss: 0.7982, Val Acc: 0.7603
# Epoch 159/200 - Train Loss: 0.6071, Train Acc: 0.7881, Val Loss: 0.7838, Val Acc: 0.7260
# Epoch 160/200 - Train Loss: 0.6143, Train Acc: 0.7617, Val Loss: 0.7870, Val Acc: 0.7466
# Epoch 161/200 - Train Loss: 0.6046, Train Acc: 0.7588, Val Loss: 0.7956, Val Acc: 0.7637
# Epoch 162/200 - Train Loss: 0.5988, Train Acc: 0.7918, Val Loss: 0.7875, Val Acc: 0.7568
# Epoch 163/200 - Train Loss: 0.6341, Train Acc: 0.7639, Val Loss: 0.7868, Val Acc: 0.7432
# Epoch 164/200 - Train Loss: 0.6054, Train Acc: 0.7933, Val Loss: 0.7880, Val Acc: 0.7534
# Epoch 165/200 - Train Loss: 0.6261, Train Acc: 0.7581, Val Loss: 0.7879, Val Acc: 0.7226
# Epoch 166/200 - Train Loss: 0.5959, Train Acc: 0.7676, Val Loss: 0.7971, Val Acc: 0.7705
# Epoch 167/200 - Train Loss: 0.5905, Train Acc: 0.7683, Val Loss: 0.7969, Val Acc: 0.7740
# Epoch 168/200 - Train Loss: 0.6186, Train Acc: 0.7830, Val Loss: 0.7867, Val Acc: 0.7466
# Epoch 169/200 - Train Loss: 0.6094, Train Acc: 0.7720, Val Loss: 0.7858, Val Acc: 0.7603
# Epoch 170/200 - Train Loss: 0.6223, Train Acc: 0.7632, Val Loss: 0.7955, Val Acc: 0.7500
# Epoch 171/200 - Train Loss: 0.6333, Train Acc: 0.7375, Val Loss: 0.7921, Val Acc: 0.7432
# Epoch 172/200 - Train Loss: 0.6122, Train Acc: 0.7742, Val Loss: 0.8016, Val Acc: 0.7740
# Epoch 173/200 - Train Loss: 0.6102, Train Acc: 0.7742, Val Loss: 0.7891, Val Acc: 0.7637
# Epoch 174/200 - Train Loss: 0.5985, Train Acc: 0.7705, Val Loss: 0.7932, Val Acc: 0.7603
# Epoch 175/200 - Train Loss: 0.6097, Train Acc: 0.7698, Val Loss: 0.7914, Val Acc: 0.7363
# Epoch 176/200 - Train Loss: 0.6162, Train Acc: 0.7581, Val Loss: 0.7947, Val Acc: 0.7534
# Epoch 177/200 - Train Loss: 0.6095, Train Acc: 0.7705, Val Loss: 0.7916, Val Acc: 0.7226
# Epoch 178/200 - Train Loss: 0.6149, Train Acc: 0.7639, Val Loss: 0.8024, Val Acc: 0.7774
# Epoch 179/200 - Train Loss: 0.6041, Train Acc: 0.7727, Val Loss: 0.7893, Val Acc: 0.7466
# Epoch 180/200 - Train Loss: 0.5869, Train Acc: 0.7764, Val Loss: 0.7897, Val Acc: 0.7534
# Epoch 181/200 - Train Loss: 0.6009, Train Acc: 0.7977, Val Loss: 0.7867, Val Acc: 0.7432
# Epoch 182/200 - Train Loss: 0.5915, Train Acc: 0.7830, Val Loss: 0.7931, Val Acc: 0.7671
# Epoch 183/200 - Train Loss: 0.5761, Train Acc: 0.7808, Val Loss: 0.7954, Val Acc: 0.7466
# Epoch 184/200 - Train Loss: 0.6049, Train Acc: 0.7647, Val Loss: 0.8045, Val Acc: 0.7774
# Epoch 185/200 - Train Loss: 0.6040, Train Acc: 0.7859, Val Loss: 0.7978, Val Acc: 0.7740
# Epoch 186/200 - Train Loss: 0.6215, Train Acc: 0.7559, Val Loss: 0.8015, Val Acc: 0.7671
# Epoch 187/200 - Train Loss: 0.5909, Train Acc: 0.7764, Val Loss: 0.7848, Val Acc: 0.7329
# Epoch 188/200 - Train Loss: 0.6043, Train Acc: 0.7859, Val Loss: 0.7877, Val Acc: 0.7466
# Epoch 189/200 - Train Loss: 0.6224, Train Acc: 0.7669, Val Loss: 0.7897, Val Acc: 0.7397
# Epoch 190/200 - Train Loss: 0.5985, Train Acc: 0.7779, Val Loss: 0.8002, Val Acc: 0.7466
# Epoch 191/200 - Train Loss: 0.6039, Train Acc: 0.7720, Val Loss: 0.7942, Val Acc: 0.7603
# Epoch 192/200 - Train Loss: 0.6246, Train Acc: 0.7581, Val Loss: 0.8079, Val Acc: 0.7534
# Epoch 193/200 - Train Loss: 0.5966, Train Acc: 0.7625, Val Loss: 0.7813, Val Acc: 0.7500
# Epoch 194/200 - Train Loss: 0.6316, Train Acc: 0.7764, Val Loss: 0.7867, Val Acc: 0.7568
# Epoch 195/200 - Train Loss: 0.5814, Train Acc: 0.7749, Val Loss: 0.7882, Val Acc: 0.7466
# Epoch 196/200 - Train Loss: 0.5799, Train Acc: 0.7705, Val Loss: 0.8043, Val Acc: 0.7705
# Epoch 197/200 - Train Loss: 0.6006, Train Acc: 0.7801, Val Loss: 0.7732, Val Acc: 0.7568
# Epoch 198/200 - Train Loss: 0.6019, Train Acc: 0.7837, Val Loss: 0.7973, Val Acc: 0.7534
# Epoch 199/200 - Train Loss: 0.6102, Train Acc: 0.7632, Val Loss: 0.7943, Val Acc: 0.7603
# Epoch 200/200 - Train Loss: 0.6037, Train Acc: 0.7830, Val Loss: 0.7847, Val Acc: 0.7363

# %%
def plot_training_history(history):
    epochs = range(1, len(history['train_loss']) + 1)

    train_losses = [x.cpu().numpy() if torch.is_tensor(x) else x for x in history['train_loss']]
    val_losses = [x.cpu().numpy() if torch.is_tensor(x) else x for x in history['val_loss']]
    train_accs = [x.cpu().numpy() if torch.is_tensor(x) else x for x in history['train_acc']]
    val_accs = [x.cpu().numpy() if torch.is_tensor(x) else x for x in history['val_acc']]

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.plot(epochs, val_losses, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.ylim(0, 1.5)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accs, label='Train Accuracy')
    plt.plot(epochs, val_accs, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.ylim(0, 1)
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()
plot_training_history(training_history)

# %% [markdown]
# # TEST SET

# %%
import os
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import copy
from sklearn.metrics import roc_auc_score, balanced_accuracy_score, recall_score, precision_score


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = torch.load('/Mineral/E2.path')
model.to(device)
criterion = torch.nn.CrossEntropyLoss()


img_dir_fe='/Mineral/Enhanced-Al-S'
img_dir_ca = '/Mineral/Ca-S'
img_dir_mg='/Mineral/Enhanced-Fe-S'
test_csv = '/Mineral/test_split.csv'

test_dataset = MineralDataset(img_dir_fe, img_dir_ca, img_dir_mg, test_csv, transform=transform_test)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

def evaluate_model(model, data_loader, criterion, device):
    model.eval()  
    all_probs = []
    all_labels = []
    all_losses = []

    with torch.no_grad(): 
        for inputs, labels in data_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            probabilities = torch.softmax(outputs, dim=1)
            all_probs.append(probabilities.cpu().numpy())
            all_labels.append(labels.cpu().numpy())
            all_losses.append(loss.cpu().numpy())

    all_probs = np.concatenate(all_probs)
    all_labels = np.concatenate(all_labels)
    all_losses = np.array(all_losses)
    return all_probs, all_labels, all_losses

def bootstrap_metric(y_true, y_prob, metric_func, n_bootstrap=1000, alpha=0.05, **kwargs):
    rng = np.random.default_rng()
    indices = np.arange(len(y_true))
    bootstrapped_scores = []
    for _ in range(n_bootstrap):
        sample_indices = rng.choice(indices, size=len(indices), replace=True)
        if metric_func == roc_auc_score:
            score = metric_func(y_true[sample_indices], y_prob[sample_indices], **kwargs)
        else:
            y_pred = np.argmax(y_prob[sample_indices], axis=1)
            score = metric_func(y_true[sample_indices], y_pred, **kwargs)
        bootstrapped_scores.append(score)
    sorted_scores = np.sort(bootstrapped_scores)
    ci_lower = sorted_scores[int((alpha/2) * n_bootstrap)]
    ci_upper = sorted_scores[int((1 - alpha/2) * n_bootstrap)]
    return np.mean(bootstrapped_scores), ci_lower, ci_upper

def bootstrap_loss(losses, n_bootstrap=1000, alpha=0.05):
    rng = np.random.default_rng()
    indices = np.arange(len(losses))
    bootstrapped_losses = []
    for _ in range(n_bootstrap):
        sample_indices = rng.choice(indices, size=len(indices), replace=True)
        sample_loss = losses[sample_indices]
        bootstrapped_losses.append(np.mean(sample_loss))
    sorted_losses = np.sort(bootstrapped_losses)
    ci_lower = sorted_losses[int((alpha/2) * n_bootstrap)]
    ci_upper = sorted_losses[int((1 - alpha/2) * n_bootstrap)]
    return np.mean(bootstrapped_losses), ci_lower, ci_upper


test_probs, test_labels, test_losses = evaluate_model(model, test_loader, criterion, device)

class_labels = np.unique(test_labels)
metrics = {}
for class_label in class_labels:
    auc_roc_mean, auc_roc_ci_low, auc_roc_ci_high = bootstrap_metric(test_labels == class_label, test_probs[:, class_label], roc_auc_score)
    balanced_acc_mean, balanced_acc_ci_low, balanced_acc_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: balanced_accuracy_score(y_true == class_label, y_pred == class_label))
    sensitivity_mean, sensitivity_ci_low, sensitivity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: recall_score(y_true == class_label, y_pred == class_label, zero_division=0))
    specificity_mean, specificity_ci_low, specificity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: precision_score(y_true == class_label, y_pred == class_label, zero_division=0))

    metrics[class_label] = {
        "AUC-ROC": (auc_roc_mean, auc_roc_ci_low, auc_roc_ci_high),
        "Balanced Accuracy": (balanced_acc_mean, balanced_acc_ci_low, balanced_acc_ci_high),
        "Sensitivity": (sensitivity_mean, sensitivity_ci_low, sensitivity_ci_high),
        "Specificity": (specificity_mean, specificity_ci_low, specificity_ci_high)
    }

print("Class\t\tAUC-ROC\t\t\tBalanced Accuracy\tSensitivity\t\tSpecificity")
for class_label, metric_values in metrics.items():
    auc_roc = metric_values["AUC-ROC"]
    balanced_acc = metric_values["Balanced Accuracy"]
    sensitivity = metric_values["Sensitivity"]
    specificity = metric_values["Specificity"]
    print(f"{class_label}\t\t{auc_roc[0]:.2f} ({auc_roc[1]:.2f}-{auc_roc[2]:.2f})\t"
          f"{balanced_acc[0]:.2f} ({balanced_acc[1]:.2f}-{balanced_acc[2]:.2f})\t"
          f"{sensitivity[0]:.2f} ({sensitivity[1]:.2f}-{sensitivity[2]:.2f})\t"
          f"{specificity[0]:.2f} ({specificity[1]:.2f}-{specificity[2]:.2f})")

auc_roc_mean, auc_roc_ci_low, auc_roc_ci_high = bootstrap_metric(test_labels, test_probs, roc_auc_score, multi_class='ovr')
balanced_acc_mean, balanced_acc_ci_low, balanced_acc_ci_high = bootstrap_metric(test_labels, test_probs, balanced_accuracy_score)
sensitivity_mean, sensitivity_ci_low, sensitivity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: recall_score(y_true, y_pred, average='macro', zero_division=0))
specificity_mean, specificity_ci_low, specificity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: precision_score(y_true, y_pred, average='macro', zero_division=0))

loss_mean, loss_ci_low, loss_ci_high = bootstrap_loss(test_losses)

print(f"Overall\t\t{auc_roc_mean:.2f} ({auc_roc_ci_low:.2f}-{auc_roc_ci_high:.2f})\t"
      f"{balanced_acc_mean:.2f} ({balanced_acc_ci_low:.2f}-{balanced_acc_ci_high:.2f})\t"
      f"{sensitivity_mean:.2f} ({sensitivity_ci_low:.2f}-{sensitivity_ci_high:.2f})\t"
      f"{specificity_mean:.2f} ({specificity_ci_low:.2f}-{specificity_ci_high:.2f})")
print(f"Loss\t\t{loss_mean:.4f} ({loss_ci_low:.4f}-{loss_ci_high:.4f})")
# Out:
# Class		AUC-ROC			Balanced Accuracy	Sensitivity		Specificity
# 0		0.92 (0.89-0.95)	0.83 (0.79-0.88)	0.76 (0.67-0.85)	0.80 (0.72-0.88)
# 1		0.87 (0.83-0.92)	0.81 (0.77-0.86)	0.76 (0.70-0.82)	0.88 (0.83-0.93)
# 2		0.64 (0.51-0.76)	0.60 (0.51-0.70)	0.37 (0.17-0.55)	0.18 (0.08-0.29)
# Overall		0.81 (0.76-0.86)	0.63 (0.56-0.71)	0.63 (0.56-0.70)	0.62 (0.58-0.67)
# Loss		0.6900 (0.5969-0.7797)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

test_predictions, test_labels = get_predictions_and_labels(trained_model, test_loader, device)

cm = confusion_matrix(test_labels, test_predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

print(classification_report(test_labels, test_predictions, target_names=['Class 0', 'Class 1', 'Class 2']))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.76      0.78        96
#      Class 1       0.88      0.76      0.82       170
#      Class 2       0.18      0.37      0.24        27
#
#     accuracy                           0.73       293
#    macro avg       0.62      0.63      0.61       293
# weighted avg       0.79      0.73      0.75       293

# %%
import torch
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from itertools import cycle

def evaluate_model_for_roc(model, test_loader, device='cuda'):
    model.to(device)
    model.eval()

    all_preds_prob = []
    all_labels = []

    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        with torch.no_grad():
            outputs = model(inputs)
            probs = torch.nn.functional.softmax(outputs, dim=1)
            all_preds_prob.append(probs.cpu().numpy())
            all_labels.append(labels.cpu().numpy())

    all_preds_prob = np.concatenate(all_preds_prob)
    all_labels = np.concatenate(all_labels)

    return all_preds_prob, all_labels

num_classes = 3
all_preds_prob, all_labels = evaluate_model_for_roc(trained_model, test_loader, device=device)
all_labels_one_hot = label_binarize(all_labels, classes=[0, 1, 2])

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(all_labels_one_hot[:, i], all_preds_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

colors = cycle(['blue', 'red', 'green'])
for i, color in zip(range(num_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.2f})'.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-class ROC')
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt

def get_predictions(model, test_loader, device):
    model.eval() 
    predictions = []
    true_labels = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            outputs = model(inputs)
            probs = torch.nn.functional.softmax(outputs, dim=1)
            predictions.extend(probs.cpu().numpy())
            true_labels.extend(labels.cpu().numpy())

    return np.array(predictions), np.array(true_labels)

predictions, true_labels = get_predictions(trained_model, test_loader, device)

plt.figure(figsize=(6, 4))
bins = np.linspace(0, 1, 30)
for class_index in range(num_classes):
    plt.hist(predictions[:, class_index], bins=bins, alpha=0.5, label=f'Class {class_index}', density=True)
plt.title('Distribution of Predicted Probabilities')
plt.xlabel('Probability')
plt.ylabel('Density')
plt.legend()
plt.show()
