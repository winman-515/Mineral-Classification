# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from torch.utils.data import Dataset

class MineralDataset(Dataset):
    def __init__(self, img_dir_al, img_dir_mg, img_dir_fe, labels_csv, transform=None):
        self.dataframe = pd.read_csv(labels_csv)
        self.img_dir_al = img_dir_al
        self.img_dir_mg = img_dir_mg
        self.img_dir_fe = img_dir_fe
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        file_name = row['Segmented Filename']
        label = row['Class']
        img_fe = Image.open(os.path.join(self.img_dir_fe, file_name)).convert('L')
        img_al = Image.open(os.path.join(self.img_dir_al, file_name)).convert('L')
        img_mg = Image.open(os.path.join(self.img_dir_mg, file_name)).convert('L')
        img_combined = Image.merge('RGB', (img_fe, img_al, img_mg))
        if self.transform:
            img_combined = self.transform(img_combined)
        return img_combined, label
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),  
    transforms.RandomRotation(10),     
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transform_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
dataset_train = MineralDataset(
    img_dir_al='/Mineral/Enhanced-Al-S',
    img_dir_mg='/Mineral/Mg-S',
    img_dir_fe='/Mineral/Enhanced-Fe-S',
    labels_csv='/Mineral/train_split.csv', 
    transform=transform_train
)

dataset_val = MineralDataset(
    img_dir_al='/Mineral/Enhanced-Al-S',
    img_dir_mg='/Mineral/Mg-S',
    img_dir_fe='/Mineral/Enhanced-Fe-S',
    labels_csv='/Mineral/val_split.csv',
    transform=transform_test
)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import matplotlib.pyplot as plt
import copy

resnet34 = models.resnet34(pretrained=True)

for param in resnet34.parameters():
    param.requires_grad = False

num_classes = 3  
num_ftrs = resnet34.fc.in_features
resnet34.fc = nn.Linear(num_ftrs, num_classes)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
resnet34 = resnet34.to(device)

labels = [label for _, label in dataset_train]  
class_weights = compute_class_weight('balanced', classes=np.unique(labels), y=labels)
class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(resnet34.fc.parameters(), lr=0.0001)  


def train_and_evaluate_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=200, device='cuda'):
    model.to(device)
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

    for epoch in range(num_epochs):
        
        model.train()
        train_loss = 0.0
        train_corrects = 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            train_corrects += torch.sum(preds == labels.data)

        train_loss /= len(train_loader.dataset)
        train_acc = train_corrects.double() / len(train_loader.dataset)
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)

        
        model.eval()
        val_loss = 0.0
        val_corrects = 0
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            with torch.no_grad():
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                _, preds = torch.max(outputs, 1)
                val_corrects += torch.sum(preds == labels.data)

        val_loss /= len(val_loader.dataset)
        val_acc = val_corrects.double() / len(val_loader.dataset)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)

        print(f'Epoch {epoch+1}/{num_epochs} - Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')

        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = copy.deepcopy(model.state_dict())

    model.load_state_dict(best_model_wts)
    return model, history


train_loader = DataLoader(dataset_train, batch_size=32, shuffle=True)
val_loader = DataLoader(dataset_val, batch_size=32, shuffle=False)
trained_model, training_history = train_and_evaluate_model(resnet34, train_loader, val_loader, criterion, optimizer, num_epochs=200, device=device)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/200 - Train Loss: 1.1556, Train Acc: 0.3732, Val Loss: 1.0870, Val Acc: 0.3938
# Epoch 2/200 - Train Loss: 1.0747, Train Acc: 0.4413, Val Loss: 1.0299, Val Acc: 0.5274
# Epoch 3/200 - Train Loss: 1.0460, Train Acc: 0.4897, Val Loss: 0.9936, Val Acc: 0.5377
# Epoch 4/200 - Train Loss: 0.9922, Train Acc: 0.5814, Val Loss: 0.9617, Val Acc: 0.5959
# Epoch 5/200 - Train Loss: 0.9612, Train Acc: 0.6224, Val Loss: 0.9434, Val Acc: 0.5582
# Epoch 6/200 - Train Loss: 0.9323, Train Acc: 0.5946, Val Loss: 0.9147, Val Acc: 0.6336
# Epoch 7/200 - Train Loss: 0.9105, Train Acc: 0.6650, Val Loss: 0.8984, Val Acc: 0.6610
# Epoch 8/200 - Train Loss: 0.8909, Train Acc: 0.6686, Val Loss: 0.8899, Val Acc: 0.6336
# Epoch 9/200 - Train Loss: 0.8639, Train Acc: 0.7104, Val Loss: 0.8813, Val Acc: 0.6301
# Epoch 10/200 - Train Loss: 0.8742, Train Acc: 0.6628, Val Loss: 0.8641, Val Acc: 0.6918
# Epoch 11/200 - Train Loss: 0.8533, Train Acc: 0.6979, Val Loss: 0.8547, Val Acc: 0.6884
# Epoch 12/200 - Train Loss: 0.8347, Train Acc: 0.6979, Val Loss: 0.8494, Val Acc: 0.6815
# Epoch 13/200 - Train Loss: 0.8133, Train Acc: 0.7324, Val Loss: 0.8483, Val Acc: 0.6575
# Epoch 14/200 - Train Loss: 0.8226, Train Acc: 0.7038, Val Loss: 0.8378, Val Acc: 0.6678
# Epoch 15/200 - Train Loss: 0.7884, Train Acc: 0.7045, Val Loss: 0.8350, Val Acc: 0.7089
# Epoch 16/200 - Train Loss: 0.7912, Train Acc: 0.7207, Val Loss: 0.8325, Val Acc: 0.6610
# Epoch 17/200 - Train Loss: 0.7876, Train Acc: 0.7141, Val Loss: 0.8255, Val Acc: 0.6815
# Epoch 18/200 - Train Loss: 0.7730, Train Acc: 0.7148, Val Loss: 0.8175, Val Acc: 0.7021
# Epoch 19/200 - Train Loss: 0.7682, Train Acc: 0.7346, Val Loss: 0.8103, Val Acc: 0.6815
# Epoch 20/200 - Train Loss: 0.7604, Train Acc: 0.7375, Val Loss: 0.8112, Val Acc: 0.6884
# Epoch 21/200 - Train Loss: 0.7496, Train Acc: 0.7397, Val Loss: 0.8118, Val Acc: 0.6712
# Epoch 22/200 - Train Loss: 0.7403, Train Acc: 0.7383, Val Loss: 0.8087, Val Acc: 0.6644
# Epoch 23/200 - Train Loss: 0.7577, Train Acc: 0.7346, Val Loss: 0.8076, Val Acc: 0.6712
# Epoch 24/200 - Train Loss: 0.7443, Train Acc: 0.7221, Val Loss: 0.8014, Val Acc: 0.6884
# Epoch 25/200 - Train Loss: 0.7372, Train Acc: 0.7434, Val Loss: 0.7923, Val Acc: 0.7055
# Epoch 26/200 - Train Loss: 0.7410, Train Acc: 0.7177, Val Loss: 0.7924, Val Acc: 0.6918
# Epoch 27/200 - Train Loss: 0.7344, Train Acc: 0.7251, Val Loss: 0.7954, Val Acc: 0.6849
# Epoch 28/200 - Train Loss: 0.7161, Train Acc: 0.7625, Val Loss: 0.7872, Val Acc: 0.6747
# Epoch 29/200 - Train Loss: 0.7187, Train Acc: 0.7287, Val Loss: 0.7871, Val Acc: 0.6884
# Epoch 30/200 - Train Loss: 0.7137, Train Acc: 0.7471, Val Loss: 0.7880, Val Acc: 0.6815
# Epoch 31/200 - Train Loss: 0.7015, Train Acc: 0.7493, Val Loss: 0.7913, Val Acc: 0.6747
# Epoch 32/200 - Train Loss: 0.6894, Train Acc: 0.7603, Val Loss: 0.7841, Val Acc: 0.6918
# Epoch 33/200 - Train Loss: 0.6920, Train Acc: 0.7691, Val Loss: 0.7832, Val Acc: 0.6884
# Epoch 34/200 - Train Loss: 0.6949, Train Acc: 0.7500, Val Loss: 0.7864, Val Acc: 0.6952
# Epoch 35/200 - Train Loss: 0.6987, Train Acc: 0.7595, Val Loss: 0.7775, Val Acc: 0.6884
# Epoch 36/200 - Train Loss: 0.7063, Train Acc: 0.7353, Val Loss: 0.7807, Val Acc: 0.7021
# Epoch 37/200 - Train Loss: 0.6988, Train Acc: 0.7566, Val Loss: 0.7823, Val Acc: 0.6781
# Epoch 38/200 - Train Loss: 0.6807, Train Acc: 0.7654, Val Loss: 0.7751, Val Acc: 0.7329
# Epoch 39/200 - Train Loss: 0.6798, Train Acc: 0.7698, Val Loss: 0.7722, Val Acc: 0.7089
# Epoch 40/200 - Train Loss: 0.6768, Train Acc: 0.7647, Val Loss: 0.7698, Val Acc: 0.7089
# Epoch 41/200 - Train Loss: 0.6699, Train Acc: 0.7537, Val Loss: 0.7672, Val Acc: 0.6918
# Epoch 42/200 - Train Loss: 0.6757, Train Acc: 0.7625, Val Loss: 0.7687, Val Acc: 0.7192
# Epoch 43/200 - Train Loss: 0.6884, Train Acc: 0.7603, Val Loss: 0.7692, Val Acc: 0.6918
# Epoch 44/200 - Train Loss: 0.6726, Train Acc: 0.7434, Val Loss: 0.7644, Val Acc: 0.7158
# Epoch 45/200 - Train Loss: 0.6725, Train Acc: 0.7683, Val Loss: 0.7665, Val Acc: 0.7021
# Epoch 46/200 - Train Loss: 0.6768, Train Acc: 0.7573, Val Loss: 0.7640, Val Acc: 0.7089
# Epoch 47/200 - Train Loss: 0.6781, Train Acc: 0.7617, Val Loss: 0.7702, Val Acc: 0.6952
# Epoch 48/200 - Train Loss: 0.6519, Train Acc: 0.7771, Val Loss: 0.7635, Val Acc: 0.7192
# Epoch 49/200 - Train Loss: 0.6533, Train Acc: 0.7815, Val Loss: 0.7672, Val Acc: 0.6986
# Epoch 50/200 - Train Loss: 0.6467, Train Acc: 0.7830, Val Loss: 0.7661, Val Acc: 0.7226
# Epoch 51/200 - Train Loss: 0.6607, Train Acc: 0.7617, Val Loss: 0.7678, Val Acc: 0.7363
# Epoch 52/200 - Train Loss: 0.6600, Train Acc: 0.7676, Val Loss: 0.7651, Val Acc: 0.7260
# Epoch 53/200 - Train Loss: 0.6555, Train Acc: 0.7749, Val Loss: 0.7617, Val Acc: 0.7055
# Epoch 54/200 - Train Loss: 0.6455, Train Acc: 0.7713, Val Loss: 0.7611, Val Acc: 0.7123
# Epoch 55/200 - Train Loss: 0.6378, Train Acc: 0.7845, Val Loss: 0.7650, Val Acc: 0.6986
# Epoch 56/200 - Train Loss: 0.6431, Train Acc: 0.7647, Val Loss: 0.7605, Val Acc: 0.6986
# Epoch 57/200 - Train Loss: 0.6544, Train Acc: 0.7661, Val Loss: 0.7648, Val Acc: 0.7397
# Epoch 58/200 - Train Loss: 0.6314, Train Acc: 0.7830, Val Loss: 0.7564, Val Acc: 0.7089
# Epoch 59/200 - Train Loss: 0.6284, Train Acc: 0.7705, Val Loss: 0.7568, Val Acc: 0.7432
# Epoch 60/200 - Train Loss: 0.6413, Train Acc: 0.7749, Val Loss: 0.7608, Val Acc: 0.7158
# Epoch 61/200 - Train Loss: 0.6369, Train Acc: 0.7933, Val Loss: 0.7505, Val Acc: 0.7397
# Epoch 62/200 - Train Loss: 0.6318, Train Acc: 0.7823, Val Loss: 0.7584, Val Acc: 0.7329
# Epoch 63/200 - Train Loss: 0.6537, Train Acc: 0.7537, Val Loss: 0.7549, Val Acc: 0.7123
# Epoch 64/200 - Train Loss: 0.6356, Train Acc: 0.7779, Val Loss: 0.7600, Val Acc: 0.7329
# Epoch 65/200 - Train Loss: 0.6455, Train Acc: 0.7705, Val Loss: 0.7686, Val Acc: 0.7397
# Epoch 66/200 - Train Loss: 0.6372, Train Acc: 0.7749, Val Loss: 0.7655, Val Acc: 0.7295
# Epoch 67/200 - Train Loss: 0.6248, Train Acc: 0.7889, Val Loss: 0.7511, Val Acc: 0.7192
# Epoch 68/200 - Train Loss: 0.6299, Train Acc: 0.7713, Val Loss: 0.7701, Val Acc: 0.7500
# Epoch 69/200 - Train Loss: 0.6294, Train Acc: 0.7903, Val Loss: 0.7583, Val Acc: 0.7226
# Epoch 70/200 - Train Loss: 0.6305, Train Acc: 0.7735, Val Loss: 0.7590, Val Acc: 0.7192
# Epoch 71/200 - Train Loss: 0.6058, Train Acc: 0.7867, Val Loss: 0.7546, Val Acc: 0.7500
# Epoch 72/200 - Train Loss: 0.6282, Train Acc: 0.7551, Val Loss: 0.7544, Val Acc: 0.7363
# Epoch 73/200 - Train Loss: 0.6165, Train Acc: 0.7918, Val Loss: 0.7533, Val Acc: 0.7329
# Epoch 74/200 - Train Loss: 0.6382, Train Acc: 0.7742, Val Loss: 0.7561, Val Acc: 0.6952
# Epoch 75/200 - Train Loss: 0.6337, Train Acc: 0.7595, Val Loss: 0.7466, Val Acc: 0.6986
# Epoch 76/200 - Train Loss: 0.6154, Train Acc: 0.7698, Val Loss: 0.7592, Val Acc: 0.7397
# Epoch 77/200 - Train Loss: 0.6235, Train Acc: 0.7896, Val Loss: 0.7495, Val Acc: 0.7158
# Epoch 78/200 - Train Loss: 0.5999, Train Acc: 0.7940, Val Loss: 0.7494, Val Acc: 0.7568
# Epoch 79/200 - Train Loss: 0.6038, Train Acc: 0.7771, Val Loss: 0.7553, Val Acc: 0.7397
# Epoch 80/200 - Train Loss: 0.6109, Train Acc: 0.7749, Val Loss: 0.7442, Val Acc: 0.7466
# Epoch 81/200 - Train Loss: 0.6051, Train Acc: 0.7881, Val Loss: 0.7528, Val Acc: 0.7226
# Epoch 82/200 - Train Loss: 0.6130, Train Acc: 0.7808, Val Loss: 0.7526, Val Acc: 0.7466
# Epoch 83/200 - Train Loss: 0.5873, Train Acc: 0.7962, Val Loss: 0.7557, Val Acc: 0.7500
# Epoch 84/200 - Train Loss: 0.5874, Train Acc: 0.7830, Val Loss: 0.7491, Val Acc: 0.7158
# Epoch 85/200 - Train Loss: 0.5983, Train Acc: 0.7903, Val Loss: 0.7523, Val Acc: 0.7226
# Epoch 86/200 - Train Loss: 0.6122, Train Acc: 0.7691, Val Loss: 0.7561, Val Acc: 0.7158
# Epoch 87/200 - Train Loss: 0.6088, Train Acc: 0.7801, Val Loss: 0.7559, Val Acc: 0.7363
# Epoch 88/200 - Train Loss: 0.5859, Train Acc: 0.7962, Val Loss: 0.7507, Val Acc: 0.7432
# Epoch 89/200 - Train Loss: 0.6296, Train Acc: 0.7757, Val Loss: 0.7479, Val Acc: 0.7158
# Epoch 90/200 - Train Loss: 0.6183, Train Acc: 0.7918, Val Loss: 0.7525, Val Acc: 0.7329
# Epoch 91/200 - Train Loss: 0.6037, Train Acc: 0.7742, Val Loss: 0.7429, Val Acc: 0.7432
# Epoch 92/200 - Train Loss: 0.5875, Train Acc: 0.7991, Val Loss: 0.7406, Val Acc: 0.7466
# Epoch 93/200 - Train Loss: 0.6110, Train Acc: 0.7940, Val Loss: 0.7531, Val Acc: 0.7432
# Epoch 94/200 - Train Loss: 0.5879, Train Acc: 0.7947, Val Loss: 0.7557, Val Acc: 0.7192
# Epoch 95/200 - Train Loss: 0.5801, Train Acc: 0.7947, Val Loss: 0.7487, Val Acc: 0.7295
# Epoch 96/200 - Train Loss: 0.5899, Train Acc: 0.7830, Val Loss: 0.7559, Val Acc: 0.7432
# Epoch 97/200 - Train Loss: 0.6069, Train Acc: 0.7727, Val Loss: 0.7431, Val Acc: 0.7397
# Epoch 98/200 - Train Loss: 0.6073, Train Acc: 0.7815, Val Loss: 0.7504, Val Acc: 0.7329
# Epoch 99/200 - Train Loss: 0.6095, Train Acc: 0.7823, Val Loss: 0.7367, Val Acc: 0.7260
# Epoch 100/200 - Train Loss: 0.5861, Train Acc: 0.7933, Val Loss: 0.7442, Val Acc: 0.7295
# Epoch 101/200 - Train Loss: 0.5766, Train Acc: 0.7896, Val Loss: 0.7445, Val Acc: 0.7397
# Epoch 102/200 - Train Loss: 0.5896, Train Acc: 0.7786, Val Loss: 0.7440, Val Acc: 0.7500
# Epoch 103/200 - Train Loss: 0.5927, Train Acc: 0.7808, Val Loss: 0.7455, Val Acc: 0.7500
# Epoch 104/200 - Train Loss: 0.6032, Train Acc: 0.7903, Val Loss: 0.7489, Val Acc: 0.7466
# Epoch 105/200 - Train Loss: 0.5929, Train Acc: 0.8116, Val Loss: 0.7474, Val Acc: 0.7295
# Epoch 106/200 - Train Loss: 0.5752, Train Acc: 0.7779, Val Loss: 0.7572, Val Acc: 0.7432
# Epoch 107/200 - Train Loss: 0.5856, Train Acc: 0.8035, Val Loss: 0.7532, Val Acc: 0.7260
# Epoch 108/200 - Train Loss: 0.5881, Train Acc: 0.7830, Val Loss: 0.7529, Val Acc: 0.7329
# Epoch 109/200 - Train Loss: 0.5919, Train Acc: 0.7991, Val Loss: 0.7510, Val Acc: 0.7158
# Epoch 110/200 - Train Loss: 0.5924, Train Acc: 0.7940, Val Loss: 0.7460, Val Acc: 0.7466
# Epoch 111/200 - Train Loss: 0.5903, Train Acc: 0.8065, Val Loss: 0.7462, Val Acc: 0.7123
# Epoch 112/200 - Train Loss: 0.5882, Train Acc: 0.7742, Val Loss: 0.7484, Val Acc: 0.7568
# Epoch 113/200 - Train Loss: 0.5853, Train Acc: 0.8035, Val Loss: 0.7435, Val Acc: 0.7123
# Epoch 114/200 - Train Loss: 0.5827, Train Acc: 0.7625, Val Loss: 0.7513, Val Acc: 0.7534
# Epoch 115/200 - Train Loss: 0.5782, Train Acc: 0.7984, Val Loss: 0.7449, Val Acc: 0.7089
# Epoch 116/200 - Train Loss: 0.5670, Train Acc: 0.7940, Val Loss: 0.7487, Val Acc: 0.7500
# Epoch 117/200 - Train Loss: 0.5811, Train Acc: 0.7955, Val Loss: 0.7319, Val Acc: 0.7432
# Epoch 118/200 - Train Loss: 0.5754, Train Acc: 0.7962, Val Loss: 0.7358, Val Acc: 0.7329
# Epoch 119/200 - Train Loss: 0.5754, Train Acc: 0.7808, Val Loss: 0.7445, Val Acc: 0.7603
# Epoch 120/200 - Train Loss: 0.5676, Train Acc: 0.8072, Val Loss: 0.7467, Val Acc: 0.7260
# Epoch 121/200 - Train Loss: 0.5767, Train Acc: 0.7786, Val Loss: 0.7453, Val Acc: 0.7568
# Epoch 122/200 - Train Loss: 0.5865, Train Acc: 0.8013, Val Loss: 0.7401, Val Acc: 0.7500
# Epoch 123/200 - Train Loss: 0.5606, Train Acc: 0.8028, Val Loss: 0.7443, Val Acc: 0.7260
# Epoch 124/200 - Train Loss: 0.5603, Train Acc: 0.7874, Val Loss: 0.7454, Val Acc: 0.7260
# Epoch 125/200 - Train Loss: 0.5719, Train Acc: 0.7955, Val Loss: 0.7442, Val Acc: 0.7500
# Epoch 126/200 - Train Loss: 0.5921, Train Acc: 0.7969, Val Loss: 0.7500, Val Acc: 0.7500
# Epoch 127/200 - Train Loss: 0.5739, Train Acc: 0.7830, Val Loss: 0.7554, Val Acc: 0.7432
# Epoch 128/200 - Train Loss: 0.5850, Train Acc: 0.8021, Val Loss: 0.7492, Val Acc: 0.7158
# Epoch 129/200 - Train Loss: 0.5525, Train Acc: 0.8072, Val Loss: 0.7509, Val Acc: 0.7603
# Epoch 130/200 - Train Loss: 0.5733, Train Acc: 0.7808, Val Loss: 0.7452, Val Acc: 0.7534
# Epoch 131/200 - Train Loss: 0.5703, Train Acc: 0.7991, Val Loss: 0.7561, Val Acc: 0.7329
# Epoch 132/200 - Train Loss: 0.5789, Train Acc: 0.8072, Val Loss: 0.7444, Val Acc: 0.7603
# Epoch 133/200 - Train Loss: 0.5631, Train Acc: 0.8050, Val Loss: 0.7466, Val Acc: 0.7432
# Epoch 134/200 - Train Loss: 0.5709, Train Acc: 0.7911, Val Loss: 0.7415, Val Acc: 0.7123
# Epoch 135/200 - Train Loss: 0.5736, Train Acc: 0.7940, Val Loss: 0.7454, Val Acc: 0.7500
# Epoch 136/200 - Train Loss: 0.5675, Train Acc: 0.7933, Val Loss: 0.7413, Val Acc: 0.7637
# Epoch 137/200 - Train Loss: 0.5585, Train Acc: 0.7977, Val Loss: 0.7439, Val Acc: 0.7568
# Epoch 138/200 - Train Loss: 0.5698, Train Acc: 0.7896, Val Loss: 0.7379, Val Acc: 0.7603
# Epoch 139/200 - Train Loss: 0.5542, Train Acc: 0.8065, Val Loss: 0.7497, Val Acc: 0.7466
# Epoch 140/200 - Train Loss: 0.5543, Train Acc: 0.8094, Val Loss: 0.7498, Val Acc: 0.7637
# Epoch 141/200 - Train Loss: 0.5571, Train Acc: 0.8035, Val Loss: 0.7490, Val Acc: 0.7432
# Epoch 142/200 - Train Loss: 0.5762, Train Acc: 0.7940, Val Loss: 0.7447, Val Acc: 0.7432
# Epoch 143/200 - Train Loss: 0.5571, Train Acc: 0.8043, Val Loss: 0.7427, Val Acc: 0.7432
# Epoch 144/200 - Train Loss: 0.5881, Train Acc: 0.7837, Val Loss: 0.7467, Val Acc: 0.7534
# Epoch 145/200 - Train Loss: 0.5564, Train Acc: 0.8057, Val Loss: 0.7475, Val Acc: 0.7158
# Epoch 146/200 - Train Loss: 0.5581, Train Acc: 0.7977, Val Loss: 0.7502, Val Acc: 0.7534
# Epoch 147/200 - Train Loss: 0.5662, Train Acc: 0.8013, Val Loss: 0.7513, Val Acc: 0.7226
# Epoch 148/200 - Train Loss: 0.5594, Train Acc: 0.7830, Val Loss: 0.7486, Val Acc: 0.7603
# Epoch 149/200 - Train Loss: 0.5659, Train Acc: 0.8057, Val Loss: 0.7560, Val Acc: 0.7397
# Epoch 150/200 - Train Loss: 0.5772, Train Acc: 0.7845, Val Loss: 0.7519, Val Acc: 0.7603
# Epoch 151/200 - Train Loss: 0.5702, Train Acc: 0.8065, Val Loss: 0.7480, Val Acc: 0.7397
# Epoch 152/200 - Train Loss: 0.5681, Train Acc: 0.7801, Val Loss: 0.7525, Val Acc: 0.7363
# Epoch 153/200 - Train Loss: 0.5472, Train Acc: 0.8072, Val Loss: 0.7581, Val Acc: 0.7466
# Epoch 154/200 - Train Loss: 0.5489, Train Acc: 0.8087, Val Loss: 0.7372, Val Acc: 0.7192
# Epoch 155/200 - Train Loss: 0.5644, Train Acc: 0.7852, Val Loss: 0.7465, Val Acc: 0.7295
# Epoch 156/200 - Train Loss: 0.5457, Train Acc: 0.7933, Val Loss: 0.7513, Val Acc: 0.7637
# Epoch 157/200 - Train Loss: 0.5679, Train Acc: 0.7969, Val Loss: 0.7506, Val Acc: 0.7500
# Epoch 158/200 - Train Loss: 0.5562, Train Acc: 0.7984, Val Loss: 0.7552, Val Acc: 0.7363
# Epoch 159/200 - Train Loss: 0.5626, Train Acc: 0.7881, Val Loss: 0.7533, Val Acc: 0.7466
# Epoch 160/200 - Train Loss: 0.5569, Train Acc: 0.8130, Val Loss: 0.7582, Val Acc: 0.7021
# Epoch 161/200 - Train Loss: 0.5539, Train Acc: 0.7911, Val Loss: 0.7484, Val Acc: 0.7260
# Epoch 162/200 - Train Loss: 0.5523, Train Acc: 0.7859, Val Loss: 0.7563, Val Acc: 0.7500
# Epoch 163/200 - Train Loss: 0.5371, Train Acc: 0.7933, Val Loss: 0.7489, Val Acc: 0.7534
# Epoch 164/200 - Train Loss: 0.5518, Train Acc: 0.8087, Val Loss: 0.7539, Val Acc: 0.7089
# Epoch 165/200 - Train Loss: 0.5581, Train Acc: 0.8021, Val Loss: 0.7544, Val Acc: 0.7466
# Epoch 166/200 - Train Loss: 0.5583, Train Acc: 0.7852, Val Loss: 0.7505, Val Acc: 0.7089
# Epoch 167/200 - Train Loss: 0.5446, Train Acc: 0.8138, Val Loss: 0.7474, Val Acc: 0.7329
# Epoch 168/200 - Train Loss: 0.5530, Train Acc: 0.8087, Val Loss: 0.7499, Val Acc: 0.7432
# Epoch 169/200 - Train Loss: 0.5476, Train Acc: 0.7889, Val Loss: 0.7455, Val Acc: 0.7192
# Epoch 170/200 - Train Loss: 0.5440, Train Acc: 0.7940, Val Loss: 0.7562, Val Acc: 0.7192
# Epoch 171/200 - Train Loss: 0.5645, Train Acc: 0.7955, Val Loss: 0.7577, Val Acc: 0.7397
# Epoch 172/200 - Train Loss: 0.5744, Train Acc: 0.7991, Val Loss: 0.7591, Val Acc: 0.7158
# Epoch 173/200 - Train Loss: 0.5284, Train Acc: 0.7830, Val Loss: 0.7472, Val Acc: 0.7466
# Epoch 174/200 - Train Loss: 0.5427, Train Acc: 0.8160, Val Loss: 0.7573, Val Acc: 0.7432
# Epoch 175/200 - Train Loss: 0.5458, Train Acc: 0.8021, Val Loss: 0.7556, Val Acc: 0.7260
# Epoch 176/200 - Train Loss: 0.5510, Train Acc: 0.7933, Val Loss: 0.7529, Val Acc: 0.7603
# Epoch 177/200 - Train Loss: 0.5390, Train Acc: 0.8043, Val Loss: 0.7449, Val Acc: 0.7089
# Epoch 178/200 - Train Loss: 0.5164, Train Acc: 0.8262, Val Loss: 0.7588, Val Acc: 0.7603
# Epoch 179/200 - Train Loss: 0.5555, Train Acc: 0.7977, Val Loss: 0.7512, Val Acc: 0.7158
# Epoch 180/200 - Train Loss: 0.5414, Train Acc: 0.8035, Val Loss: 0.7587, Val Acc: 0.7603
# Epoch 181/200 - Train Loss: 0.5520, Train Acc: 0.8094, Val Loss: 0.7557, Val Acc: 0.7466
# Epoch 182/200 - Train Loss: 0.5537, Train Acc: 0.8101, Val Loss: 0.7522, Val Acc: 0.7295
# Epoch 183/200 - Train Loss: 0.5442, Train Acc: 0.7771, Val Loss: 0.7652, Val Acc: 0.7671
# Epoch 184/200 - Train Loss: 0.5306, Train Acc: 0.8270, Val Loss: 0.7585, Val Acc: 0.7671
# Epoch 185/200 - Train Loss: 0.5290, Train Acc: 0.8050, Val Loss: 0.7463, Val Acc: 0.7329
# Epoch 186/200 - Train Loss: 0.5369, Train Acc: 0.8196, Val Loss: 0.7529, Val Acc: 0.7534
# Epoch 187/200 - Train Loss: 0.5473, Train Acc: 0.7955, Val Loss: 0.7557, Val Acc: 0.7329
# Epoch 188/200 - Train Loss: 0.5301, Train Acc: 0.8035, Val Loss: 0.7541, Val Acc: 0.7534
# Epoch 189/200 - Train Loss: 0.5620, Train Acc: 0.8013, Val Loss: 0.7575, Val Acc: 0.7534
# Epoch 190/200 - Train Loss: 0.5499, Train Acc: 0.8035, Val Loss: 0.7515, Val Acc: 0.7089
# Epoch 191/200 - Train Loss: 0.5342, Train Acc: 0.7991, Val Loss: 0.7603, Val Acc: 0.7534
# Epoch 192/200 - Train Loss: 0.5412, Train Acc: 0.8123, Val Loss: 0.7453, Val Acc: 0.7192
# Epoch 193/200 - Train Loss: 0.5462, Train Acc: 0.7903, Val Loss: 0.7554, Val Acc: 0.7568
# Epoch 194/200 - Train Loss: 0.5329, Train Acc: 0.7977, Val Loss: 0.7598, Val Acc: 0.7568
# Epoch 195/200 - Train Loss: 0.5515, Train Acc: 0.8182, Val Loss: 0.7462, Val Acc: 0.7363
# Epoch 196/200 - Train Loss: 0.5362, Train Acc: 0.8101, Val Loss: 0.7594, Val Acc: 0.7568
# Epoch 197/200 - Train Loss: 0.5477, Train Acc: 0.7918, Val Loss: 0.7591, Val Acc: 0.7432
# Epoch 198/200 - Train Loss: 0.5394, Train Acc: 0.8240, Val Loss: 0.7548, Val Acc: 0.7466
# Epoch 199/200 - Train Loss: 0.5652, Train Acc: 0.7764, Val Loss: 0.7553, Val Acc: 0.7295
# Epoch 200/200 - Train Loss: 0.5468, Train Acc: 0.7962, Val Loss: 0.7641, Val Acc: 0.7671

# %%
def plot_training_history(history):
    epochs = range(1, len(history['train_loss']) + 1)

    train_losses = [x.cpu().numpy() if torch.is_tensor(x) else x for x in history['train_loss']]
    val_losses = [x.cpu().numpy() if torch.is_tensor(x) else x for x in history['val_loss']]
    train_accs = [x.cpu().numpy() if torch.is_tensor(x) else x for x in history['train_acc']]
    val_accs = [x.cpu().numpy() if torch.is_tensor(x) else x for x in history['val_acc']]

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.plot(epochs, val_losses, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.ylim(0, 1.5)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accs, label='Train Accuracy')
    plt.plot(epochs, val_accs, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.ylim(0, 1)
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()
plot_training_history(training_history)

# %% [markdown]
# # TEST SET

# %%
import os
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import copy
from sklearn.metrics import roc_auc_score, balanced_accuracy_score, recall_score, precision_score



device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = torch.load('/Mineral/E3.path')
model.to(device)
criterion = torch.nn.CrossEntropyLoss()

img_dir_al = '/Mineral/Enhanced-Al-S'
img_dir_fe = '/Mineral/Enhanced-Fe-S'
img_dir_mg = '/Mineral/Mg-S'
test_csv = '/Mineral/test_split.csv'

test_dataset = MineralDataset(img_dir_al, img_dir_fe, img_dir_mg, test_csv, transform=transform_test)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

def evaluate_model(model, data_loader, criterion, device):
    model.eval()  
    all_probs = []
    all_labels = []
    all_losses = []

    with torch.no_grad(): 
        for inputs, labels in data_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            probabilities = torch.softmax(outputs, dim=1)
            all_probs.append(probabilities.cpu().numpy())
            all_labels.append(labels.cpu().numpy())
            all_losses.append(loss.cpu().numpy())

    all_probs = np.concatenate(all_probs)
    all_labels = np.concatenate(all_labels)
    all_losses = np.array(all_losses)
    return all_probs, all_labels, all_losses

def bootstrap_metric(y_true, y_prob, metric_func, n_bootstrap=1000, alpha=0.05, **kwargs):
    rng = np.random.default_rng()
    indices = np.arange(len(y_true))
    bootstrapped_scores = []
    for _ in range(n_bootstrap):
        sample_indices = rng.choice(indices, size=len(indices), replace=True)
        if metric_func == roc_auc_score:
            score = metric_func(y_true[sample_indices], y_prob[sample_indices], **kwargs)
        else:
            y_pred = np.argmax(y_prob[sample_indices], axis=1)
            score = metric_func(y_true[sample_indices], y_pred, **kwargs)
        bootstrapped_scores.append(score)
    sorted_scores = np.sort(bootstrapped_scores)
    ci_lower = sorted_scores[int((alpha/2) * n_bootstrap)]
    ci_upper = sorted_scores[int((1 - alpha/2) * n_bootstrap)]
    return np.mean(bootstrapped_scores), ci_lower, ci_upper

def bootstrap_loss(losses, n_bootstrap=1000, alpha=0.05):
    rng = np.random.default_rng()
    indices = np.arange(len(losses))
    bootstrapped_losses = []
    for _ in range(n_bootstrap):
        sample_indices = rng.choice(indices, size=len(indices), replace=True)
        sample_loss = losses[sample_indices]
        bootstrapped_losses.append(np.mean(sample_loss))
    sorted_losses = np.sort(bootstrapped_losses)
    ci_lower = sorted_losses[int((alpha/2) * n_bootstrap)]
    ci_upper = sorted_losses[int((1 - alpha/2) * n_bootstrap)]
    return np.mean(bootstrapped_losses), ci_lower, ci_upper

test_probs, test_labels, test_losses = evaluate_model(model, test_loader, criterion, device)

class_labels = np.unique(test_labels)
metrics = {}
for class_label in class_labels:
    auc_roc_mean, auc_roc_ci_low, auc_roc_ci_high = bootstrap_metric(test_labels == class_label, test_probs[:, class_label], roc_auc_score)
    balanced_acc_mean, balanced_acc_ci_low, balanced_acc_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: balanced_accuracy_score(y_true == class_label, y_pred == class_label))
    sensitivity_mean, sensitivity_ci_low, sensitivity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: recall_score(y_true == class_label, y_pred == class_label, zero_division=0))
    specificity_mean, specificity_ci_low, specificity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: precision_score(y_true == class_label, y_pred == class_label, zero_division=0))

    metrics[class_label] = {
        "AUC-ROC": (auc_roc_mean, auc_roc_ci_low, auc_roc_ci_high),
        "Balanced Accuracy": (balanced_acc_mean, balanced_acc_ci_low, balanced_acc_ci_high),
        "Sensitivity": (sensitivity_mean, sensitivity_ci_low, sensitivity_ci_high),
        "Specificity": (specificity_mean, specificity_ci_low, specificity_ci_high)
    }

print("Class\t\tAUC-ROC\t\t\tBalanced Accuracy\tSensitivity\t\tSpecificity")
for class_label, metric_values in metrics.items():
    auc_roc = metric_values["AUC-ROC"]
    balanced_acc = metric_values["Balanced Accuracy"]
    sensitivity = metric_values["Sensitivity"]
    specificity = metric_values["Specificity"]
    print(f"{class_label}\t\t{auc_roc[0]:.2f} ({auc_roc[1]:.2f}-{auc_roc[2]:.2f})\t"
          f"{balanced_acc[0]:.2f} ({balanced_acc[1]:.2f}-{balanced_acc[2]:.2f})\t"
          f"{sensitivity[0]:.2f} ({sensitivity[1]:.2f}-{sensitivity[2]:.2f})\t"
          f"{specificity[0]:.2f} ({specificity[1]:.2f}-{specificity[2]:.2f})")

auc_roc_mean, auc_roc_ci_low, auc_roc_ci_high = bootstrap_metric(test_labels, test_probs, roc_auc_score, multi_class='ovr')
balanced_acc_mean, balanced_acc_ci_low, balanced_acc_ci_high = bootstrap_metric(test_labels, test_probs, balanced_accuracy_score)
sensitivity_mean, sensitivity_ci_low, sensitivity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: recall_score(y_true, y_pred, average='macro', zero_division=0))
specificity_mean, specificity_ci_low, specificity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: precision_score(y_true, y_pred, average='macro', zero_division=0))

loss_mean, loss_ci_low, loss_ci_high = bootstrap_loss(test_losses)

print(f"Overall\t\t{auc_roc_mean:.2f} ({auc_roc_ci_low:.2f}-{auc_roc_ci_high:.2f})\t"
      f"{balanced_acc_mean:.2f} ({balanced_acc_ci_low:.2f}-{balanced_acc_ci_high:.2f})\t"
      f"{sensitivity_mean:.2f} ({sensitivity_ci_low:.2f}-{sensitivity_ci_high:.2f})\t"
      f"{specificity_mean:.2f} ({specificity_ci_low:.2f}-{specificity_ci_high:.2f})")
print(f"Loss\t\t{loss_mean:.4f} ({loss_ci_low:.4f}-{loss_ci_high:.4f})")
# Out:
# Class		AUC-ROC			Balanced Accuracy	Sensitivity		Specificity
# 0		0.80 (0.75-0.85)	0.61 (0.56-0.66)	0.33 (0.23-0.42)	0.62 (0.48-0.75)
# 1		0.79 (0.73-0.84)	0.71 (0.67-0.76)	0.59 (0.52-0.67)	0.84 (0.77-0.90)
# 2		0.48 (0.36-0.60)	0.54 (0.44-0.63)	0.48 (0.30-0.67)	0.11 (0.05-0.17)
# Overall		0.69 (0.63-0.75)	0.47 (0.39-0.55)	0.47 (0.38-0.54)	0.52 (0.47-0.57)
# Loss		1.2028 (1.0567-1.3391)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report


test_predictions, test_labels = get_predictions_and_labels(trained_model, test_loader, device)

cm = confusion_matrix(test_labels, test_predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

print(classification_report(test_labels, test_predictions, target_names=['Class 0', 'Class 1', 'Class 2']))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.62      0.32      0.42        96
#      Class 1       0.83      0.59      0.69       170
#      Class 2       0.11      0.48      0.17        27
#
#     accuracy                           0.49       293
#    macro avg       0.52      0.47      0.43       293
# weighted avg       0.70      0.49      0.56       293

# %%
import torch
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from itertools import cycle

def evaluate_model_for_roc(model, test_loader, device='cuda'):
    model.to(device)
    model.eval()

    all_preds_prob = []
    all_labels = []

    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        with torch.no_grad():
            outputs = model(inputs)
            probs = torch.nn.functional.softmax(outputs, dim=1)
            all_preds_prob.append(probs.cpu().numpy())
            all_labels.append(labels.cpu().numpy())

    all_preds_prob = np.concatenate(all_preds_prob)
    all_labels = np.concatenate(all_labels)

    return all_preds_prob, all_labels

num_classes = 3
all_preds_prob, all_labels = evaluate_model_for_roc(trained_model, test_loader, device=device)
all_labels_one_hot = label_binarize(all_labels, classes=[0, 1, 2])

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(all_labels_one_hot[:, i], all_preds_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

colors = cycle(['blue', 'red', 'green'])
for i, color in zip(range(num_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.2f})'.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-class ROC')
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt

def get_predictions(model, test_loader, device):
    model.eval()  
    predictions = []
    true_labels = []

    with torch.no_grad(): 
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            outputs = model(inputs)
            probs = torch.nn.functional.softmax(outputs, dim=1) 
            predictions.extend(probs.cpu().numpy())
            true_labels.extend(labels.cpu().numpy())

    return np.array(predictions), np.array(true_labels)

predictions, true_labels = get_predictions(model, test_loader, device)

plt.figure(figsize=(6, 4))
bins = np.linspace(0, 1, 30) 
for class_index in range(num_classes):
    plt.hist(predictions[:, class_index], bins=bins, alpha=0.5, label=f'Class {class_index}')
plt.title('Distribution of Predicted Probabilities')
plt.xlabel('Probability')
plt.ylabel('Frequency')
plt.legend()
plt.show()
