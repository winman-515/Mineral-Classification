# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from torch.utils.data import Dataset


class MineralDataset(Dataset):
    def __init__(self, img_dir_al, img_dir_ca, img_dir_mg, labels_csv, transform=None):
        self.dataframe = pd.read_csv(labels_csv)
        self.img_dir_al = img_dir_al
        self.img_dir_ca = img_dir_ca
        self.img_dir_mg = img_dir_mg
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        file_name = row['Segmented Filename']
        label = row['Class']
        img_al = Image.open(os.path.join(self.img_dir_al, file_name)).convert('L')
        img_ca = Image.open(os.path.join(self.img_dir_ca, file_name)).convert('L')
        img_mg = Image.open(os.path.join(self.img_dir_mg, file_name)).convert('L')
        img_combined = Image.merge('RGB', (img_al, img_ca, img_mg))
        if self.transform:
            img_combined = self.transform(img_combined)
        return img_combined, label
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),  
    transforms.RandomRotation(10),       
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transform_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
#Combined Data set
dataset_train = MineralDataset(
    img_dir_al='/Mineral/Enhanced-Al-S',
    img_dir_ca='/Mineral/Ca-S',
    img_dir_mg='/Mineral/Mg-S',
    labels_csv='/Mineral/train_split.csv',  
    transform=transform_train
)

dataset_val = MineralDataset(
    img_dir_al='/Mineral/Enhanced-Al-S',
    img_dir_ca='/Mineral/Ca-S',
    img_dir_mg='/Mineral/Mg-S',
    labels_csv='/Mineral/val_split.csv',
    transform=transform_test
)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import matplotlib.pyplot as plt
import copy


resnet34 = models.resnet34(pretrained=True)

for param in resnet34.parameters():
    param.requires_grad = False


num_classes = 3  
num_ftrs = resnet34.fc.in_features
resnet34.fc = nn.Linear(num_ftrs, num_classes)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
resnet34 = resnet34.to(device)


labels = [label for _, label in dataset_train]  
class_weights = compute_class_weight('balanced', classes=np.unique(labels), y=labels)
class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(resnet34.fc.parameters(), lr=0.0001)  


def train_and_evaluate_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=200, device='cuda'):
    model.to(device)
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

    for epoch in range(num_epochs):
  
        model.train()
        train_loss = 0.0
        train_corrects = 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            train_corrects += torch.sum(preds == labels.data)

        train_loss /= len(train_loader.dataset)
        train_acc = train_corrects.double() / len(train_loader.dataset)
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)

      
        model.eval()
        val_loss = 0.0
        val_corrects = 0
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            with torch.no_grad():
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                _, preds = torch.max(outputs, 1)
                val_corrects += torch.sum(preds == labels.data)

        val_loss /= len(val_loader.dataset)
        val_acc = val_corrects.double() / len(val_loader.dataset)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)

        print(f'Epoch {epoch+1}/{num_epochs} - Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')

        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = copy.deepcopy(model.state_dict())

    model.load_state_dict(best_model_wts)
    return model, history


train_loader = DataLoader(dataset_train, batch_size=32, shuffle=True)
val_loader = DataLoader(dataset_val, batch_size=32, shuffle=False)
trained_model, training_history = train_and_evaluate_model(resnet34, train_loader, val_loader, criterion, optimizer, num_epochs=200, device=device)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/200 - Train Loss: 1.1053, Train Acc: 0.4377, Val Loss: 1.0662, Val Acc: 0.4247
# Epoch 2/200 - Train Loss: 1.0512, Train Acc: 0.4663, Val Loss: 1.0169, Val Acc: 0.5685
# Epoch 3/200 - Train Loss: 0.9952, Train Acc: 0.6136, Val Loss: 0.9754, Val Acc: 0.5890
# Epoch 4/200 - Train Loss: 0.9458, Train Acc: 0.6048, Val Loss: 0.9444, Val Acc: 0.6918
# Epoch 5/200 - Train Loss: 0.9228, Train Acc: 0.6613, Val Loss: 0.9157, Val Acc: 0.6678
# Epoch 6/200 - Train Loss: 0.9100, Train Acc: 0.6400, Val Loss: 0.8952, Val Acc: 0.6815
# Epoch 7/200 - Train Loss: 0.8639, Train Acc: 0.6796, Val Loss: 0.8776, Val Acc: 0.7055
# Epoch 8/200 - Train Loss: 0.8499, Train Acc: 0.7082, Val Loss: 0.8631, Val Acc: 0.6986
# Epoch 9/200 - Train Loss: 0.8372, Train Acc: 0.7163, Val Loss: 0.8513, Val Acc: 0.7397
# Epoch 10/200 - Train Loss: 0.8288, Train Acc: 0.7045, Val Loss: 0.8445, Val Acc: 0.7226
# Epoch 11/200 - Train Loss: 0.8064, Train Acc: 0.7192, Val Loss: 0.8354, Val Acc: 0.7432
# Epoch 12/200 - Train Loss: 0.8048, Train Acc: 0.7243, Val Loss: 0.8290, Val Acc: 0.7192
# Epoch 13/200 - Train Loss: 0.8176, Train Acc: 0.7126, Val Loss: 0.8210, Val Acc: 0.7466
# Epoch 14/200 - Train Loss: 0.7810, Train Acc: 0.7053, Val Loss: 0.8189, Val Acc: 0.7329
# Epoch 15/200 - Train Loss: 0.7628, Train Acc: 0.7309, Val Loss: 0.8113, Val Acc: 0.7432
# Epoch 16/200 - Train Loss: 0.7651, Train Acc: 0.7133, Val Loss: 0.8110, Val Acc: 0.7568
# Epoch 17/200 - Train Loss: 0.7534, Train Acc: 0.7493, Val Loss: 0.8015, Val Acc: 0.7740
# Epoch 18/200 - Train Loss: 0.7764, Train Acc: 0.7177, Val Loss: 0.7971, Val Acc: 0.7089
# Epoch 19/200 - Train Loss: 0.7601, Train Acc: 0.7258, Val Loss: 0.7923, Val Acc: 0.7397
# Epoch 20/200 - Train Loss: 0.7488, Train Acc: 0.7383, Val Loss: 0.7900, Val Acc: 0.7500
# Epoch 21/200 - Train Loss: 0.7526, Train Acc: 0.7214, Val Loss: 0.7954, Val Acc: 0.7432
# Epoch 22/200 - Train Loss: 0.7330, Train Acc: 0.7309, Val Loss: 0.7925, Val Acc: 0.7774
# Epoch 23/200 - Train Loss: 0.7334, Train Acc: 0.7339, Val Loss: 0.7851, Val Acc: 0.7329
# Epoch 24/200 - Train Loss: 0.7402, Train Acc: 0.7434, Val Loss: 0.7878, Val Acc: 0.7603
# Epoch 25/200 - Train Loss: 0.7260, Train Acc: 0.7324, Val Loss: 0.7813, Val Acc: 0.7500
# Epoch 26/200 - Train Loss: 0.7251, Train Acc: 0.7383, Val Loss: 0.7806, Val Acc: 0.7534
# Epoch 27/200 - Train Loss: 0.7251, Train Acc: 0.7375, Val Loss: 0.7781, Val Acc: 0.7329
# Epoch 28/200 - Train Loss: 0.7458, Train Acc: 0.7295, Val Loss: 0.7740, Val Acc: 0.7534
# Epoch 29/200 - Train Loss: 0.7157, Train Acc: 0.7119, Val Loss: 0.7784, Val Acc: 0.7740
# Epoch 30/200 - Train Loss: 0.7331, Train Acc: 0.7603, Val Loss: 0.7712, Val Acc: 0.7500
# Epoch 31/200 - Train Loss: 0.7059, Train Acc: 0.7522, Val Loss: 0.7718, Val Acc: 0.7671
# Epoch 32/200 - Train Loss: 0.7251, Train Acc: 0.7405, Val Loss: 0.7683, Val Acc: 0.7295
# Epoch 33/200 - Train Loss: 0.6885, Train Acc: 0.7493, Val Loss: 0.7709, Val Acc: 0.7603
# Epoch 34/200 - Train Loss: 0.7107, Train Acc: 0.7471, Val Loss: 0.7674, Val Acc: 0.7568
# Epoch 35/200 - Train Loss: 0.7032, Train Acc: 0.7324, Val Loss: 0.7673, Val Acc: 0.7671
# Epoch 36/200 - Train Loss: 0.6925, Train Acc: 0.7412, Val Loss: 0.7636, Val Acc: 0.7534
# Epoch 37/200 - Train Loss: 0.6977, Train Acc: 0.7331, Val Loss: 0.7673, Val Acc: 0.7774
# Epoch 38/200 - Train Loss: 0.6908, Train Acc: 0.7588, Val Loss: 0.7662, Val Acc: 0.7774
# Epoch 39/200 - Train Loss: 0.7027, Train Acc: 0.7449, Val Loss: 0.7603, Val Acc: 0.7774
# Epoch 40/200 - Train Loss: 0.6878, Train Acc: 0.7456, Val Loss: 0.7570, Val Acc: 0.7500
# Epoch 41/200 - Train Loss: 0.6796, Train Acc: 0.7463, Val Loss: 0.7623, Val Acc: 0.7774
# Epoch 42/200 - Train Loss: 0.6841, Train Acc: 0.7595, Val Loss: 0.7558, Val Acc: 0.7432
# Epoch 43/200 - Train Loss: 0.6904, Train Acc: 0.7449, Val Loss: 0.7599, Val Acc: 0.7842
# Epoch 44/200 - Train Loss: 0.6835, Train Acc: 0.7485, Val Loss: 0.7608, Val Acc: 0.7842
# Epoch 45/200 - Train Loss: 0.6735, Train Acc: 0.7771, Val Loss: 0.7554, Val Acc: 0.7226
# Epoch 46/200 - Train Loss: 0.6788, Train Acc: 0.7361, Val Loss: 0.7591, Val Acc: 0.7637
# Epoch 47/200 - Train Loss: 0.6851, Train Acc: 0.7610, Val Loss: 0.7543, Val Acc: 0.7397
# Epoch 48/200 - Train Loss: 0.6710, Train Acc: 0.7566, Val Loss: 0.7515, Val Acc: 0.7671
# Epoch 49/200 - Train Loss: 0.6672, Train Acc: 0.7537, Val Loss: 0.7534, Val Acc: 0.7363
# Epoch 50/200 - Train Loss: 0.6869, Train Acc: 0.7515, Val Loss: 0.7578, Val Acc: 0.7740
# Epoch 51/200 - Train Loss: 0.6760, Train Acc: 0.7581, Val Loss: 0.7526, Val Acc: 0.7568
# Epoch 52/200 - Train Loss: 0.6617, Train Acc: 0.7500, Val Loss: 0.7507, Val Acc: 0.7705
# Epoch 53/200 - Train Loss: 0.6612, Train Acc: 0.7698, Val Loss: 0.7571, Val Acc: 0.7808
# Epoch 54/200 - Train Loss: 0.6631, Train Acc: 0.7566, Val Loss: 0.7525, Val Acc: 0.7705
# Epoch 55/200 - Train Loss: 0.6704, Train Acc: 0.7537, Val Loss: 0.7507, Val Acc: 0.7500
# Epoch 56/200 - Train Loss: 0.6754, Train Acc: 0.7735, Val Loss: 0.7521, Val Acc: 0.7432
# Epoch 57/200 - Train Loss: 0.6840, Train Acc: 0.7478, Val Loss: 0.7497, Val Acc: 0.7877
# Epoch 58/200 - Train Loss: 0.6581, Train Acc: 0.7735, Val Loss: 0.7436, Val Acc: 0.7432
# Epoch 59/200 - Train Loss: 0.6552, Train Acc: 0.7339, Val Loss: 0.7478, Val Acc: 0.7774
# Epoch 60/200 - Train Loss: 0.6430, Train Acc: 0.7749, Val Loss: 0.7506, Val Acc: 0.7945
# Epoch 61/200 - Train Loss: 0.6520, Train Acc: 0.7669, Val Loss: 0.7509, Val Acc: 0.7705
# Epoch 62/200 - Train Loss: 0.6444, Train Acc: 0.7617, Val Loss: 0.7511, Val Acc: 0.7911
# Epoch 63/200 - Train Loss: 0.6671, Train Acc: 0.7566, Val Loss: 0.7443, Val Acc: 0.7466
# Epoch 64/200 - Train Loss: 0.6566, Train Acc: 0.7625, Val Loss: 0.7531, Val Acc: 0.8014
# Epoch 65/200 - Train Loss: 0.6412, Train Acc: 0.7808, Val Loss: 0.7464, Val Acc: 0.7466
# Epoch 66/200 - Train Loss: 0.6335, Train Acc: 0.7779, Val Loss: 0.7544, Val Acc: 0.8048
# Epoch 67/200 - Train Loss: 0.6418, Train Acc: 0.7610, Val Loss: 0.7482, Val Acc: 0.7842
# Epoch 68/200 - Train Loss: 0.6540, Train Acc: 0.7808, Val Loss: 0.7389, Val Acc: 0.7705
# Epoch 69/200 - Train Loss: 0.6539, Train Acc: 0.7551, Val Loss: 0.7481, Val Acc: 0.7842
# Epoch 70/200 - Train Loss: 0.6516, Train Acc: 0.7698, Val Loss: 0.7494, Val Acc: 0.7877
# Epoch 71/200 - Train Loss: 0.6461, Train Acc: 0.7691, Val Loss: 0.7437, Val Acc: 0.7808
# Epoch 72/200 - Train Loss: 0.6501, Train Acc: 0.7449, Val Loss: 0.7496, Val Acc: 0.7911
# Epoch 73/200 - Train Loss: 0.6390, Train Acc: 0.7874, Val Loss: 0.7450, Val Acc: 0.7774
# Epoch 74/200 - Train Loss: 0.6519, Train Acc: 0.7683, Val Loss: 0.7481, Val Acc: 0.7911
# Epoch 75/200 - Train Loss: 0.6464, Train Acc: 0.7771, Val Loss: 0.7449, Val Acc: 0.7603
# Epoch 76/200 - Train Loss: 0.6603, Train Acc: 0.7610, Val Loss: 0.7436, Val Acc: 0.7842
# Epoch 77/200 - Train Loss: 0.6466, Train Acc: 0.7507, Val Loss: 0.7413, Val Acc: 0.7740
# Epoch 78/200 - Train Loss: 0.6160, Train Acc: 0.7764, Val Loss: 0.7431, Val Acc: 0.7842
# Epoch 79/200 - Train Loss: 0.6348, Train Acc: 0.7683, Val Loss: 0.7416, Val Acc: 0.7740
# Epoch 80/200 - Train Loss: 0.6275, Train Acc: 0.7984, Val Loss: 0.7448, Val Acc: 0.7671
# Epoch 81/200 - Train Loss: 0.6490, Train Acc: 0.7383, Val Loss: 0.7429, Val Acc: 0.7740
# Epoch 82/200 - Train Loss: 0.6315, Train Acc: 0.7969, Val Loss: 0.7445, Val Acc: 0.7740
# Epoch 83/200 - Train Loss: 0.6367, Train Acc: 0.7610, Val Loss: 0.7524, Val Acc: 0.8116
# Epoch 84/200 - Train Loss: 0.6292, Train Acc: 0.7779, Val Loss: 0.7454, Val Acc: 0.7808
# Epoch 85/200 - Train Loss: 0.6411, Train Acc: 0.7691, Val Loss: 0.7520, Val Acc: 0.8151
# Epoch 86/200 - Train Loss: 0.6305, Train Acc: 0.7845, Val Loss: 0.7363, Val Acc: 0.7637
# Epoch 87/200 - Train Loss: 0.6193, Train Acc: 0.7705, Val Loss: 0.7446, Val Acc: 0.8014
# Epoch 88/200 - Train Loss: 0.6274, Train Acc: 0.7918, Val Loss: 0.7404, Val Acc: 0.7808
# Epoch 89/200 - Train Loss: 0.6309, Train Acc: 0.7647, Val Loss: 0.7420, Val Acc: 0.7877
# Epoch 90/200 - Train Loss: 0.6209, Train Acc: 0.7727, Val Loss: 0.7389, Val Acc: 0.7705
# Epoch 91/200 - Train Loss: 0.6208, Train Acc: 0.7859, Val Loss: 0.7420, Val Acc: 0.7671
# Epoch 92/200 - Train Loss: 0.6187, Train Acc: 0.7698, Val Loss: 0.7441, Val Acc: 0.7705
# Epoch 93/200 - Train Loss: 0.6380, Train Acc: 0.7661, Val Loss: 0.7400, Val Acc: 0.7877
# Epoch 94/200 - Train Loss: 0.6379, Train Acc: 0.7727, Val Loss: 0.7413, Val Acc: 0.7705
# Epoch 95/200 - Train Loss: 0.6316, Train Acc: 0.7867, Val Loss: 0.7400, Val Acc: 0.7705
# Epoch 96/200 - Train Loss: 0.6353, Train Acc: 0.7610, Val Loss: 0.7367, Val Acc: 0.7842
# Epoch 97/200 - Train Loss: 0.6364, Train Acc: 0.7808, Val Loss: 0.7398, Val Acc: 0.7740
# Epoch 98/200 - Train Loss: 0.6160, Train Acc: 0.7698, Val Loss: 0.7455, Val Acc: 0.7979
# Epoch 99/200 - Train Loss: 0.6303, Train Acc: 0.7595, Val Loss: 0.7411, Val Acc: 0.7842
# Epoch 100/200 - Train Loss: 0.6204, Train Acc: 0.7852, Val Loss: 0.7443, Val Acc: 0.7945
# Epoch 101/200 - Train Loss: 0.6166, Train Acc: 0.7955, Val Loss: 0.7392, Val Acc: 0.7911
# Epoch 102/200 - Train Loss: 0.6320, Train Acc: 0.7669, Val Loss: 0.7391, Val Acc: 0.7808
# Epoch 103/200 - Train Loss: 0.6518, Train Acc: 0.7845, Val Loss: 0.7382, Val Acc: 0.7466
# Epoch 104/200 - Train Loss: 0.6076, Train Acc: 0.7529, Val Loss: 0.7402, Val Acc: 0.7945
# Epoch 105/200 - Train Loss: 0.6197, Train Acc: 0.7727, Val Loss: 0.7414, Val Acc: 0.7774
# Epoch 106/200 - Train Loss: 0.6010, Train Acc: 0.7925, Val Loss: 0.7408, Val Acc: 0.7774
# Epoch 107/200 - Train Loss: 0.6249, Train Acc: 0.7669, Val Loss: 0.7424, Val Acc: 0.7945
# Epoch 108/200 - Train Loss: 0.6459, Train Acc: 0.7727, Val Loss: 0.7384, Val Acc: 0.7705
# Epoch 109/200 - Train Loss: 0.6037, Train Acc: 0.7889, Val Loss: 0.7336, Val Acc: 0.7774
# Epoch 110/200 - Train Loss: 0.6299, Train Acc: 0.7771, Val Loss: 0.7411, Val Acc: 0.7842
# Epoch 111/200 - Train Loss: 0.6059, Train Acc: 0.8013, Val Loss: 0.7369, Val Acc: 0.7808
# Epoch 112/200 - Train Loss: 0.6233, Train Acc: 0.7698, Val Loss: 0.7378, Val Acc: 0.7637
# Epoch 113/200 - Train Loss: 0.6152, Train Acc: 0.7610, Val Loss: 0.7374, Val Acc: 0.7945
# Epoch 114/200 - Train Loss: 0.6081, Train Acc: 0.7977, Val Loss: 0.7373, Val Acc: 0.7705
# Epoch 115/200 - Train Loss: 0.5905, Train Acc: 0.7874, Val Loss: 0.7408, Val Acc: 0.7808
# Epoch 116/200 - Train Loss: 0.6351, Train Acc: 0.7779, Val Loss: 0.7380, Val Acc: 0.7740
# Epoch 117/200 - Train Loss: 0.6057, Train Acc: 0.7720, Val Loss: 0.7433, Val Acc: 0.7740
# Epoch 118/200 - Train Loss: 0.6178, Train Acc: 0.7823, Val Loss: 0.7432, Val Acc: 0.7808
# Epoch 119/200 - Train Loss: 0.6095, Train Acc: 0.7632, Val Loss: 0.7385, Val Acc: 0.7774
# Epoch 120/200 - Train Loss: 0.6200, Train Acc: 0.7654, Val Loss: 0.7398, Val Acc: 0.7671
# Epoch 121/200 - Train Loss: 0.6013, Train Acc: 0.7933, Val Loss: 0.7398, Val Acc: 0.7808
# Epoch 122/200 - Train Loss: 0.6181, Train Acc: 0.7661, Val Loss: 0.7476, Val Acc: 0.7842
# Epoch 123/200 - Train Loss: 0.6244, Train Acc: 0.7903, Val Loss: 0.7328, Val Acc: 0.7603
# Epoch 124/200 - Train Loss: 0.5838, Train Acc: 0.7955, Val Loss: 0.7516, Val Acc: 0.8048
# Epoch 125/200 - Train Loss: 0.6210, Train Acc: 0.7632, Val Loss: 0.7383, Val Acc: 0.7740
# Epoch 126/200 - Train Loss: 0.6020, Train Acc: 0.8087, Val Loss: 0.7387, Val Acc: 0.7774
# Epoch 127/200 - Train Loss: 0.6285, Train Acc: 0.7581, Val Loss: 0.7465, Val Acc: 0.7808
# Epoch 128/200 - Train Loss: 0.6181, Train Acc: 0.7830, Val Loss: 0.7357, Val Acc: 0.7808
# Epoch 129/200 - Train Loss: 0.6144, Train Acc: 0.7845, Val Loss: 0.7349, Val Acc: 0.7740
# Epoch 130/200 - Train Loss: 0.5918, Train Acc: 0.7881, Val Loss: 0.7470, Val Acc: 0.7945
# Epoch 131/200 - Train Loss: 0.5993, Train Acc: 0.7911, Val Loss: 0.7436, Val Acc: 0.7774
# Epoch 132/200 - Train Loss: 0.6140, Train Acc: 0.7874, Val Loss: 0.7438, Val Acc: 0.7774
# Epoch 133/200 - Train Loss: 0.5942, Train Acc: 0.7925, Val Loss: 0.7412, Val Acc: 0.7945
# Epoch 134/200 - Train Loss: 0.6191, Train Acc: 0.7595, Val Loss: 0.7543, Val Acc: 0.8014
# Epoch 135/200 - Train Loss: 0.5875, Train Acc: 0.7859, Val Loss: 0.7508, Val Acc: 0.8014
# Epoch 136/200 - Train Loss: 0.6080, Train Acc: 0.7845, Val Loss: 0.7408, Val Acc: 0.7774
# Epoch 137/200 - Train Loss: 0.5970, Train Acc: 0.7705, Val Loss: 0.7414, Val Acc: 0.7808
# Epoch 138/200 - Train Loss: 0.5931, Train Acc: 0.7845, Val Loss: 0.7564, Val Acc: 0.8151
# Epoch 139/200 - Train Loss: 0.5914, Train Acc: 0.7977, Val Loss: 0.7392, Val Acc: 0.7740
# Epoch 140/200 - Train Loss: 0.6116, Train Acc: 0.7779, Val Loss: 0.7427, Val Acc: 0.7774
# Epoch 141/200 - Train Loss: 0.5898, Train Acc: 0.7683, Val Loss: 0.7384, Val Acc: 0.7671
# Epoch 142/200 - Train Loss: 0.5901, Train Acc: 0.7969, Val Loss: 0.7457, Val Acc: 0.7842
# Epoch 143/200 - Train Loss: 0.6139, Train Acc: 0.7698, Val Loss: 0.7446, Val Acc: 0.7808
# Epoch 144/200 - Train Loss: 0.6115, Train Acc: 0.7911, Val Loss: 0.7463, Val Acc: 0.7740
# Epoch 145/200 - Train Loss: 0.6090, Train Acc: 0.7698, Val Loss: 0.7402, Val Acc: 0.7740
# Epoch 146/200 - Train Loss: 0.6027, Train Acc: 0.7581, Val Loss: 0.7442, Val Acc: 0.7808
# Epoch 147/200 - Train Loss: 0.6030, Train Acc: 0.7808, Val Loss: 0.7305, Val Acc: 0.7740
# Epoch 148/200 - Train Loss: 0.6084, Train Acc: 0.7918, Val Loss: 0.7319, Val Acc: 0.7774
# Epoch 149/200 - Train Loss: 0.6028, Train Acc: 0.7698, Val Loss: 0.7366, Val Acc: 0.7740
# Epoch 150/200 - Train Loss: 0.5835, Train Acc: 0.7962, Val Loss: 0.7365, Val Acc: 0.7808
# Epoch 151/200 - Train Loss: 0.5845, Train Acc: 0.7881, Val Loss: 0.7322, Val Acc: 0.7774
# Epoch 152/200 - Train Loss: 0.5839, Train Acc: 0.7639, Val Loss: 0.7352, Val Acc: 0.7705
# Epoch 153/200 - Train Loss: 0.5939, Train Acc: 0.7786, Val Loss: 0.7341, Val Acc: 0.7705
# Epoch 154/200 - Train Loss: 0.5888, Train Acc: 0.7793, Val Loss: 0.7429, Val Acc: 0.7808
# Epoch 155/200 - Train Loss: 0.5862, Train Acc: 0.7896, Val Loss: 0.7424, Val Acc: 0.7842
# Epoch 156/200 - Train Loss: 0.6068, Train Acc: 0.7647, Val Loss: 0.7366, Val Acc: 0.7774
# Epoch 157/200 - Train Loss: 0.6081, Train Acc: 0.7757, Val Loss: 0.7405, Val Acc: 0.7671
# Epoch 158/200 - Train Loss: 0.5968, Train Acc: 0.7991, Val Loss: 0.7423, Val Acc: 0.7740
# Epoch 159/200 - Train Loss: 0.5974, Train Acc: 0.7845, Val Loss: 0.7465, Val Acc: 0.7945
# Epoch 160/200 - Train Loss: 0.5894, Train Acc: 0.7955, Val Loss: 0.7396, Val Acc: 0.7671
# Epoch 161/200 - Train Loss: 0.5934, Train Acc: 0.7603, Val Loss: 0.7408, Val Acc: 0.7842
# Epoch 162/200 - Train Loss: 0.5796, Train Acc: 0.7999, Val Loss: 0.7340, Val Acc: 0.7705
# Epoch 163/200 - Train Loss: 0.5797, Train Acc: 0.7735, Val Loss: 0.7552, Val Acc: 0.8219
# Epoch 164/200 - Train Loss: 0.6029, Train Acc: 0.7837, Val Loss: 0.7431, Val Acc: 0.7671
# Epoch 165/200 - Train Loss: 0.6024, Train Acc: 0.7786, Val Loss: 0.7399, Val Acc: 0.7705
# Epoch 166/200 - Train Loss: 0.5993, Train Acc: 0.7654, Val Loss: 0.7454, Val Acc: 0.7877
# Epoch 167/200 - Train Loss: 0.5944, Train Acc: 0.7947, Val Loss: 0.7460, Val Acc: 0.7877
# Epoch 168/200 - Train Loss: 0.5881, Train Acc: 0.8043, Val Loss: 0.7321, Val Acc: 0.7808
# Epoch 169/200 - Train Loss: 0.5598, Train Acc: 0.8065, Val Loss: 0.7366, Val Acc: 0.7705
# Epoch 170/200 - Train Loss: 0.5963, Train Acc: 0.7610, Val Loss: 0.7398, Val Acc: 0.7774
# Epoch 171/200 - Train Loss: 0.5901, Train Acc: 0.7867, Val Loss: 0.7475, Val Acc: 0.7979
# Epoch 172/200 - Train Loss: 0.6026, Train Acc: 0.7889, Val Loss: 0.7331, Val Acc: 0.7603
# Epoch 173/200 - Train Loss: 0.5937, Train Acc: 0.7867, Val Loss: 0.7353, Val Acc: 0.7740
# Epoch 174/200 - Train Loss: 0.5913, Train Acc: 0.7720, Val Loss: 0.7369, Val Acc: 0.7705
# Epoch 175/200 - Train Loss: 0.5781, Train Acc: 0.8043, Val Loss: 0.7358, Val Acc: 0.7671
# Epoch 176/200 - Train Loss: 0.6252, Train Acc: 0.7397, Val Loss: 0.7422, Val Acc: 0.7808
# Epoch 177/200 - Train Loss: 0.5912, Train Acc: 0.7896, Val Loss: 0.7358, Val Acc: 0.7637
# Epoch 178/200 - Train Loss: 0.5809, Train Acc: 0.7771, Val Loss: 0.7386, Val Acc: 0.7774
# Epoch 179/200 - Train Loss: 0.5799, Train Acc: 0.7962, Val Loss: 0.7482, Val Acc: 0.8014
# Epoch 180/200 - Train Loss: 0.5847, Train Acc: 0.7793, Val Loss: 0.7419, Val Acc: 0.7774
# Epoch 181/200 - Train Loss: 0.5925, Train Acc: 0.7757, Val Loss: 0.7395, Val Acc: 0.7740
# Epoch 182/200 - Train Loss: 0.5766, Train Acc: 0.7925, Val Loss: 0.7440, Val Acc: 0.7877
# Epoch 183/200 - Train Loss: 0.5929, Train Acc: 0.7793, Val Loss: 0.7348, Val Acc: 0.7740
# Epoch 184/200 - Train Loss: 0.5636, Train Acc: 0.8050, Val Loss: 0.7388, Val Acc: 0.7842
# Epoch 185/200 - Train Loss: 0.5605, Train Acc: 0.7962, Val Loss: 0.7484, Val Acc: 0.7911
# Epoch 186/200 - Train Loss: 0.5626, Train Acc: 0.7911, Val Loss: 0.7468, Val Acc: 0.7911
# Epoch 187/200 - Train Loss: 0.5722, Train Acc: 0.8035, Val Loss: 0.7416, Val Acc: 0.7740
# Epoch 188/200 - Train Loss: 0.5833, Train Acc: 0.8028, Val Loss: 0.7465, Val Acc: 0.7808
# Epoch 189/200 - Train Loss: 0.5947, Train Acc: 0.7852, Val Loss: 0.7447, Val Acc: 0.7979
# Epoch 190/200 - Train Loss: 0.5902, Train Acc: 0.7903, Val Loss: 0.7374, Val Acc: 0.7740
# Epoch 191/200 - Train Loss: 0.5609, Train Acc: 0.7962, Val Loss: 0.7347, Val Acc: 0.7705
# Epoch 192/200 - Train Loss: 0.5975, Train Acc: 0.7808, Val Loss: 0.7380, Val Acc: 0.7705
# Epoch 193/200 - Train Loss: 0.5698, Train Acc: 0.8087, Val Loss: 0.7374, Val Acc: 0.7671
# Epoch 194/200 - Train Loss: 0.5692, Train Acc: 0.7918, Val Loss: 0.7347, Val Acc: 0.7603
# Epoch 195/200 - Train Loss: 0.5742, Train Acc: 0.8050, Val Loss: 0.7396, Val Acc: 0.7568
# Epoch 196/200 - Train Loss: 0.5808, Train Acc: 0.7830, Val Loss: 0.7360, Val Acc: 0.7568
# Epoch 197/200 - Train Loss: 0.5660, Train Acc: 0.7933, Val Loss: 0.7345, Val Acc: 0.7774
# Epoch 198/200 - Train Loss: 0.5870, Train Acc: 0.7544, Val Loss: 0.7440, Val Acc: 0.7671
# Epoch 199/200 - Train Loss: 0.5700, Train Acc: 0.7955, Val Loss: 0.7359, Val Acc: 0.7671
# Epoch 200/200 - Train Loss: 0.5742, Train Acc: 0.7830, Val Loss: 0.7346, Val Acc: 0.7637

# %%
import torch
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

def get_predictions_and_labels(model, loader, device):
    model.eval()  
    predictions = []
    labels = []
    with torch.no_grad():
        for inputs, actuals in loader:
            inputs = inputs.to(device)
            actuals = actuals.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            predictions.extend(preds.cpu().numpy())
            labels.extend(actuals.cpu().numpy())
    return predictions, labels


val_predictions, val_labels = get_predictions_and_labels(trained_model, val_loader, device)

# %%
def plot_training_history(history):
    epochs = range(1, len(history['train_loss']) + 1)

    
    train_losses = [x.cpu().numpy() if torch.is_tensor(x) else x for x in history['train_loss']]
    val_losses = [x.cpu().numpy() if torch.is_tensor(x) else x for x in history['val_loss']]
    train_accs = [x.cpu().numpy() if torch.is_tensor(x) else x for x in history['train_acc']]
    val_accs = [x.cpu().numpy() if torch.is_tensor(x) else x for x in history['val_acc']]

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.plot(epochs, val_losses, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.ylim(0, 1.5)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accs, label='Train Accuracy')
    plt.plot(epochs, val_accs, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.ylim(0, 1)
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()
plot_training_history(training_history)

# %% [markdown]
# # TEST SET

# %%
import os
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import copy
from sklearn.metrics import roc_auc_score, balanced_accuracy_score, recall_score, precision_score



device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = torch.load('/Mineral/E1.path')
model.to(device)
criterion = torch.nn.CrossEntropyLoss()

img_dir_al = '/Mineral/Enhanced-Al-S'
img_dir_ca = '/Mineral/Ca-S'
img_dir_mg = '/Mineral/Mg-S'
test_csv = '/Mineral/test_split.csv'

test_dataset = MineralDataset(img_dir_al, img_dir_ca, img_dir_mg, test_csv, transform=transform_test)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

def evaluate_model(model, data_loader, criterion, device):
    model.eval()  
    all_probs = []
    all_labels = []
    all_losses = []

    with torch.no_grad():  
        for inputs, labels in data_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            probabilities = torch.softmax(outputs, dim=1)
            all_probs.append(probabilities.cpu().numpy())
            all_labels.append(labels.cpu().numpy())
            all_losses.append(loss.cpu().numpy())

    all_probs = np.concatenate(all_probs)
    all_labels = np.concatenate(all_labels)
    all_losses = np.array(all_losses)
    return all_probs, all_labels, all_losses

def bootstrap_metric(y_true, y_prob, metric_func, n_bootstrap=1000, alpha=0.05, **kwargs):
    rng = np.random.default_rng()
    indices = np.arange(len(y_true))
    bootstrapped_scores = []
    for _ in range(n_bootstrap):
        sample_indices = rng.choice(indices, size=len(indices), replace=True)
        if metric_func == roc_auc_score:
            score = metric_func(y_true[sample_indices], y_prob[sample_indices], **kwargs)
        else:
            y_pred = np.argmax(y_prob[sample_indices], axis=1)
            score = metric_func(y_true[sample_indices], y_pred, **kwargs)
        bootstrapped_scores.append(score)
    sorted_scores = np.sort(bootstrapped_scores)
    ci_lower = sorted_scores[int((alpha/2) * n_bootstrap)]
    ci_upper = sorted_scores[int((1 - alpha/2) * n_bootstrap)]
    return np.mean(bootstrapped_scores), ci_lower, ci_upper

def bootstrap_loss(losses, n_bootstrap=1000, alpha=0.05):
    rng = np.random.default_rng()
    indices = np.arange(len(losses))
    bootstrapped_losses = []
    for _ in range(n_bootstrap):
        sample_indices = rng.choice(indices, size=len(indices), replace=True)
        sample_loss = losses[sample_indices]
        bootstrapped_losses.append(np.mean(sample_loss))
    sorted_losses = np.sort(bootstrapped_losses)
    ci_lower = sorted_losses[int((alpha/2) * n_bootstrap)]
    ci_upper = sorted_losses[int((1 - alpha/2) * n_bootstrap)]
    return np.mean(bootstrapped_losses), ci_lower, ci_upper

test_probs, test_labels, test_losses = evaluate_model(model, test_loader, criterion, device)

# 95% CI Calculation
class_labels = np.unique(test_labels)
metrics = {}
for class_label in class_labels:
    auc_roc_mean, auc_roc_ci_low, auc_roc_ci_high = bootstrap_metric(test_labels == class_label, test_probs[:, class_label], roc_auc_score)
    balanced_acc_mean, balanced_acc_ci_low, balanced_acc_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: balanced_accuracy_score(y_true == class_label, y_pred == class_label))
    sensitivity_mean, sensitivity_ci_low, sensitivity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: recall_score(y_true == class_label, y_pred == class_label, zero_division=0))
    specificity_mean, specificity_ci_low, specificity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: precision_score(y_true == class_label, y_pred == class_label, zero_division=0))

    metrics[class_label] = {
        "AUC-ROC": (auc_roc_mean, auc_roc_ci_low, auc_roc_ci_high),
        "Balanced Accuracy": (balanced_acc_mean, balanced_acc_ci_low, balanced_acc_ci_high),
        "Sensitivity": (sensitivity_mean, sensitivity_ci_low, sensitivity_ci_high),
        "Specificity": (specificity_mean, specificity_ci_low, specificity_ci_high)
    }

print("Class\t\tAUC-ROC\t\t\tBalanced Accuracy\tSensitivity\t\tSpecificity")
for class_label, metric_values in metrics.items():
    auc_roc = metric_values["AUC-ROC"]
    balanced_acc = metric_values["Balanced Accuracy"]
    sensitivity = metric_values["Sensitivity"]
    specificity = metric_values["Specificity"]
    print(f"{class_label}\t\t{auc_roc[0]:.2f} ({auc_roc[1]:.2f}-{auc_roc[2]:.2f})\t"
          f"{balanced_acc[0]:.2f} ({balanced_acc[1]:.2f}-{balanced_acc[2]:.2f})\t"
          f"{sensitivity[0]:.2f} ({sensitivity[1]:.2f}-{sensitivity[2]:.2f})\t"
          f"{specificity[0]:.2f} ({specificity[1]:.2f}-{specificity[2]:.2f})")

auc_roc_mean, auc_roc_ci_low, auc_roc_ci_high = bootstrap_metric(test_labels, test_probs, roc_auc_score, multi_class='ovr')
balanced_acc_mean, balanced_acc_ci_low, balanced_acc_ci_high = bootstrap_metric(test_labels, test_probs, balanced_accuracy_score)
sensitivity_mean, sensitivity_ci_low, sensitivity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: recall_score(y_true, y_pred, average='macro', zero_division=0))
specificity_mean, specificity_ci_low, specificity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, y_pred: precision_score(y_true, y_pred, average='macro', zero_division=0))


loss_mean, loss_ci_low, loss_ci_high = bootstrap_loss(test_losses)

print(f"Overall\t\t{auc_roc_mean:.2f} ({auc_roc_ci_low:.2f}-{auc_roc_ci_high:.2f})\t"
      f"{balanced_acc_mean:.2f} ({balanced_acc_ci_low:.2f}-{balanced_acc_ci_high:.2f})\t"
      f"{sensitivity_mean:.2f} ({sensitivity_ci_low:.2f}-{sensitivity_ci_high:.2f})\t"
      f"{specificity_mean:.2f} ({specificity_ci_low:.2f}-{specificity_ci_high:.2f})")
print(f"Loss\t\t{loss_mean:.4f} ({loss_ci_low:.4f}-{loss_ci_high:.4f})")
# Out:
# Class		AUC-ROC			Balanced Accuracy	Sensitivity		Specificity
# 0		0.93 (0.89-0.96)	0.86 (0.82-0.90)	0.81 (0.73-0.89)	0.82 (0.74-0.90)
# 1		0.89 (0.85-0.93)	0.82 (0.77-0.86)	0.79 (0.72-0.85)	0.88 (0.83-0.93)
# 2		0.68 (0.57-0.79)	0.60 (0.51-0.70)	0.33 (0.16-0.52)	0.19 (0.09-0.30)
# Overall		0.83 (0.79-0.88)	0.65 (0.58-0.72)	0.65 (0.57-0.72)	0.63 (0.59-0.68)
# Loss		0.6279 (0.5258-0.7413)

# %%
import torch
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

def get_predictions_and_labels(model, test_loader, device):
    model.eval() 
    predictions = []
    labels = []
    with torch.no_grad():
        for inputs, actuals in test_loader:
            inputs = inputs.to(device)
            actuals = actuals.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            predictions.extend(preds.cpu().numpy())
            labels.extend(actuals.cpu().numpy())
    return predictions, labels

test_predictions, test_labels = get_predictions_and_labels(trained_model, test_loader, device)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

test_predictions, test_labels = get_predictions_and_labels(trained_model, test_loader, device)

cm = confusion_matrix(test_labels, test_predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

print(classification_report(test_labels, test_predictions, target_names=['Class 0', 'Class 1', 'Class 2']))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.81      0.82        96
#      Class 1       0.88      0.79      0.83       170
#      Class 2       0.20      0.33      0.25        27
#
#     accuracy                           0.75       293
#    macro avg       0.63      0.64      0.63       293
# weighted avg       0.80      0.75      0.77       293

# %%
import torch
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from itertools import cycle

def evaluate_model_for_roc(model, test_loader, device='cuda'):
    model.to(device)
    model.eval()

    all_preds_prob = []
    all_labels = []

    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        with torch.no_grad():
            outputs = model(inputs)
            probs = torch.nn.functional.softmax(outputs, dim=1)
            all_preds_prob.append(probs.cpu().numpy())
            all_labels.append(labels.cpu().numpy())

    all_preds_prob = np.concatenate(all_preds_prob)
    all_labels = np.concatenate(all_labels)

    return all_preds_prob, all_labels

num_classes = 3
all_preds_prob, all_labels = evaluate_model_for_roc(trained_model, test_loader, device=device)
all_labels_one_hot = label_binarize(all_labels, classes=[0, 1, 2])

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(all_labels_one_hot[:, i], all_preds_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

colors = cycle(['blue', 'red', 'green'])
for i, color in zip(range(num_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.2f})'.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-class ROC')
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt

def get_predictions(model, test_loader, device):
    model.eval()  # Set the model to evaluation mode
    predictions = []
    true_labels = []

    with torch.no_grad():  # Disable gradient calculation for efficiency
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            outputs = model(inputs)
            probs = torch.nn.functional.softmax(outputs, dim=1)  # Convert logits to probabilities
            predictions.extend(probs.cpu().numpy())
            true_labels.extend(labels.cpu().numpy())

    return np.array(predictions), np.array(true_labels)

# Get predictions and true labels
predictions, true_labels = get_predictions(model, test_loader, device)

# Plotting the distribution of probabilities using histograms
plt.figure(figsize=(6, 4))
bins = np.linspace(0, 1, 30)  # Define bin edges for histograms
for class_index in range(num_classes):
    plt.hist(predictions[:, class_index], bins=bins, alpha=0.5, label=f'Class {class_index}')
plt.title('Distribution of Predicted Probabilities')
plt.xlabel('Probability')
plt.ylabel('Frequency')
plt.legend()
plt.show()
