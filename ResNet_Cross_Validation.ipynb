# %%
import os
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms, models
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import KFold
from scipy.stats import sem, t
import numpy as np
import copy

class MineralDataset(Dataset):
    def __init__(self, img_dir, dataframe, transform=None):
        self.dataframe = dataframe
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        file_name = row['Segmented Filename']
        label = row['Class']
        img_path = os.path.join(self.img_dir, file_name)
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label

transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transform_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

IMAGE_DIR = '/Mineral/CPX seg'
TRAIN_SPLIT_FILE = '/Mineral/train_split.csv'
VAL_SPLIT_FILE = '/Mineral/val_split.csv'
train_data = pd.read_csv(TRAIN_SPLIT_FILE)
val_data = pd.read_csv(VAL_SPLIT_FILE)
#Complete training set
data = pd.concat([train_data, val_data], ignore_index=True)

dataset = MineralDataset(
    img_dir=IMAGE_DIR,
    dataframe=data,
    transform=None 
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def initialize_model(num_classes=3):
    model = models.resnet34(pretrained=True)
    for param in model.parameters():
        param.requires_grad = False
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, num_classes)
    model = model.to(device)
    return model

def train_and_evaluate_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=100, device='cuda'):
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    history = {
        'train_loss': [],
        'train_acc': [],
        'val_loss': [],
        'val_acc': []
    }

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        train_corrects = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            train_corrects += torch.sum(preds == labels.data).item()

        train_loss = train_loss / len(train_loader.dataset)
        train_acc = train_corrects / len(train_loader.dataset)
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)

        model.eval()
        val_loss = 0.0
        val_corrects = 0

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * inputs.size(0)
                _, preds = torch.max(outputs, 1)
                val_corrects += torch.sum(preds == labels.data).item()

        val_loss = val_loss / len(val_loader.dataset)
        val_acc = val_corrects / len(val_loader.dataset)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)

        print(f'Epoch {epoch+1}/{num_epochs}: Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')

        if val_acc > best_acc:
            best_acc = val_acc
            best_model_wts = copy.deepcopy(model.state_dict())

    model.load_state_dict(best_model_wts)
    return model, history

# K-fold training, set 100 epochs to allow model convergent on each fold
kf = KFold(n_splits=5, shuffle=True, random_state=42)
num_epochs = 100

for fold, (train_idx, val_idx) in enumerate(kf.split(dataset)):
    print(f"Fold {fold+1}")

    
    train_subset = Subset(dataset, train_idx)
    val_subset = Subset(dataset, val_idx)

 
    train_subset.dataset.transform = transform_train
    val_subset.dataset.transform = transform_val

  
    train_loader = DataLoader(train_subset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)

    labels = [dataset[idx][1] for idx in train_idx]
    classes = np.unique(labels)
    class_weights = compute_class_weight('balanced', classes=classes, y=labels)
    class_weights_tensor = torch.tensor(class_weights, dtype=torch.float).to(device)

    model = initialize_model(num_classes=3)
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
    optimizer = optim.Adam(model.fc.parameters(), lr=0.0001)

    trained_model, history = train_and_evaluate_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=num_epochs, device=device)


    torch.save(trained_model, f'/Mineral/complete_model_fold_{fold+1}.pth')

    print(f"Fold {fold+1} - Train Loss: {history['train_loss'][-1]:.4f}, Train Accuracy: {history['train_acc'][-1]:.2f}%, Val Loss: {history['val_loss'][-1]:.4f}, Val Accuracy: {history['val_acc'][-1]:.2f}%")
# Out:
# Fold 1
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/100: Train Loss: 1.2235, Train Acc: 0.2515, Val Loss: 1.1629, Val Acc: 0.3193
# Epoch 2/100: Train Loss: 1.1353, Train Acc: 0.3678, Val Loss: 1.0964, Val Acc: 0.4066
# Epoch 3/100: Train Loss: 1.0598, Train Acc: 0.4441, Val Loss: 1.0379, Val Acc: 0.4940
# Epoch 4/100: Train Loss: 1.0090, Train Acc: 0.5363, Val Loss: 0.9779, Val Acc: 0.6235
# Epoch 5/100: Train Loss: 0.9674, Train Acc: 0.5665, Val Loss: 0.9457, Val Acc: 0.6024
# Epoch 6/100: Train Loss: 0.9331, Train Acc: 0.6329, Val Loss: 0.9146, Val Acc: 0.6205
# Epoch 7/100: Train Loss: 0.9014, Train Acc: 0.6556, Val Loss: 0.8932, Val Acc: 0.6386
# Epoch 8/100: Train Loss: 0.8664, Train Acc: 0.6881, Val Loss: 0.8637, Val Acc: 0.6988
# Epoch 9/100: Train Loss: 0.8396, Train Acc: 0.6911, Val Loss: 0.8484, Val Acc: 0.7078
# Epoch 10/100: Train Loss: 0.8235, Train Acc: 0.7054, Val Loss: 0.8296, Val Acc: 0.7078
# Epoch 11/100: Train Loss: 0.8001, Train Acc: 0.7122, Val Loss: 0.8186, Val Acc: 0.6807
# Epoch 12/100: Train Loss: 0.7776, Train Acc: 0.7243, Val Loss: 0.7999, Val Acc: 0.7440
# Epoch 13/100: Train Loss: 0.7751, Train Acc: 0.7205, Val Loss: 0.7923, Val Acc: 0.7199
# Epoch 14/100: Train Loss: 0.7576, Train Acc: 0.7470, Val Loss: 0.7841, Val Acc: 0.7018
# Epoch 15/100: Train Loss: 0.7428, Train Acc: 0.7160, Val Loss: 0.7701, Val Acc: 0.7440
# Epoch 16/100: Train Loss: 0.7317, Train Acc: 0.7492, Val Loss: 0.7708, Val Acc: 0.6988
# Epoch 17/100: Train Loss: 0.7276, Train Acc: 0.7289, Val Loss: 0.7620, Val Acc: 0.7259
# Epoch 18/100: Train Loss: 0.7144, Train Acc: 0.7492, Val Loss: 0.7475, Val Acc: 0.7500
# Epoch 19/100: Train Loss: 0.7065, Train Acc: 0.7372, Val Loss: 0.7491, Val Acc: 0.7048
# Epoch 20/100: Train Loss: 0.6927, Train Acc: 0.7621, Val Loss: 0.7400, Val Acc: 0.7349
# Epoch 21/100: Train Loss: 0.6938, Train Acc: 0.7273, Val Loss: 0.7358, Val Acc: 0.7620
# Epoch 22/100: Train Loss: 0.6881, Train Acc: 0.7734, Val Loss: 0.7326, Val Acc: 0.7470
# Epoch 23/100: Train Loss: 0.6851, Train Acc: 0.7183, Val Loss: 0.7247, Val Acc: 0.7470
# Epoch 24/100: Train Loss: 0.6690, Train Acc: 0.7681, Val Loss: 0.7181, Val Acc: 0.7349
# Epoch 25/100: Train Loss: 0.6625, Train Acc: 0.7538, Val Loss: 0.7216, Val Acc: 0.7259
# Epoch 26/100: Train Loss: 0.6569, Train Acc: 0.7727, Val Loss: 0.7120, Val Acc: 0.7440
# Epoch 27/100: Train Loss: 0.6476, Train Acc: 0.7878, Val Loss: 0.7125, Val Acc: 0.7139
# Epoch 28/100: Train Loss: 0.6424, Train Acc: 0.7674, Val Loss: 0.7123, Val Acc: 0.7169
# Epoch 29/100: Train Loss: 0.6435, Train Acc: 0.7832, Val Loss: 0.7085, Val Acc: 0.7199
# Epoch 30/100: Train Loss: 0.6362, Train Acc: 0.7485, Val Loss: 0.7075, Val Acc: 0.7289
# Epoch 31/100: Train Loss: 0.6206, Train Acc: 0.7681, Val Loss: 0.6981, Val Acc: 0.7530
# Epoch 32/100: Train Loss: 0.6389, Train Acc: 0.7840, Val Loss: 0.6986, Val Acc: 0.7530
# Epoch 33/100: Train Loss: 0.6126, Train Acc: 0.7757, Val Loss: 0.7004, Val Acc: 0.7108
# Epoch 34/100: Train Loss: 0.6180, Train Acc: 0.7893, Val Loss: 0.6926, Val Acc: 0.7289
# Epoch 35/100: Train Loss: 0.6262, Train Acc: 0.7779, Val Loss: 0.6953, Val Acc: 0.7349
# Epoch 36/100: Train Loss: 0.6137, Train Acc: 0.7598, Val Loss: 0.6913, Val Acc: 0.7590
# Epoch 37/100: Train Loss: 0.6119, Train Acc: 0.7961, Val Loss: 0.6885, Val Acc: 0.7289
# Epoch 38/100: Train Loss: 0.6030, Train Acc: 0.7734, Val Loss: 0.6884, Val Acc: 0.7681
# Epoch 39/100: Train Loss: 0.6080, Train Acc: 0.7915, Val Loss: 0.6891, Val Acc: 0.7470
# Epoch 40/100: Train Loss: 0.5999, Train Acc: 0.7817, Val Loss: 0.6835, Val Acc: 0.7651
# Epoch 41/100: Train Loss: 0.5968, Train Acc: 0.7998, Val Loss: 0.6839, Val Acc: 0.7500
# Epoch 42/100: Train Loss: 0.5944, Train Acc: 0.7968, Val Loss: 0.6841, Val Acc: 0.7229
# Epoch 43/100: Train Loss: 0.6059, Train Acc: 0.7757, Val Loss: 0.6864, Val Acc: 0.7681
# Epoch 44/100: Train Loss: 0.5773, Train Acc: 0.8014, Val Loss: 0.6832, Val Acc: 0.7440
# Epoch 45/100: Train Loss: 0.5904, Train Acc: 0.7863, Val Loss: 0.6792, Val Acc: 0.7530
# Epoch 46/100: Train Loss: 0.5793, Train Acc: 0.8074, Val Loss: 0.6807, Val Acc: 0.7380
# Epoch 47/100: Train Loss: 0.5848, Train Acc: 0.7674, Val Loss: 0.6848, Val Acc: 0.7711
# Epoch 48/100: Train Loss: 0.5820, Train Acc: 0.8021, Val Loss: 0.6786, Val Acc: 0.7169
# Epoch 49/100: Train Loss: 0.5771, Train Acc: 0.7900, Val Loss: 0.6768, Val Acc: 0.7349
# Epoch 50/100: Train Loss: 0.5763, Train Acc: 0.7900, Val Loss: 0.6725, Val Acc: 0.7500
# Epoch 51/100: Train Loss: 0.5653, Train Acc: 0.7998, Val Loss: 0.6767, Val Acc: 0.7741
# Epoch 52/100: Train Loss: 0.5723, Train Acc: 0.7923, Val Loss: 0.6725, Val Acc: 0.7681
# Epoch 53/100: Train Loss: 0.5658, Train Acc: 0.7870, Val Loss: 0.6771, Val Acc: 0.7530
# Epoch 54/100: Train Loss: 0.5645, Train Acc: 0.7893, Val Loss: 0.6745, Val Acc: 0.7620
# Epoch 55/100: Train Loss: 0.5531, Train Acc: 0.7938, Val Loss: 0.6783, Val Acc: 0.7380
# Epoch 56/100: Train Loss: 0.5576, Train Acc: 0.8089, Val Loss: 0.6752, Val Acc: 0.7530
# Epoch 57/100: Train Loss: 0.5569, Train Acc: 0.8066, Val Loss: 0.6742, Val Acc: 0.7349
# Epoch 58/100: Train Loss: 0.5557, Train Acc: 0.8036, Val Loss: 0.6727, Val Acc: 0.7560
# Epoch 59/100: Train Loss: 0.5428, Train Acc: 0.8248, Val Loss: 0.6733, Val Acc: 0.7259
# Epoch 60/100: Train Loss: 0.5488, Train Acc: 0.7915, Val Loss: 0.6737, Val Acc: 0.7651
# Epoch 61/100: Train Loss: 0.5394, Train Acc: 0.8210, Val Loss: 0.6743, Val Acc: 0.7380
# Epoch 62/100: Train Loss: 0.5409, Train Acc: 0.7976, Val Loss: 0.6730, Val Acc: 0.7440
# Epoch 63/100: Train Loss: 0.5465, Train Acc: 0.8059, Val Loss: 0.6717, Val Acc: 0.7440
# Epoch 64/100: Train Loss: 0.5391, Train Acc: 0.7938, Val Loss: 0.6714, Val Acc: 0.7982
# Epoch 65/100: Train Loss: 0.5447, Train Acc: 0.8021, Val Loss: 0.6682, Val Acc: 0.7801
# Epoch 66/100: Train Loss: 0.5383, Train Acc: 0.8278, Val Loss: 0.6633, Val Acc: 0.7771
# Epoch 67/100: Train Loss: 0.5338, Train Acc: 0.8127, Val Loss: 0.6684, Val Acc: 0.7530
# Epoch 68/100: Train Loss: 0.5421, Train Acc: 0.8119, Val Loss: 0.6688, Val Acc: 0.7892
# Epoch 69/100: Train Loss: 0.5275, Train Acc: 0.8210, Val Loss: 0.6684, Val Acc: 0.7651
# Epoch 70/100: Train Loss: 0.5302, Train Acc: 0.8059, Val Loss: 0.6735, Val Acc: 0.7711
# Epoch 71/100: Train Loss: 0.5282, Train Acc: 0.8142, Val Loss: 0.6674, Val Acc: 0.7530
# Epoch 72/100: Train Loss: 0.5232, Train Acc: 0.8134, Val Loss: 0.6700, Val Acc: 0.7620
# Epoch 73/100: Train Loss: 0.5208, Train Acc: 0.8142, Val Loss: 0.6700, Val Acc: 0.7590
# Epoch 74/100: Train Loss: 0.5304, Train Acc: 0.8112, Val Loss: 0.6702, Val Acc: 0.7711
# Epoch 75/100: Train Loss: 0.5133, Train Acc: 0.8293, Val Loss: 0.6710, Val Acc: 0.7440
# Epoch 76/100: Train Loss: 0.5248, Train Acc: 0.7885, Val Loss: 0.6659, Val Acc: 0.7771
# Epoch 77/100: Train Loss: 0.5202, Train Acc: 0.8225, Val Loss: 0.6640, Val Acc: 0.7590
# Epoch 78/100: Train Loss: 0.5240, Train Acc: 0.7938, Val Loss: 0.6721, Val Acc: 0.7711
# Epoch 79/100: Train Loss: 0.5037, Train Acc: 0.8210, Val Loss: 0.6690, Val Acc: 0.7530
# Epoch 80/100: Train Loss: 0.5161, Train Acc: 0.8270, Val Loss: 0.6707, Val Acc: 0.7349
# Epoch 81/100: Train Loss: 0.5118, Train Acc: 0.7953, Val Loss: 0.6642, Val Acc: 0.7801
# Epoch 82/100: Train Loss: 0.5028, Train Acc: 0.8285, Val Loss: 0.6696, Val Acc: 0.7620
# Epoch 83/100: Train Loss: 0.5147, Train Acc: 0.8210, Val Loss: 0.6719, Val Acc: 0.7922
# Epoch 84/100: Train Loss: 0.4938, Train Acc: 0.8444, Val Loss: 0.6663, Val Acc: 0.7500
# Epoch 85/100: Train Loss: 0.5041, Train Acc: 0.8104, Val Loss: 0.6730, Val Acc: 0.8042
# Epoch 86/100: Train Loss: 0.4972, Train Acc: 0.8233, Val Loss: 0.6731, Val Acc: 0.7651
# Epoch 87/100: Train Loss: 0.4986, Train Acc: 0.8255, Val Loss: 0.6688, Val Acc: 0.7831
# Epoch 88/100: Train Loss: 0.5047, Train Acc: 0.8074, Val Loss: 0.6676, Val Acc: 0.8012
# Epoch 89/100: Train Loss: 0.4957, Train Acc: 0.8263, Val Loss: 0.6717, Val Acc: 0.7681
# Epoch 90/100: Train Loss: 0.4945, Train Acc: 0.8225, Val Loss: 0.6705, Val Acc: 0.7801
# Epoch 91/100: Train Loss: 0.5002, Train Acc: 0.8263, Val Loss: 0.6723, Val Acc: 0.7861
# Epoch 92/100: Train Loss: 0.4972, Train Acc: 0.8308, Val Loss: 0.6654, Val Acc: 0.7801
# Epoch 93/100: Train Loss: 0.4869, Train Acc: 0.8308, Val Loss: 0.6706, Val Acc: 0.7771
# Epoch 94/100: Train Loss: 0.4958, Train Acc: 0.8134, Val Loss: 0.6730, Val Acc: 0.7952
# Epoch 95/100: Train Loss: 0.4889, Train Acc: 0.8384, Val Loss: 0.6725, Val Acc: 0.7711
# Epoch 96/100: Train Loss: 0.4950, Train Acc: 0.8112, Val Loss: 0.6755, Val Acc: 0.7801
# Epoch 97/100: Train Loss: 0.4870, Train Acc: 0.8406, Val Loss: 0.6647, Val Acc: 0.7560
# Epoch 98/100: Train Loss: 0.4895, Train Acc: 0.8225, Val Loss: 0.6679, Val Acc: 0.7560
# Epoch 99/100: Train Loss: 0.4911, Train Acc: 0.8202, Val Loss: 0.6761, Val Acc: 0.7892
# Epoch 100/100: Train Loss: 0.4920, Train Acc: 0.8293, Val Loss: 0.6716, Val Acc: 0.7560
# Fold 1 - Train Loss: 0.4920, Train Accuracy: 0.83%, Val Loss: 0.6716, Val Accuracy: 0.76%
# Fold 2
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/100: Train Loss: 1.1211, Train Acc: 0.3449, Val Loss: 1.1034, Val Acc: 0.3353
# Epoch 2/100: Train Loss: 1.0360, Train Acc: 0.5094, Val Loss: 1.0091, Val Acc: 0.4713
# Epoch 3/100: Train Loss: 0.9855, Train Acc: 0.5796, Val Loss: 0.9745, Val Acc: 0.6435
# Epoch 4/100: Train Loss: 0.9385, Train Acc: 0.5864, Val Loss: 0.9327, Val Acc: 0.6526
# Epoch 5/100: Train Loss: 0.8940, Train Acc: 0.7026, Val Loss: 0.8999, Val Acc: 0.6858
# Epoch 6/100: Train Loss: 0.8746, Train Acc: 0.6770, Val Loss: 0.8743, Val Acc: 0.6888
# Epoch 7/100: Train Loss: 0.8469, Train Acc: 0.7336, Val Loss: 0.8487, Val Acc: 0.6828
# Epoch 8/100: Train Loss: 0.8268, Train Acc: 0.6981, Val Loss: 0.8349, Val Acc: 0.6918
# Epoch 9/100: Train Loss: 0.8090, Train Acc: 0.7072, Val Loss: 0.8203, Val Acc: 0.7190
# Epoch 10/100: Train Loss: 0.7968, Train Acc: 0.7298, Val Loss: 0.8004, Val Acc: 0.7100
# Epoch 11/100: Train Loss: 0.7717, Train Acc: 0.7419, Val Loss: 0.7906, Val Acc: 0.7100
# Epoch 12/100: Train Loss: 0.7591, Train Acc: 0.7298, Val Loss: 0.7855, Val Acc: 0.7160
# Epoch 13/100: Train Loss: 0.7457, Train Acc: 0.7555, Val Loss: 0.7713, Val Acc: 0.7221
# Epoch 14/100: Train Loss: 0.7267, Train Acc: 0.7600, Val Loss: 0.7671, Val Acc: 0.7523
# Epoch 15/100: Train Loss: 0.7243, Train Acc: 0.7577, Val Loss: 0.7575, Val Acc: 0.7281
# Epoch 16/100: Train Loss: 0.7089, Train Acc: 0.7502, Val Loss: 0.7498, Val Acc: 0.7492
# Epoch 17/100: Train Loss: 0.7102, Train Acc: 0.7404, Val Loss: 0.7428, Val Acc: 0.7402
# Epoch 18/100: Train Loss: 0.6914, Train Acc: 0.7600, Val Loss: 0.7325, Val Acc: 0.7583
# Epoch 19/100: Train Loss: 0.7023, Train Acc: 0.7555, Val Loss: 0.7219, Val Acc: 0.7221
# Epoch 20/100: Train Loss: 0.6865, Train Acc: 0.7653, Val Loss: 0.7317, Val Acc: 0.7311
# Epoch 21/100: Train Loss: 0.6732, Train Acc: 0.7811, Val Loss: 0.7245, Val Acc: 0.7311
# Epoch 22/100: Train Loss: 0.6744, Train Acc: 0.7623, Val Loss: 0.7206, Val Acc: 0.7311
# Epoch 23/100: Train Loss: 0.6569, Train Acc: 0.7977, Val Loss: 0.7149, Val Acc: 0.7462
# Epoch 24/100: Train Loss: 0.6486, Train Acc: 0.7879, Val Loss: 0.7095, Val Acc: 0.7492
# Epoch 25/100: Train Loss: 0.6487, Train Acc: 0.7615, Val Loss: 0.7234, Val Acc: 0.7825
# Epoch 26/100: Train Loss: 0.6435, Train Acc: 0.7826, Val Loss: 0.7140, Val Acc: 0.7372
# Epoch 27/100: Train Loss: 0.6397, Train Acc: 0.7932, Val Loss: 0.7063, Val Acc: 0.7432
# Epoch 28/100: Train Loss: 0.6371, Train Acc: 0.7683, Val Loss: 0.7028, Val Acc: 0.7402
# Epoch 29/100: Train Loss: 0.6360, Train Acc: 0.7940, Val Loss: 0.6973, Val Acc: 0.7372
# Epoch 30/100: Train Loss: 0.6267, Train Acc: 0.7804, Val Loss: 0.7056, Val Acc: 0.7583
# Epoch 31/100: Train Loss: 0.6189, Train Acc: 0.7781, Val Loss: 0.6957, Val Acc: 0.7372
# Epoch 32/100: Train Loss: 0.6203, Train Acc: 0.8091, Val Loss: 0.6921, Val Acc: 0.7462
# Epoch 33/100: Train Loss: 0.6095, Train Acc: 0.7826, Val Loss: 0.7046, Val Acc: 0.7946
# Epoch 34/100: Train Loss: 0.6099, Train Acc: 0.7834, Val Loss: 0.6944, Val Acc: 0.7644
# Epoch 35/100: Train Loss: 0.6060, Train Acc: 0.7826, Val Loss: 0.6989, Val Acc: 0.7462
# Epoch 36/100: Train Loss: 0.6027, Train Acc: 0.7887, Val Loss: 0.6962, Val Acc: 0.7795
# Epoch 37/100: Train Loss: 0.6004, Train Acc: 0.8091, Val Loss: 0.7021, Val Acc: 0.7644
# Epoch 38/100: Train Loss: 0.5976, Train Acc: 0.7909, Val Loss: 0.6957, Val Acc: 0.7523
# Epoch 39/100: Train Loss: 0.5870, Train Acc: 0.8015, Val Loss: 0.6956, Val Acc: 0.7613
# Epoch 40/100: Train Loss: 0.5942, Train Acc: 0.7834, Val Loss: 0.7026, Val Acc: 0.7704
# Epoch 41/100: Train Loss: 0.5796, Train Acc: 0.7864, Val Loss: 0.6986, Val Acc: 0.7553
# Epoch 42/100: Train Loss: 0.5886, Train Acc: 0.7985, Val Loss: 0.7034, Val Acc: 0.7704
# Epoch 43/100: Train Loss: 0.5649, Train Acc: 0.7977, Val Loss: 0.6954, Val Acc: 0.7523
# Epoch 44/100: Train Loss: 0.5807, Train Acc: 0.8181, Val Loss: 0.6959, Val Acc: 0.7583
# Epoch 45/100: Train Loss: 0.5758, Train Acc: 0.7917, Val Loss: 0.6839, Val Acc: 0.7583
# Epoch 46/100: Train Loss: 0.5719, Train Acc: 0.8075, Val Loss: 0.6879, Val Acc: 0.7462
# Epoch 47/100: Train Loss: 0.5642, Train Acc: 0.7970, Val Loss: 0.7002, Val Acc: 0.7734
# Epoch 48/100: Train Loss: 0.5680, Train Acc: 0.8151, Val Loss: 0.6847, Val Acc: 0.7341
# Epoch 49/100: Train Loss: 0.5606, Train Acc: 0.7872, Val Loss: 0.7076, Val Acc: 0.7915
# Epoch 50/100: Train Loss: 0.5691, Train Acc: 0.7849, Val Loss: 0.6950, Val Acc: 0.7523
# Epoch 51/100: Train Loss: 0.5707, Train Acc: 0.8211, Val Loss: 0.6917, Val Acc: 0.7372
# Epoch 52/100: Train Loss: 0.5639, Train Acc: 0.7992, Val Loss: 0.7016, Val Acc: 0.7855
# Epoch 53/100: Train Loss: 0.5518, Train Acc: 0.8113, Val Loss: 0.6896, Val Acc: 0.7583
# Epoch 54/100: Train Loss: 0.5476, Train Acc: 0.8242, Val Loss: 0.6853, Val Acc: 0.7372
# Epoch 55/100: Train Loss: 0.5441, Train Acc: 0.8106, Val Loss: 0.6940, Val Acc: 0.7795
# Epoch 56/100: Train Loss: 0.5599, Train Acc: 0.8053, Val Loss: 0.6986, Val Acc: 0.7553
# Epoch 57/100: Train Loss: 0.5400, Train Acc: 0.8038, Val Loss: 0.6809, Val Acc: 0.7583
# Epoch 58/100: Train Loss: 0.5356, Train Acc: 0.8219, Val Loss: 0.6886, Val Acc: 0.7372
# Epoch 59/100: Train Loss: 0.5418, Train Acc: 0.7985, Val Loss: 0.7170, Val Acc: 0.7885
# Epoch 60/100: Train Loss: 0.5413, Train Acc: 0.8279, Val Loss: 0.6879, Val Acc: 0.7221
# Epoch 61/100: Train Loss: 0.5498, Train Acc: 0.7962, Val Loss: 0.7064, Val Acc: 0.7734
# Epoch 62/100: Train Loss: 0.5370, Train Acc: 0.8257, Val Loss: 0.6968, Val Acc: 0.7402
# Epoch 63/100: Train Loss: 0.5296, Train Acc: 0.8309, Val Loss: 0.6963, Val Acc: 0.7492
# Epoch 64/100: Train Loss: 0.5210, Train Acc: 0.8075, Val Loss: 0.6989, Val Acc: 0.7613
# Epoch 65/100: Train Loss: 0.5223, Train Acc: 0.8242, Val Loss: 0.6965, Val Acc: 0.7553
# Epoch 66/100: Train Loss: 0.5275, Train Acc: 0.8234, Val Loss: 0.6910, Val Acc: 0.7432
# Epoch 67/100: Train Loss: 0.5255, Train Acc: 0.8106, Val Loss: 0.6981, Val Acc: 0.7523
# Epoch 68/100: Train Loss: 0.5106, Train Acc: 0.8174, Val Loss: 0.6958, Val Acc: 0.7523
# Epoch 69/100: Train Loss: 0.5288, Train Acc: 0.8309, Val Loss: 0.6946, Val Acc: 0.7523
# Epoch 70/100: Train Loss: 0.5152, Train Acc: 0.8234, Val Loss: 0.6974, Val Acc: 0.7523
# Epoch 71/100: Train Loss: 0.5167, Train Acc: 0.8158, Val Loss: 0.7084, Val Acc: 0.7583
# Epoch 72/100: Train Loss: 0.5376, Train Acc: 0.8158, Val Loss: 0.7216, Val Acc: 0.8066
# Epoch 73/100: Train Loss: 0.5138, Train Acc: 0.8279, Val Loss: 0.7031, Val Acc: 0.7734
# Epoch 74/100: Train Loss: 0.5066, Train Acc: 0.8287, Val Loss: 0.6918, Val Acc: 0.7462
# Epoch 75/100: Train Loss: 0.5253, Train Acc: 0.8106, Val Loss: 0.7224, Val Acc: 0.7915
# Epoch 76/100: Train Loss: 0.5105, Train Acc: 0.8370, Val Loss: 0.7119, Val Acc: 0.7674
# Epoch 77/100: Train Loss: 0.5027, Train Acc: 0.8317, Val Loss: 0.7155, Val Acc: 0.7795
# Epoch 78/100: Train Loss: 0.5058, Train Acc: 0.8294, Val Loss: 0.6924, Val Acc: 0.7462
# Epoch 79/100: Train Loss: 0.5128, Train Acc: 0.8196, Val Loss: 0.7076, Val Acc: 0.7583
# Epoch 80/100: Train Loss: 0.5150, Train Acc: 0.8294, Val Loss: 0.7019, Val Acc: 0.7492
# Epoch 81/100: Train Loss: 0.5204, Train Acc: 0.8196, Val Loss: 0.7037, Val Acc: 0.7644
# Epoch 82/100: Train Loss: 0.5033, Train Acc: 0.8249, Val Loss: 0.7044, Val Acc: 0.7583
# Epoch 83/100: Train Loss: 0.5038, Train Acc: 0.8204, Val Loss: 0.7032, Val Acc: 0.7432
# Epoch 84/100: Train Loss: 0.4937, Train Acc: 0.8302, Val Loss: 0.7170, Val Acc: 0.7553
# Epoch 85/100: Train Loss: 0.4970, Train Acc: 0.8264, Val Loss: 0.7069, Val Acc: 0.7523
# Epoch 86/100: Train Loss: 0.4951, Train Acc: 0.8249, Val Loss: 0.7156, Val Acc: 0.7583
# Epoch 87/100: Train Loss: 0.4971, Train Acc: 0.8521, Val Loss: 0.7115, Val Acc: 0.7492
# Epoch 88/100: Train Loss: 0.4821, Train Acc: 0.8226, Val Loss: 0.7191, Val Acc: 0.7825
# Epoch 89/100: Train Loss: 0.4877, Train Acc: 0.8475, Val Loss: 0.7156, Val Acc: 0.7372
# Epoch 90/100: Train Loss: 0.4880, Train Acc: 0.8362, Val Loss: 0.7173, Val Acc: 0.7553
# Epoch 91/100: Train Loss: 0.5016, Train Acc: 0.8226, Val Loss: 0.7024, Val Acc: 0.7764
# Epoch 92/100: Train Loss: 0.4853, Train Acc: 0.8438, Val Loss: 0.7135, Val Acc: 0.7583
# Epoch 93/100: Train Loss: 0.4944, Train Acc: 0.8226, Val Loss: 0.7075, Val Acc: 0.7492
# Epoch 94/100: Train Loss: 0.5010, Train Acc: 0.8234, Val Loss: 0.7157, Val Acc: 0.7644
# Epoch 95/100: Train Loss: 0.4971, Train Acc: 0.8279, Val Loss: 0.7241, Val Acc: 0.7674
# Epoch 96/100: Train Loss: 0.4804, Train Acc: 0.8249, Val Loss: 0.7318, Val Acc: 0.7734
# Epoch 97/100: Train Loss: 0.4818, Train Acc: 0.8491, Val Loss: 0.7072, Val Acc: 0.7523
# Epoch 98/100: Train Loss: 0.4898, Train Acc: 0.8272, Val Loss: 0.7084, Val Acc: 0.7855
# Epoch 99/100: Train Loss: 0.4738, Train Acc: 0.8370, Val Loss: 0.7043, Val Acc: 0.7402
# Epoch 100/100: Train Loss: 0.4780, Train Acc: 0.8332, Val Loss: 0.7302, Val Acc: 0.7462
# Fold 2 - Train Loss: 0.4780, Train Accuracy: 0.83%, Val Loss: 0.7302, Val Accuracy: 0.75%
# Fold 3
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/100: Train Loss: 1.1518, Train Acc: 0.3208, Val Loss: 1.1206, Val Acc: 0.3958
# Epoch 2/100: Train Loss: 1.0669, Train Acc: 0.4543, Val Loss: 1.0656, Val Acc: 0.5257
# Epoch 3/100: Train Loss: 1.0140, Train Acc: 0.5487, Val Loss: 1.0002, Val Acc: 0.6133
# Epoch 4/100: Train Loss: 0.9617, Train Acc: 0.5977, Val Loss: 0.9587, Val Acc: 0.6828
# Epoch 5/100: Train Loss: 0.9164, Train Acc: 0.6377, Val Loss: 0.9158, Val Acc: 0.7009
# Epoch 6/100: Train Loss: 0.8814, Train Acc: 0.6709, Val Loss: 0.8877, Val Acc: 0.7100
# Epoch 7/100: Train Loss: 0.8606, Train Acc: 0.7147, Val Loss: 0.8623, Val Acc: 0.7492
# Epoch 8/100: Train Loss: 0.8345, Train Acc: 0.6943, Val Loss: 0.8391, Val Acc: 0.7402
# Epoch 9/100: Train Loss: 0.8116, Train Acc: 0.7366, Val Loss: 0.8147, Val Acc: 0.7402
# Epoch 10/100: Train Loss: 0.7983, Train Acc: 0.7215, Val Loss: 0.8030, Val Acc: 0.7644
# Epoch 11/100: Train Loss: 0.7941, Train Acc: 0.7147, Val Loss: 0.7993, Val Acc: 0.7734
# Epoch 12/100: Train Loss: 0.7779, Train Acc: 0.7555, Val Loss: 0.7720, Val Acc: 0.7251
# Epoch 13/100: Train Loss: 0.7605, Train Acc: 0.7238, Val Loss: 0.7752, Val Acc: 0.7764
# Epoch 14/100: Train Loss: 0.7381, Train Acc: 0.7472, Val Loss: 0.7545, Val Acc: 0.7915
# Epoch 15/100: Train Loss: 0.7274, Train Acc: 0.7713, Val Loss: 0.7519, Val Acc: 0.7825
# Epoch 16/100: Train Loss: 0.7291, Train Acc: 0.7374, Val Loss: 0.7388, Val Acc: 0.7613
# Epoch 17/100: Train Loss: 0.7130, Train Acc: 0.7434, Val Loss: 0.7309, Val Acc: 0.7583
# Epoch 18/100: Train Loss: 0.7103, Train Acc: 0.7660, Val Loss: 0.7168, Val Acc: 0.7674
# Epoch 19/100: Train Loss: 0.6996, Train Acc: 0.7389, Val Loss: 0.7129, Val Acc: 0.7704
# Epoch 20/100: Train Loss: 0.6912, Train Acc: 0.7615, Val Loss: 0.7230, Val Acc: 0.7855
# Epoch 21/100: Train Loss: 0.6797, Train Acc: 0.7494, Val Loss: 0.7018, Val Acc: 0.7674
# Epoch 22/100: Train Loss: 0.6765, Train Acc: 0.7645, Val Loss: 0.7062, Val Acc: 0.7855
# Epoch 23/100: Train Loss: 0.6701, Train Acc: 0.7691, Val Loss: 0.6948, Val Acc: 0.7674
# Epoch 24/100: Train Loss: 0.6585, Train Acc: 0.7585, Val Loss: 0.7067, Val Acc: 0.7885
# Epoch 25/100: Train Loss: 0.6561, Train Acc: 0.7645, Val Loss: 0.6937, Val Acc: 0.7915
# Epoch 26/100: Train Loss: 0.6561, Train Acc: 0.7849, Val Loss: 0.6859, Val Acc: 0.7795
# Epoch 27/100: Train Loss: 0.6463, Train Acc: 0.7728, Val Loss: 0.6878, Val Acc: 0.7825
# Epoch 28/100: Train Loss: 0.6432, Train Acc: 0.7713, Val Loss: 0.6787, Val Acc: 0.7764
# Epoch 29/100: Train Loss: 0.6368, Train Acc: 0.7630, Val Loss: 0.6733, Val Acc: 0.7795
# Epoch 30/100: Train Loss: 0.6312, Train Acc: 0.7766, Val Loss: 0.6830, Val Acc: 0.7855
# Epoch 31/100: Train Loss: 0.6454, Train Acc: 0.7834, Val Loss: 0.6655, Val Acc: 0.7523
# Epoch 32/100: Train Loss: 0.6284, Train Acc: 0.7623, Val Loss: 0.6781, Val Acc: 0.8036
# Epoch 33/100: Train Loss: 0.6208, Train Acc: 0.7902, Val Loss: 0.6689, Val Acc: 0.7674
# Epoch 34/100: Train Loss: 0.6270, Train Acc: 0.7721, Val Loss: 0.6602, Val Acc: 0.7704
# Epoch 35/100: Train Loss: 0.6175, Train Acc: 0.7819, Val Loss: 0.6759, Val Acc: 0.7976
# Epoch 36/100: Train Loss: 0.6162, Train Acc: 0.7706, Val Loss: 0.6662, Val Acc: 0.7734
# Epoch 37/100: Train Loss: 0.6014, Train Acc: 0.7713, Val Loss: 0.6701, Val Acc: 0.7946
# Epoch 38/100: Train Loss: 0.6087, Train Acc: 0.7834, Val Loss: 0.6633, Val Acc: 0.7976
# Epoch 39/100: Train Loss: 0.6090, Train Acc: 0.7706, Val Loss: 0.6538, Val Acc: 0.7764
# Epoch 40/100: Train Loss: 0.5897, Train Acc: 0.7872, Val Loss: 0.6564, Val Acc: 0.7915
# Epoch 41/100: Train Loss: 0.6008, Train Acc: 0.7721, Val Loss: 0.6733, Val Acc: 0.7976
# Epoch 42/100: Train Loss: 0.6011, Train Acc: 0.7932, Val Loss: 0.6552, Val Acc: 0.7976
# Epoch 43/100: Train Loss: 0.5969, Train Acc: 0.7766, Val Loss: 0.6534, Val Acc: 0.7946
# Epoch 44/100: Train Loss: 0.5954, Train Acc: 0.7698, Val Loss: 0.6537, Val Acc: 0.7825
# Epoch 45/100: Train Loss: 0.5785, Train Acc: 0.7683, Val Loss: 0.6537, Val Acc: 0.7976
# Epoch 46/100: Train Loss: 0.5903, Train Acc: 0.8015, Val Loss: 0.6374, Val Acc: 0.7885
# Epoch 47/100: Train Loss: 0.5699, Train Acc: 0.7947, Val Loss: 0.6564, Val Acc: 0.8036
# Epoch 48/100: Train Loss: 0.5851, Train Acc: 0.7917, Val Loss: 0.6616, Val Acc: 0.8157
# Epoch 49/100: Train Loss: 0.5820, Train Acc: 0.7826, Val Loss: 0.6385, Val Acc: 0.7885
# Epoch 50/100: Train Loss: 0.5807, Train Acc: 0.8000, Val Loss: 0.6383, Val Acc: 0.7795
# Epoch 51/100: Train Loss: 0.5802, Train Acc: 0.7902, Val Loss: 0.6456, Val Acc: 0.7946
# Epoch 52/100: Train Loss: 0.5678, Train Acc: 0.8136, Val Loss: 0.6404, Val Acc: 0.7915
# Epoch 53/100: Train Loss: 0.5706, Train Acc: 0.8075, Val Loss: 0.6386, Val Acc: 0.7734
# Epoch 54/100: Train Loss: 0.5696, Train Acc: 0.7691, Val Loss: 0.6361, Val Acc: 0.7946
# Epoch 55/100: Train Loss: 0.5720, Train Acc: 0.7970, Val Loss: 0.6392, Val Acc: 0.7885
# Epoch 56/100: Train Loss: 0.5701, Train Acc: 0.7819, Val Loss: 0.6374, Val Acc: 0.7976
# Epoch 57/100: Train Loss: 0.5602, Train Acc: 0.8053, Val Loss: 0.6431, Val Acc: 0.7976
# Epoch 58/100: Train Loss: 0.5445, Train Acc: 0.7992, Val Loss: 0.6523, Val Acc: 0.8127
# Epoch 59/100: Train Loss: 0.5485, Train Acc: 0.8008, Val Loss: 0.6474, Val Acc: 0.8127
# Epoch 60/100: Train Loss: 0.5523, Train Acc: 0.8000, Val Loss: 0.6471, Val Acc: 0.8036
# Epoch 61/100: Train Loss: 0.5590, Train Acc: 0.7917, Val Loss: 0.6418, Val Acc: 0.8036
# Epoch 62/100: Train Loss: 0.5503, Train Acc: 0.8053, Val Loss: 0.6390, Val Acc: 0.7915
# Epoch 63/100: Train Loss: 0.5496, Train Acc: 0.7940, Val Loss: 0.6361, Val Acc: 0.7885
# Epoch 64/100: Train Loss: 0.5458, Train Acc: 0.8113, Val Loss: 0.6362, Val Acc: 0.7885
# Epoch 65/100: Train Loss: 0.5360, Train Acc: 0.7872, Val Loss: 0.6713, Val Acc: 0.8338
# Epoch 66/100: Train Loss: 0.5316, Train Acc: 0.8234, Val Loss: 0.6336, Val Acc: 0.7976
# Epoch 67/100: Train Loss: 0.5435, Train Acc: 0.7902, Val Loss: 0.6527, Val Acc: 0.8127
# Epoch 68/100: Train Loss: 0.5358, Train Acc: 0.8340, Val Loss: 0.6389, Val Acc: 0.8036
# Epoch 69/100: Train Loss: 0.5397, Train Acc: 0.7879, Val Loss: 0.6546, Val Acc: 0.7976
# Epoch 70/100: Train Loss: 0.5336, Train Acc: 0.7962, Val Loss: 0.6299, Val Acc: 0.7946
# Epoch 71/100: Train Loss: 0.5296, Train Acc: 0.8113, Val Loss: 0.6412, Val Acc: 0.8097
# Epoch 72/100: Train Loss: 0.5166, Train Acc: 0.7909, Val Loss: 0.6488, Val Acc: 0.8097
# Epoch 73/100: Train Loss: 0.5274, Train Acc: 0.8143, Val Loss: 0.6408, Val Acc: 0.8006
# Epoch 74/100: Train Loss: 0.5402, Train Acc: 0.8000, Val Loss: 0.6276, Val Acc: 0.7915
# Epoch 75/100: Train Loss: 0.5270, Train Acc: 0.8060, Val Loss: 0.6458, Val Acc: 0.8006
# Epoch 76/100: Train Loss: 0.5194, Train Acc: 0.8196, Val Loss: 0.6398, Val Acc: 0.7915
# Epoch 77/100: Train Loss: 0.5231, Train Acc: 0.8060, Val Loss: 0.6382, Val Acc: 0.7946
# Epoch 78/100: Train Loss: 0.5323, Train Acc: 0.8038, Val Loss: 0.6351, Val Acc: 0.7976
# Epoch 79/100: Train Loss: 0.5194, Train Acc: 0.8068, Val Loss: 0.6483, Val Acc: 0.8127
# Epoch 80/100: Train Loss: 0.5177, Train Acc: 0.8189, Val Loss: 0.6367, Val Acc: 0.7976
# Epoch 81/100: Train Loss: 0.5180, Train Acc: 0.8098, Val Loss: 0.6269, Val Acc: 0.7885
# Epoch 82/100: Train Loss: 0.5207, Train Acc: 0.8083, Val Loss: 0.6525, Val Acc: 0.8218
# Epoch 83/100: Train Loss: 0.5162, Train Acc: 0.8023, Val Loss: 0.6437, Val Acc: 0.8127
# Epoch 84/100: Train Loss: 0.5090, Train Acc: 0.8136, Val Loss: 0.6577, Val Acc: 0.8127
# Epoch 85/100: Train Loss: 0.5262, Train Acc: 0.8204, Val Loss: 0.6436, Val Acc: 0.7946
# Epoch 86/100: Train Loss: 0.5082, Train Acc: 0.8083, Val Loss: 0.6507, Val Acc: 0.8187
# Epoch 87/100: Train Loss: 0.5091, Train Acc: 0.8113, Val Loss: 0.6549, Val Acc: 0.8248
# Epoch 88/100: Train Loss: 0.5168, Train Acc: 0.8287, Val Loss: 0.6288, Val Acc: 0.7764
# Epoch 89/100: Train Loss: 0.5195, Train Acc: 0.7857, Val Loss: 0.6380, Val Acc: 0.7976
# Epoch 90/100: Train Loss: 0.5074, Train Acc: 0.8158, Val Loss: 0.6404, Val Acc: 0.7976
# Epoch 91/100: Train Loss: 0.4930, Train Acc: 0.8325, Val Loss: 0.6528, Val Acc: 0.8157
# Epoch 92/100: Train Loss: 0.4912, Train Acc: 0.8257, Val Loss: 0.6323, Val Acc: 0.7764
# Epoch 93/100: Train Loss: 0.4894, Train Acc: 0.8121, Val Loss: 0.6372, Val Acc: 0.7915
# Epoch 94/100: Train Loss: 0.5101, Train Acc: 0.8204, Val Loss: 0.6370, Val Acc: 0.7885
# Epoch 95/100: Train Loss: 0.5113, Train Acc: 0.7925, Val Loss: 0.6523, Val Acc: 0.7976
# Epoch 96/100: Train Loss: 0.5006, Train Acc: 0.8128, Val Loss: 0.6591, Val Acc: 0.8157
# Epoch 97/100: Train Loss: 0.5010, Train Acc: 0.8211, Val Loss: 0.6551, Val Acc: 0.8066
# Epoch 98/100: Train Loss: 0.4936, Train Acc: 0.8211, Val Loss: 0.6431, Val Acc: 0.7946
# Epoch 99/100: Train Loss: 0.4922, Train Acc: 0.8234, Val Loss: 0.6425, Val Acc: 0.7946
# Epoch 100/100: Train Loss: 0.4906, Train Acc: 0.8332, Val Loss: 0.6365, Val Acc: 0.8006
# Fold 3 - Train Loss: 0.4906, Train Accuracy: 0.83%, Val Loss: 0.6365, Val Accuracy: 0.80%
# Fold 4
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/100: Train Loss: 1.0803, Train Acc: 0.4687, Val Loss: 1.0114, Val Acc: 0.5740
# Epoch 2/100: Train Loss: 1.0060, Train Acc: 0.5245, Val Loss: 0.9504, Val Acc: 0.6435
# Epoch 3/100: Train Loss: 0.9677, Train Acc: 0.5834, Val Loss: 0.9151, Val Acc: 0.7009
# Epoch 4/100: Train Loss: 0.9196, Train Acc: 0.6521, Val Loss: 0.8899, Val Acc: 0.6828
# Epoch 5/100: Train Loss: 0.8957, Train Acc: 0.6453, Val Loss: 0.8721, Val Acc: 0.7039
# Epoch 6/100: Train Loss: 0.8730, Train Acc: 0.7094, Val Loss: 0.8451, Val Acc: 0.7100
# Epoch 7/100: Train Loss: 0.8438, Train Acc: 0.6913, Val Loss: 0.8304, Val Acc: 0.7190
# Epoch 8/100: Train Loss: 0.8234, Train Acc: 0.7057, Val Loss: 0.8162, Val Acc: 0.7069
# Epoch 9/100: Train Loss: 0.8081, Train Acc: 0.7117, Val Loss: 0.8055, Val Acc: 0.7190
# Epoch 10/100: Train Loss: 0.7938, Train Acc: 0.7019, Val Loss: 0.7929, Val Acc: 0.7492
# Epoch 11/100: Train Loss: 0.7707, Train Acc: 0.7374, Val Loss: 0.7854, Val Acc: 0.7523
# Epoch 12/100: Train Loss: 0.7659, Train Acc: 0.7064, Val Loss: 0.7771, Val Acc: 0.7281
# Epoch 13/100: Train Loss: 0.7539, Train Acc: 0.7366, Val Loss: 0.7669, Val Acc: 0.7402
# Epoch 14/100: Train Loss: 0.7361, Train Acc: 0.7291, Val Loss: 0.7601, Val Acc: 0.7462
# Epoch 15/100: Train Loss: 0.7326, Train Acc: 0.7472, Val Loss: 0.7522, Val Acc: 0.7553
# Epoch 16/100: Train Loss: 0.7213, Train Acc: 0.7381, Val Loss: 0.7454, Val Acc: 0.7764
# Epoch 17/100: Train Loss: 0.7140, Train Acc: 0.7449, Val Loss: 0.7412, Val Acc: 0.7281
# Epoch 18/100: Train Loss: 0.7048, Train Acc: 0.7525, Val Loss: 0.7374, Val Acc: 0.7311
# Epoch 19/100: Train Loss: 0.7041, Train Acc: 0.7525, Val Loss: 0.7294, Val Acc: 0.7492
# Epoch 20/100: Train Loss: 0.6821, Train Acc: 0.7502, Val Loss: 0.7305, Val Acc: 0.7644
# Epoch 21/100: Train Loss: 0.6736, Train Acc: 0.7653, Val Loss: 0.7200, Val Acc: 0.7795
# Epoch 22/100: Train Loss: 0.6750, Train Acc: 0.7592, Val Loss: 0.7177, Val Acc: 0.7432
# Epoch 23/100: Train Loss: 0.6664, Train Acc: 0.7706, Val Loss: 0.7130, Val Acc: 0.7704
# Epoch 24/100: Train Loss: 0.6577, Train Acc: 0.7728, Val Loss: 0.7106, Val Acc: 0.7734
# Epoch 25/100: Train Loss: 0.6542, Train Acc: 0.7721, Val Loss: 0.7085, Val Acc: 0.7734
# Epoch 26/100: Train Loss: 0.6465, Train Acc: 0.7743, Val Loss: 0.7024, Val Acc: 0.7523
# Epoch 27/100: Train Loss: 0.6466, Train Acc: 0.7653, Val Loss: 0.7006, Val Acc: 0.7674
# Epoch 28/100: Train Loss: 0.6395, Train Acc: 0.7766, Val Loss: 0.6965, Val Acc: 0.7795
# Epoch 29/100: Train Loss: 0.6362, Train Acc: 0.7630, Val Loss: 0.6972, Val Acc: 0.7613
# Epoch 30/100: Train Loss: 0.6331, Train Acc: 0.7789, Val Loss: 0.6952, Val Acc: 0.7885
# Epoch 31/100: Train Loss: 0.6260, Train Acc: 0.7819, Val Loss: 0.6919, Val Acc: 0.7734
# Epoch 32/100: Train Loss: 0.6336, Train Acc: 0.7894, Val Loss: 0.6880, Val Acc: 0.7946
# Epoch 33/100: Train Loss: 0.6215, Train Acc: 0.7691, Val Loss: 0.6832, Val Acc: 0.7764
# Epoch 34/100: Train Loss: 0.6319, Train Acc: 0.7826, Val Loss: 0.6873, Val Acc: 0.7825
# Epoch 35/100: Train Loss: 0.6225, Train Acc: 0.7796, Val Loss: 0.6812, Val Acc: 0.7795
# Epoch 36/100: Train Loss: 0.6085, Train Acc: 0.7970, Val Loss: 0.6802, Val Acc: 0.7432
# Epoch 37/100: Train Loss: 0.6181, Train Acc: 0.7789, Val Loss: 0.6807, Val Acc: 0.7915
# Epoch 38/100: Train Loss: 0.6100, Train Acc: 0.7811, Val Loss: 0.6752, Val Acc: 0.7764
# Epoch 39/100: Train Loss: 0.5999, Train Acc: 0.7819, Val Loss: 0.6767, Val Acc: 0.7825
# Epoch 40/100: Train Loss: 0.5902, Train Acc: 0.7902, Val Loss: 0.6741, Val Acc: 0.7795
# Epoch 41/100: Train Loss: 0.6067, Train Acc: 0.7811, Val Loss: 0.6746, Val Acc: 0.7734
# Epoch 42/100: Train Loss: 0.5875, Train Acc: 0.7826, Val Loss: 0.6819, Val Acc: 0.8097
# Epoch 43/100: Train Loss: 0.5871, Train Acc: 0.8045, Val Loss: 0.6705, Val Acc: 0.7795
# Epoch 44/100: Train Loss: 0.5949, Train Acc: 0.7849, Val Loss: 0.6716, Val Acc: 0.7855
# Epoch 45/100: Train Loss: 0.5807, Train Acc: 0.8083, Val Loss: 0.6695, Val Acc: 0.7885
# Epoch 46/100: Train Loss: 0.5832, Train Acc: 0.8045, Val Loss: 0.6674, Val Acc: 0.7674
# Epoch 47/100: Train Loss: 0.5711, Train Acc: 0.8000, Val Loss: 0.6682, Val Acc: 0.7855
# Epoch 48/100: Train Loss: 0.5707, Train Acc: 0.7902, Val Loss: 0.6719, Val Acc: 0.7885
# Epoch 49/100: Train Loss: 0.5756, Train Acc: 0.8091, Val Loss: 0.6660, Val Acc: 0.7825
# Epoch 50/100: Train Loss: 0.5761, Train Acc: 0.7970, Val Loss: 0.6665, Val Acc: 0.7795
# Epoch 51/100: Train Loss: 0.5669, Train Acc: 0.7962, Val Loss: 0.6604, Val Acc: 0.7764
# Epoch 52/100: Train Loss: 0.5593, Train Acc: 0.7992, Val Loss: 0.6595, Val Acc: 0.7885
# Epoch 53/100: Train Loss: 0.5600, Train Acc: 0.7955, Val Loss: 0.6629, Val Acc: 0.7674
# Epoch 54/100: Train Loss: 0.5673, Train Acc: 0.8008, Val Loss: 0.6605, Val Acc: 0.7492
# Epoch 55/100: Train Loss: 0.5592, Train Acc: 0.7947, Val Loss: 0.6555, Val Acc: 0.7825
# Epoch 56/100: Train Loss: 0.5595, Train Acc: 0.7970, Val Loss: 0.6589, Val Acc: 0.7734
# Epoch 57/100: Train Loss: 0.5575, Train Acc: 0.8030, Val Loss: 0.6606, Val Acc: 0.8036
# Epoch 58/100: Train Loss: 0.5514, Train Acc: 0.8151, Val Loss: 0.6603, Val Acc: 0.7825
# Epoch 59/100: Train Loss: 0.5554, Train Acc: 0.7985, Val Loss: 0.6532, Val Acc: 0.7976
# Epoch 60/100: Train Loss: 0.5440, Train Acc: 0.8226, Val Loss: 0.6594, Val Acc: 0.7523
# Epoch 61/100: Train Loss: 0.5456, Train Acc: 0.7887, Val Loss: 0.6540, Val Acc: 0.7885
# Epoch 62/100: Train Loss: 0.5493, Train Acc: 0.7992, Val Loss: 0.6543, Val Acc: 0.7915
# Epoch 63/100: Train Loss: 0.5447, Train Acc: 0.8030, Val Loss: 0.6583, Val Acc: 0.7553
# Epoch 64/100: Train Loss: 0.5426, Train Acc: 0.8309, Val Loss: 0.6518, Val Acc: 0.7885
# Epoch 65/100: Train Loss: 0.5386, Train Acc: 0.8023, Val Loss: 0.6559, Val Acc: 0.8097
# Epoch 66/100: Train Loss: 0.5498, Train Acc: 0.7857, Val Loss: 0.6554, Val Acc: 0.8066
# Epoch 67/100: Train Loss: 0.5451, Train Acc: 0.8181, Val Loss: 0.6503, Val Acc: 0.7613
# Epoch 68/100: Train Loss: 0.5548, Train Acc: 0.8166, Val Loss: 0.6498, Val Acc: 0.7704
# Epoch 69/100: Train Loss: 0.5439, Train Acc: 0.8151, Val Loss: 0.6448, Val Acc: 0.7734
# Epoch 70/100: Train Loss: 0.5289, Train Acc: 0.7864, Val Loss: 0.6479, Val Acc: 0.7704
# Epoch 71/100: Train Loss: 0.5283, Train Acc: 0.8196, Val Loss: 0.6529, Val Acc: 0.7885
# Epoch 72/100: Train Loss: 0.5225, Train Acc: 0.8317, Val Loss: 0.6463, Val Acc: 0.7795
# Epoch 73/100: Train Loss: 0.5199, Train Acc: 0.8038, Val Loss: 0.6472, Val Acc: 0.8006
# Epoch 74/100: Train Loss: 0.5219, Train Acc: 0.8294, Val Loss: 0.6485, Val Acc: 0.7915
# Epoch 75/100: Train Loss: 0.5214, Train Acc: 0.8136, Val Loss: 0.6466, Val Acc: 0.7855
# Epoch 76/100: Train Loss: 0.5087, Train Acc: 0.8294, Val Loss: 0.6462, Val Acc: 0.7674
# Epoch 77/100: Train Loss: 0.5282, Train Acc: 0.8257, Val Loss: 0.6525, Val Acc: 0.7492
# Epoch 78/100: Train Loss: 0.5254, Train Acc: 0.8030, Val Loss: 0.6489, Val Acc: 0.8127
# Epoch 79/100: Train Loss: 0.5151, Train Acc: 0.8377, Val Loss: 0.6504, Val Acc: 0.7795
# Epoch 80/100: Train Loss: 0.5282, Train Acc: 0.8098, Val Loss: 0.6482, Val Acc: 0.7825
# Epoch 81/100: Train Loss: 0.5197, Train Acc: 0.8219, Val Loss: 0.6465, Val Acc: 0.7523
# Epoch 82/100: Train Loss: 0.5282, Train Acc: 0.8053, Val Loss: 0.6432, Val Acc: 0.7432
# Epoch 83/100: Train Loss: 0.5261, Train Acc: 0.8053, Val Loss: 0.6484, Val Acc: 0.7885
# Epoch 84/100: Train Loss: 0.5115, Train Acc: 0.8377, Val Loss: 0.6457, Val Acc: 0.7553
# Epoch 85/100: Train Loss: 0.5180, Train Acc: 0.8091, Val Loss: 0.6449, Val Acc: 0.7523
# Epoch 86/100: Train Loss: 0.5218, Train Acc: 0.8226, Val Loss: 0.6402, Val Acc: 0.7795
# Epoch 87/100: Train Loss: 0.5058, Train Acc: 0.8257, Val Loss: 0.6434, Val Acc: 0.7795
# Epoch 88/100: Train Loss: 0.5103, Train Acc: 0.8158, Val Loss: 0.6458, Val Acc: 0.7523
# Epoch 89/100: Train Loss: 0.5190, Train Acc: 0.8181, Val Loss: 0.6458, Val Acc: 0.7553
# Epoch 90/100: Train Loss: 0.5179, Train Acc: 0.8075, Val Loss: 0.6436, Val Acc: 0.7825
# Epoch 91/100: Train Loss: 0.5134, Train Acc: 0.8189, Val Loss: 0.6374, Val Acc: 0.7462
# Epoch 92/100: Train Loss: 0.5048, Train Acc: 0.8196, Val Loss: 0.6418, Val Acc: 0.7795
# Epoch 93/100: Train Loss: 0.5070, Train Acc: 0.8091, Val Loss: 0.6464, Val Acc: 0.7946
# Epoch 94/100: Train Loss: 0.5061, Train Acc: 0.8143, Val Loss: 0.6426, Val Acc: 0.7976
# Epoch 95/100: Train Loss: 0.5074, Train Acc: 0.8211, Val Loss: 0.6433, Val Acc: 0.7644
# Epoch 96/100: Train Loss: 0.4988, Train Acc: 0.8219, Val Loss: 0.6414, Val Acc: 0.7674
# Epoch 97/100: Train Loss: 0.4997, Train Acc: 0.8226, Val Loss: 0.6433, Val Acc: 0.7583
# Epoch 98/100: Train Loss: 0.4979, Train Acc: 0.8347, Val Loss: 0.6448, Val Acc: 0.8006
# Epoch 99/100: Train Loss: 0.4980, Train Acc: 0.8257, Val Loss: 0.6371, Val Acc: 0.7644
# Epoch 100/100: Train Loss: 0.4962, Train Acc: 0.8392, Val Loss: 0.6408, Val Acc: 0.7674
# Fold 4 - Train Loss: 0.4962, Train Accuracy: 0.84%, Val Loss: 0.6408, Val Accuracy: 0.77%
# Fold 5
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/100: Train Loss: 1.2411, Train Acc: 0.3419, Val Loss: 1.1709, Val Acc: 0.2024
# Epoch 2/100: Train Loss: 1.0937, Train Acc: 0.4136, Val Loss: 1.0601, Val Acc: 0.4894
# Epoch 3/100: Train Loss: 1.0315, Train Acc: 0.5223, Val Loss: 1.0108, Val Acc: 0.5680
# Epoch 4/100: Train Loss: 0.9824, Train Acc: 0.5985, Val Loss: 0.9684, Val Acc: 0.6133
# Epoch 5/100: Train Loss: 0.9345, Train Acc: 0.6204, Val Loss: 0.9335, Val Acc: 0.6344
# Epoch 6/100: Train Loss: 0.9042, Train Acc: 0.6936, Val Loss: 0.9082, Val Acc: 0.6073
# Epoch 7/100: Train Loss: 0.8701, Train Acc: 0.6551, Val Loss: 0.8841, Val Acc: 0.6858
# Epoch 8/100: Train Loss: 0.8396, Train Acc: 0.7366, Val Loss: 0.8650, Val Acc: 0.6465
# Epoch 9/100: Train Loss: 0.8359, Train Acc: 0.6921, Val Loss: 0.8497, Val Acc: 0.7311
# Epoch 10/100: Train Loss: 0.8057, Train Acc: 0.7442, Val Loss: 0.8311, Val Acc: 0.6858
# Epoch 11/100: Train Loss: 0.7838, Train Acc: 0.7238, Val Loss: 0.8242, Val Acc: 0.7251
# Epoch 12/100: Train Loss: 0.7744, Train Acc: 0.7532, Val Loss: 0.8054, Val Acc: 0.7221
# Epoch 13/100: Train Loss: 0.7617, Train Acc: 0.7547, Val Loss: 0.7899, Val Acc: 0.7069
# Epoch 14/100: Train Loss: 0.7450, Train Acc: 0.7426, Val Loss: 0.7838, Val Acc: 0.7160
# Epoch 15/100: Train Loss: 0.7277, Train Acc: 0.7479, Val Loss: 0.7752, Val Acc: 0.7190
# Epoch 16/100: Train Loss: 0.7286, Train Acc: 0.7721, Val Loss: 0.7727, Val Acc: 0.7523
# Epoch 17/100: Train Loss: 0.7198, Train Acc: 0.7691, Val Loss: 0.7615, Val Acc: 0.7492
# Epoch 18/100: Train Loss: 0.7006, Train Acc: 0.7713, Val Loss: 0.7558, Val Acc: 0.7039
# Epoch 19/100: Train Loss: 0.6895, Train Acc: 0.7691, Val Loss: 0.7505, Val Acc: 0.7644
# Epoch 20/100: Train Loss: 0.6751, Train Acc: 0.7857, Val Loss: 0.7415, Val Acc: 0.7069
# Epoch 21/100: Train Loss: 0.6896, Train Acc: 0.7675, Val Loss: 0.7368, Val Acc: 0.7462
# Epoch 22/100: Train Loss: 0.6755, Train Acc: 0.7826, Val Loss: 0.7331, Val Acc: 0.7100
# Epoch 23/100: Train Loss: 0.6536, Train Acc: 0.7721, Val Loss: 0.7351, Val Acc: 0.7764
# Epoch 24/100: Train Loss: 0.6613, Train Acc: 0.7819, Val Loss: 0.7283, Val Acc: 0.7432
# Epoch 25/100: Train Loss: 0.6629, Train Acc: 0.7789, Val Loss: 0.7236, Val Acc: 0.7553
# Epoch 26/100: Train Loss: 0.6477, Train Acc: 0.8068, Val Loss: 0.7212, Val Acc: 0.7523
# Epoch 27/100: Train Loss: 0.6348, Train Acc: 0.7789, Val Loss: 0.7178, Val Acc: 0.7402
# Epoch 28/100: Train Loss: 0.6440, Train Acc: 0.7970, Val Loss: 0.7174, Val Acc: 0.7613
# Epoch 29/100: Train Loss: 0.6336, Train Acc: 0.7698, Val Loss: 0.7115, Val Acc: 0.7644
# Epoch 30/100: Train Loss: 0.6318, Train Acc: 0.7932, Val Loss: 0.7183, Val Acc: 0.7523
# Epoch 31/100: Train Loss: 0.6186, Train Acc: 0.7902, Val Loss: 0.7101, Val Acc: 0.7372
# Epoch 32/100: Train Loss: 0.6247, Train Acc: 0.7955, Val Loss: 0.7085, Val Acc: 0.7462
# Epoch 33/100: Train Loss: 0.6062, Train Acc: 0.8083, Val Loss: 0.7035, Val Acc: 0.7281
# Epoch 34/100: Train Loss: 0.6197, Train Acc: 0.7758, Val Loss: 0.7067, Val Acc: 0.7764
# Epoch 35/100: Train Loss: 0.6131, Train Acc: 0.7902, Val Loss: 0.7009, Val Acc: 0.7402
# Epoch 36/100: Train Loss: 0.6210, Train Acc: 0.7789, Val Loss: 0.7015, Val Acc: 0.7583
# Epoch 37/100: Train Loss: 0.6015, Train Acc: 0.7932, Val Loss: 0.7018, Val Acc: 0.7462
# Epoch 38/100: Train Loss: 0.6070, Train Acc: 0.7940, Val Loss: 0.6989, Val Acc: 0.7613
# Epoch 39/100: Train Loss: 0.6037, Train Acc: 0.8023, Val Loss: 0.7040, Val Acc: 0.7704
# Epoch 40/100: Train Loss: 0.5922, Train Acc: 0.8106, Val Loss: 0.6958, Val Acc: 0.7402
# Epoch 41/100: Train Loss: 0.5938, Train Acc: 0.7751, Val Loss: 0.7038, Val Acc: 0.7855
# Epoch 42/100: Train Loss: 0.5883, Train Acc: 0.8068, Val Loss: 0.6947, Val Acc: 0.7704
# Epoch 43/100: Train Loss: 0.5893, Train Acc: 0.7917, Val Loss: 0.6969, Val Acc: 0.7462
# Epoch 44/100: Train Loss: 0.5807, Train Acc: 0.8053, Val Loss: 0.6970, Val Acc: 0.7674
# Epoch 45/100: Train Loss: 0.5718, Train Acc: 0.8023, Val Loss: 0.6942, Val Acc: 0.7704
# Epoch 46/100: Train Loss: 0.5712, Train Acc: 0.8196, Val Loss: 0.6951, Val Acc: 0.7432
# Epoch 47/100: Train Loss: 0.5780, Train Acc: 0.7909, Val Loss: 0.6919, Val Acc: 0.7462
# Epoch 48/100: Train Loss: 0.5763, Train Acc: 0.8053, Val Loss: 0.6939, Val Acc: 0.7583
# Epoch 49/100: Train Loss: 0.5680, Train Acc: 0.7970, Val Loss: 0.6982, Val Acc: 0.7825
# Epoch 50/100: Train Loss: 0.5664, Train Acc: 0.8332, Val Loss: 0.6929, Val Acc: 0.7492
# Epoch 51/100: Train Loss: 0.5611, Train Acc: 0.7940, Val Loss: 0.6940, Val Acc: 0.7795
# Epoch 52/100: Train Loss: 0.5587, Train Acc: 0.8068, Val Loss: 0.6953, Val Acc: 0.7764
# Epoch 53/100: Train Loss: 0.5549, Train Acc: 0.8045, Val Loss: 0.6901, Val Acc: 0.7734
# Epoch 54/100: Train Loss: 0.5617, Train Acc: 0.8158, Val Loss: 0.6858, Val Acc: 0.7372
# Epoch 55/100: Train Loss: 0.5549, Train Acc: 0.8083, Val Loss: 0.6929, Val Acc: 0.7553
# Epoch 56/100: Train Loss: 0.5584, Train Acc: 0.7962, Val Loss: 0.7000, Val Acc: 0.7885
# Epoch 57/100: Train Loss: 0.5555, Train Acc: 0.8166, Val Loss: 0.6855, Val Acc: 0.7583
# Epoch 58/100: Train Loss: 0.5491, Train Acc: 0.8083, Val Loss: 0.6919, Val Acc: 0.7764
# Epoch 59/100: Train Loss: 0.5315, Train Acc: 0.8196, Val Loss: 0.6883, Val Acc: 0.7613
# Epoch 60/100: Train Loss: 0.5392, Train Acc: 0.8121, Val Loss: 0.6966, Val Acc: 0.7825
# Epoch 61/100: Train Loss: 0.5343, Train Acc: 0.8302, Val Loss: 0.6857, Val Acc: 0.7341
# Epoch 62/100: Train Loss: 0.5412, Train Acc: 0.8181, Val Loss: 0.6882, Val Acc: 0.7613
# Epoch 63/100: Train Loss: 0.5339, Train Acc: 0.8060, Val Loss: 0.6925, Val Acc: 0.7613
# Epoch 64/100: Train Loss: 0.5217, Train Acc: 0.8234, Val Loss: 0.6991, Val Acc: 0.7674
# Epoch 65/100: Train Loss: 0.5431, Train Acc: 0.8158, Val Loss: 0.6963, Val Acc: 0.7764
# Epoch 66/100: Train Loss: 0.5383, Train Acc: 0.8128, Val Loss: 0.6893, Val Acc: 0.7523
# Epoch 67/100: Train Loss: 0.5282, Train Acc: 0.8234, Val Loss: 0.6840, Val Acc: 0.7553
# Epoch 68/100: Train Loss: 0.5208, Train Acc: 0.8257, Val Loss: 0.6905, Val Acc: 0.7613
# Epoch 69/100: Train Loss: 0.5276, Train Acc: 0.8128, Val Loss: 0.6887, Val Acc: 0.7613
# Epoch 70/100: Train Loss: 0.5151, Train Acc: 0.8226, Val Loss: 0.6906, Val Acc: 0.7462
# Epoch 71/100: Train Loss: 0.5200, Train Acc: 0.8257, Val Loss: 0.6906, Val Acc: 0.7734
# Epoch 72/100: Train Loss: 0.5251, Train Acc: 0.8113, Val Loss: 0.6963, Val Acc: 0.7885
# Epoch 73/100: Train Loss: 0.5191, Train Acc: 0.8325, Val Loss: 0.6837, Val Acc: 0.7462
# Epoch 74/100: Train Loss: 0.5097, Train Acc: 0.8279, Val Loss: 0.6942, Val Acc: 0.7734
# Epoch 75/100: Train Loss: 0.5175, Train Acc: 0.8143, Val Loss: 0.6925, Val Acc: 0.7674
# Epoch 76/100: Train Loss: 0.5180, Train Acc: 0.8242, Val Loss: 0.6884, Val Acc: 0.7553
# Epoch 77/100: Train Loss: 0.5181, Train Acc: 0.8181, Val Loss: 0.6898, Val Acc: 0.7523
# Epoch 78/100: Train Loss: 0.5041, Train Acc: 0.8219, Val Loss: 0.6910, Val Acc: 0.7644
# Epoch 79/100: Train Loss: 0.5037, Train Acc: 0.8415, Val Loss: 0.6951, Val Acc: 0.7704
# Epoch 80/100: Train Loss: 0.5071, Train Acc: 0.8377, Val Loss: 0.6854, Val Acc: 0.7613
# Epoch 81/100: Train Loss: 0.5081, Train Acc: 0.8302, Val Loss: 0.6895, Val Acc: 0.7644
# Epoch 82/100: Train Loss: 0.5027, Train Acc: 0.8242, Val Loss: 0.7009, Val Acc: 0.7644
# Epoch 83/100: Train Loss: 0.5038, Train Acc: 0.8453, Val Loss: 0.6948, Val Acc: 0.7553
# Epoch 84/100: Train Loss: 0.4980, Train Acc: 0.8143, Val Loss: 0.7051, Val Acc: 0.7825
# Epoch 85/100: Train Loss: 0.4999, Train Acc: 0.8377, Val Loss: 0.6955, Val Acc: 0.7492
# Epoch 86/100: Train Loss: 0.4989, Train Acc: 0.8317, Val Loss: 0.6887, Val Acc: 0.7432
# Epoch 87/100: Train Loss: 0.4982, Train Acc: 0.8219, Val Loss: 0.6960, Val Acc: 0.7553
# Epoch 88/100: Train Loss: 0.4922, Train Acc: 0.8279, Val Loss: 0.6942, Val Acc: 0.7523
# Epoch 89/100: Train Loss: 0.5001, Train Acc: 0.8302, Val Loss: 0.6938, Val Acc: 0.7432
# Epoch 90/100: Train Loss: 0.4884, Train Acc: 0.8226, Val Loss: 0.7165, Val Acc: 0.7885
# Epoch 91/100: Train Loss: 0.5056, Train Acc: 0.8423, Val Loss: 0.6964, Val Acc: 0.7553
# Epoch 92/100: Train Loss: 0.4895, Train Acc: 0.8385, Val Loss: 0.7024, Val Acc: 0.7644
# Epoch 93/100: Train Loss: 0.4825, Train Acc: 0.8362, Val Loss: 0.6950, Val Acc: 0.7462
# Epoch 94/100: Train Loss: 0.4802, Train Acc: 0.8362, Val Loss: 0.7060, Val Acc: 0.7553
# Epoch 95/100: Train Loss: 0.4969, Train Acc: 0.8242, Val Loss: 0.7070, Val Acc: 0.7825
# Epoch 96/100: Train Loss: 0.4833, Train Acc: 0.8370, Val Loss: 0.7008, Val Acc: 0.7553
# Epoch 97/100: Train Loss: 0.4833, Train Acc: 0.8325, Val Loss: 0.7063, Val Acc: 0.7644
# Epoch 98/100: Train Loss: 0.4906, Train Acc: 0.8347, Val Loss: 0.7043, Val Acc: 0.7734
# Epoch 99/100: Train Loss: 0.4865, Train Acc: 0.8257, Val Loss: 0.7092, Val Acc: 0.7462
# Epoch 100/100: Train Loss: 0.4876, Train Acc: 0.8491, Val Loss: 0.7034, Val Acc: 0.7523
# Fold 5 - Train Loss: 0.4876, Train Accuracy: 0.85%, Val Loss: 0.7034, Val Accuracy: 0.75%

# %%
import torch
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from PIL import Image
import pandas as pd
import numpy as np
import os


class MineralDataset(Dataset):
    def __init__(self, img_dir, dataframe, transform=None):
        self.dataframe = dataframe
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        file_name = row['Segmented Filename']
        label = row['Class']
        img_path = os.path.join(self.img_dir, file_name)
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label


transform_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


IMAGE_DIR = '/Mineral/CPX seg'
TEST_SPLIT_FILE = '/Mineral/test_split.csv'
test_data = pd.read_csv(TEST_SPLIT_FILE)
test_dataset = MineralDataset(img_dir=IMAGE_DIR, dataframe=test_data, transform=transform_test)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


test_labels = []
for _, labels in test_loader:
    test_labels.extend(labels.numpy())
test_labels = np.array(test_labels)


all_model_predictions = []
for fold in range(1, 6):
    model_path = f'/Mineral/complete_model_fold_{fold}.pth'
    model = torch.load(model_path)
    model.to(device)
    model.eval()

    fold_predictions = []
    with torch.no_grad():
        for inputs, _ in test_loader:
            inputs = inputs.to(device)
            outputs = model(inputs)
            probabilities = torch.softmax(outputs, dim=1)
            fold_predictions.append(probabilities.cpu().numpy())

    fold_predictions = np.concatenate(fold_predictions)
    all_model_predictions.append(fold_predictions)

#final prediction label
predicted_classes = np.array([np.argmax(preds, axis=1) for preds in all_model_predictions])
final_predictions = []
for sample_predictions in predicted_classes.T:
    values, counts = np.unique(sample_predictions, return_counts=True)
    most_frequent = values[np.argmax(counts)]
    final_predictions.append(most_frequent)
final_predictions = np.array(final_predictions)

# %%
import os
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import copy
from sklearn.metrics import roc_auc_score, balanced_accuracy_score, recall_score, precision_score

criterion = nn.CrossEntropyLoss()

def evaluate_model(model, data_loader, criterion, device):
    model.eval()
    all_probs = []
    all_labels = []
    all_losses = []

    with torch.no_grad(): 
        for inputs, labels in data_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            probabilities = torch.softmax(outputs, dim=1)
            all_probs.append(probabilities.cpu().numpy())
            all_labels.append(labels.cpu().numpy())
            all_losses.append(loss.cpu().numpy())

    all_probs = np.concatenate(all_probs)
    all_labels = np.concatenate(all_labels)
    all_losses = np.array(all_losses)
    return all_probs, all_labels, all_losses

def bootstrap_metric(y_true, y_prob, metric_func, n_bootstrap=1000, alpha=0.05, **kwargs):
    rng = np.random.default_rng()
    indices = np.arange(len(y_true))
    bootstrapped_scores = []
    for _ in range(n_bootstrap):
        sample_indices = rng.choice(indices, size=len(indices), replace=True)
        if metric_func == roc_auc_score:
            score = metric_func(y_true[sample_indices], y_prob[sample_indices], **kwargs)
        else:
            y_pred = np.argmax(y_prob[sample_indices], axis=1)
            score = metric_func(y_true[sample_indices], y_pred, **kwargs)
        bootstrapped_scores.append(score)
    sorted_scores = np.sort(bootstrapped_scores)
    ci_lower = sorted_scores[int((alpha/2) * n_bootstrap)]
    ci_upper = sorted_scores[int((1 - alpha/2) * n_bootstrap)]
    return np.mean(bootstrapped_scores), ci_lower, ci_upper

def bootstrap_loss(losses, n_bootstrap=1000, alpha=0.05):
    rng = np.random.default_rng()
    indices = np.arange(len(losses))
    bootstrapped_losses = []
    for _ in range(n_bootstrap):
        sample_indices = rng.choice(indices, size=len(indices), replace=True)
        sample_loss = losses[sample_indices]
        bootstrapped_losses.append(np.mean(sample_loss))
    sorted_losses = np.sort(bootstrapped_losses)
    ci_lower = sorted_losses[int((alpha/2) * n_bootstrap)]
    ci_upper = sorted_losses[int((1 - alpha/2) * n_bootstrap)]
    return np.mean(bootstrapped_losses), ci_lower, ci_upper


test_probs, test_labels, test_losses = evaluate_model(model, test_loader, criterion, device)

class_labels = np.unique(test_labels)
metrics = {}
for class_label in class_labels:
    auc_roc_mean, auc_roc_ci_low, auc_roc_ci_high = bootstrap_metric(test_labels == class_label, test_probs[:, class_label], roc_auc_score)
    balanced_acc_mean, balanced_acc_ci_low, balanced_acc_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, final_predictions: balanced_accuracy_score(y_true == class_label, final_predictions == class_label))
    sensitivity_mean, sensitivity_ci_low, sensitivity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, final_predictions: recall_score(y_true == class_label, final_predictions == class_label, zero_division=0))
    specificity_mean, specificity_ci_low, specificity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, final_predictions: precision_score(y_true == class_label, final_predictions == class_label, zero_division=0))

    metrics[class_label] = {
        "AUC-ROC": (auc_roc_mean, auc_roc_ci_low, auc_roc_ci_high),
        "Balanced Accuracy": (balanced_acc_mean, balanced_acc_ci_low, balanced_acc_ci_high),
        "Sensitivity": (sensitivity_mean, sensitivity_ci_low, sensitivity_ci_high),
        "Specificity": (specificity_mean, specificity_ci_low, specificity_ci_high)
    }


print("Class\t\tAUC-ROC\t\t\tBalanced Accuracy\tSensitivity\t\tSpecificity")
for class_label, metric_values in metrics.items():
    auc_roc = metric_values["AUC-ROC"]
    balanced_acc = metric_values["Balanced Accuracy"]
    sensitivity = metric_values["Sensitivity"]
    specificity = metric_values["Specificity"]
    print(f"{class_label}\t\t{auc_roc[0]:.2f} ({auc_roc[1]:.2f}-{auc_roc[2]:.2f})\t"
          f"{balanced_acc[0]:.2f} ({balanced_acc[1]:.2f}-{balanced_acc[2]:.2f})\t"
          f"{sensitivity[0]:.2f} ({sensitivity[1]:.2f}-{sensitivity[2]:.2f})\t"
          f"{specificity[0]:.2f} ({specificity[1]:.2f}-{specificity[2]:.2f})")


auc_roc_mean, auc_roc_ci_low, auc_roc_ci_high = bootstrap_metric(test_labels, test_probs, roc_auc_score, multi_class='ovr')
balanced_acc_mean, balanced_acc_ci_low, balanced_acc_ci_high = bootstrap_metric(test_labels, test_probs, balanced_accuracy_score)
sensitivity_mean, sensitivity_ci_low, sensitivity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, final_predictions: recall_score(y_true, final_predictions, average='macro', zero_division=0))
specificity_mean, specificity_ci_low, specificity_ci_high = bootstrap_metric(test_labels, test_probs, lambda y_true, final_predictions: precision_score(y_true, final_predictions, average='macro', zero_division=0))


loss_mean, loss_ci_low, loss_ci_high = bootstrap_loss(test_losses)

print(f"Overall\t\t{auc_roc_mean:.2f} ({auc_roc_ci_low:.2f}-{auc_roc_ci_high:.2f})\t"
      f"{balanced_acc_mean:.2f} ({balanced_acc_ci_low:.2f}-{balanced_acc_ci_high:.2f})\t"
      f"{sensitivity_mean:.2f} ({sensitivity_ci_low:.2f}-{sensitivity_ci_high:.2f})\t"
      f"{specificity_mean:.2f} ({specificity_ci_low:.2f}-{specificity_ci_high:.2f})")
print(f"Loss\t\t{loss_mean:.4f} ({loss_ci_low:.4f}-{loss_ci_high:.4f})")
# Out:
# Class		AUC-ROC			Balanced Accuracy	Sensitivity		Specificity
# 0		0.95 (0.93-0.98)	0.89 (0.86-0.93)	0.91 (0.85-0.96)	0.79 (0.71-0.86)
# 1		0.90 (0.85-0.94)	0.83 (0.79-0.87)	0.77 (0.70-0.83)	0.90 (0.86-0.95)
# 2		0.73 (0.62-0.83)	0.67 (0.58-0.77)	0.45 (0.26-0.65)	0.32 (0.17-0.48)
# Overall		0.86 (0.81-0.90)	0.71 (0.64-0.78)	0.71 (0.64-0.78)	0.67 (0.61-0.73)
# Loss		0.6069 (0.5260-0.6880)
